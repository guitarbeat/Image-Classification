# %% [markdown]
# ## Image Focus and Astigmatism Classifier
# - **Author:** [Aaron Woods](https://aaronwoods.info)
# - **Date Created:** October, 5, 2023
# - **Repository:** [Image Classification on VSCode](https://insiders.vscode.dev/tunnel/midnightsim/c:/Users/User/Desktop/Image-Classification)
#
# ### Description
# This script provides an end-to-end machine learning pipeline for image classification. It can categorize images as "In Focus" or "Out of Focus" while also detecting astigmatism-related issues. The design is modular, making it adaptable to various image classification tasks.
#
# ### Features
# - Ingests data from Excel spreadsheets.
# - Utilizes multiple machine learning models.
# - Modular design for easy customization.
#
# ### Requirements

# %%
# ------------------------------
# Package Installation (Optional)
# ------------------------------
# Uncomment the following lines to install required packages if running on a new machine.

# %pip install opencv-python numpy pandas matplotlib protobuf seaborn scikit-learn openpyxl jinja2

# ------------------------------
# TensorFlow Installation with GPU Support
# ------------------------------
# Note: TensorFlow versions above 2.10 are not supported on GPUs on native Windows installations.
# For more details, visit: https://www.tensorflow.org/install/pip#windows-wsl2_1

# Uncomment the following line to install TensorFlow if needed.
# %pip install "tensorflow<2.11" --user
# Out:
# Requirement already satisfied: opencv-python in c:\users\aaron.woods\appdata\local\anaconda3\envs\tf\lib\site-packages (4.8.0.76)
# Requirement already satisfied: numpy in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (1.26.0)
# Requirement already satisfied: pandas in c:\users\aaron.woods\appdata\local\anaconda3\envs\tf\lib\site-packages (2.1.1)
# Requirement already satisfied: matplotlib in c:\users\aaron.woods\appdata\local\anaconda3\envs\tf\lib\site-packages (3.8.0)
# Requirement already satisfied: protobuf in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (3.19.6)
# Requirement already satisfied: seaborn in c:\users\aaron.woods\appdata\local\anaconda3\envs\tf\lib\site-packages (0.12.2)
# Requirement already satisfied: scikit-learn in c:\users\aaron.woods\appdata\local\anaconda3\envs\tf\lib\site-packages (1.3.1)
# Requirement already satisfied: openpyxl in c:\users\aaron.woods\appdata\local\anaconda3\envs\tf\lib\site-packages (3.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\aaron.woods\appdata\local\anaconda3\envs\tf\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\aaron.woods\appdata\local\anaconda3\envs\tf\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\aaron.woods\appdata\local\anaconda3\envs\tf\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\aaron.woods\appdata\local\anaconda3\envs\tf\lib\site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\aaron.woods\appdata\local\anaconda3\envs\tf\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\aaron.woods\appdata\local\anaconda3\envs\tf\lib\site-packages (from matplotlib) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\aaron.woods\appdata\local\anaconda3\envs\tf\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\aaron.woods\appdata\local\anaconda3\envs\tf\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\aaron.woods\appdata\local\anaconda3\envs\tf\lib\site-packages (from matplotlib) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\aaron.woods\appdata\local\anaconda3\envs\tf\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\aaron.woods\appdata\local\anaconda3\envs\tf\lib\site-packages (from matplotlib) (6.1.0)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\aaron.woods\appdata\local\anaconda3\envs\tf\lib\site-packages (from scikit-learn) (1.11.2)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\aaron.woods\appdata\local\anaconda3\envs\tf\lib\site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\aaron.woods\appdata\local\anaconda3\envs\tf\lib\site-packages (from scikit-learn) (3.2.0)
# Requirement already satisfied: et-xmlfile in c:\users\aaron.woods\appdata\local\anaconda3\envs\tf\lib\site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\aaron.woods\appdata\local\anaconda3\envs\tf\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.17.0)
# Requirement already satisfied: six>=1.5 in c:\users\aaron.woods\appdata\local\anaconda3\envs\tf\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tensorflow<2.11 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (2.10.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from tensorflow<2.11) (2.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from tensorflow<2.11) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from tensorflow<2.11) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from tensorflow<2.11) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from tensorflow<2.11) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from tensorflow<2.11) (3.9.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from tensorflow<2.11) (1.1.2)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from tensorflow<2.11) (16.0.6)
# Requirement already satisfied: numpy>=1.20 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from tensorflow<2.11) (1.26.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from tensorflow<2.11) (3.3.0)
# Requirement already satisfied: packaging in c:\users\aaron.woods\appdata\local\anaconda3\envs\tf\lib\site-packages (from tensorflow<2.11) (23.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from tensorflow<2.11) (3.19.6)
# Requirement already satisfied: setuptools in c:\users\aaron.woods\appdata\local\anaconda3\envs\tf\lib\site-packages (from tensorflow<2.11) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\aaron.woods\appdata\local\anaconda3\envs\tf\lib\site-packages (from tensorflow<2.11) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from tensorflow<2.11) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\aaron.woods\appdata\local\anaconda3\envs\tf\lib\site-packages (from tensorflow<2.11) (4.8.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from tensorflow<2.11) (1.15.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from tensorflow<2.11) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from tensorflow<2.11) (1.58.0)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from tensorflow<2.11) (2.10.1)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from tensorflow<2.11) (2.10.0)
# Requirement already satisfied: keras<2.11,>=2.10.0 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from tensorflow<2.11) (2.10.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\aaron.woods\appdata\local\anaconda3\envs\tf\lib\site-packages (from astunparse>=1.6.0->tensorflow<2.11) (0.38.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from tensorboard<2.11,>=2.10->tensorflow<2.11) (2.23.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from tensorboard<2.11,>=2.10->tensorflow<2.11) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from tensorboard<2.11,>=2.10->tensorflow<2.11) (3.4.4)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from tensorboard<2.11,>=2.10->tensorflow<2.11) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from tensorboard<2.11,>=2.10->tensorflow<2.11) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from tensorboard<2.11,>=2.10->tensorflow<2.11) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from tensorboard<2.11,>=2.10->tensorflow<2.11) (2.3.7)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow<2.11) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow<2.11) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow<2.11) (4.9)
# Requirement already satisfied: urllib3<2.0 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow<2.11) (1.26.16)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow<2.11) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\aaron.woods\appdata\local\anaconda3\envs\tf\lib\site-packages (from markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow<2.11) (6.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow<2.11) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow<2.11) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow<2.11) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from werkzeug>=1.0.1->tensorboard<2.11,>=2.10->tensorflow<2.11) (2.1.3)
# Requirement already satisfied: zipp>=0.5 in c:\users\aaron.woods\appdata\local\anaconda3\envs\tf\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow<2.11) (3.17.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow<2.11) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow<2.11) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# ------------------------------
# System and TensorFlow Info Check
# ------------------------------
import platform
import tensorflow as tf

def get_system_info():
    """Get system and TensorFlow information."""
    system_info = {"Platform": platform.platform(), "Python Version": platform.python_version()}
    
    try:
        system_info.update({
            "TensorFlow Version": tf.__version__,
            "Num GPUs Available": len(tf.config.list_physical_devices('GPU'))
        })
        system_info['Instructions'] = (
            "You're all set to run your model on a GPU." 
            if system_info['Num GPUs Available'] 
            else (
                "No GPUs found. To use a GPU, follow these steps:\n"
                "  1. Install NVIDIA drivers for your GPU.\n"
                "  2. Install a compatible CUDA toolkit.\n"
                "  3. Install the cuDNN library.\n"
                "  4. Make sure to install the GPU version of TensorFlow."
            )
        )
    except ModuleNotFoundError:
        system_info['Instructions'] = (
            "TensorFlow is not installed. "
            "Install it using pip by running: !pip install tensorflow"
        )
    
    return system_info

def configure_gpu_memory_growth():
    """Set GPU memory consumption growth to avoid OOM errors."""
    gpus = tf.config.experimental.list_physical_devices('GPU')
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)

# Call functions to get system info and configure GPU memory.
system_info = get_system_info()
configure_gpu_memory_growth()

# Print system information.
formatted_info = "\n".join(f"{key}: {value}" for key, value in system_info.items())
print(formatted_info)
# Out:
# Platform: Windows-10-10.0.22621-SP0
# Python Version: 3.9.18
# TensorFlow Version: 2.10.1
# Num GPUs Available: 1
# Instructions: You're all set to run your model on a GPU.

# %%
# ------------------------------
# Import Libraries
# ------------------------------

# Standard Libraries
import os
import sys
import random
import math
import glob
import logging
from datetime import datetime
from collections import defaultdict, Counter

# Third-Party Libraries
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MultiLabelBinarizer
from sklearn.utils import class_weight, resample
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import confusion_matrix

# TensorFlow and Keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, callbacks, optimizers, applications
from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow.keras.callbacks import TensorBoard, Callback
from tensorflow.data import Dataset
from tensorflow.keras.models import load_model

# Other Imports
import pickle
import itertools
from matplotlib.legend_handler import HandlerTuple

# Type Annotations
from typing import List, Dict, Tuple, Union, Any, Optional

# %% [markdown]
# ## Configuration

# %%
# Configuration Dictionary

# DOE_v2 Experiment has classweights working!

experiment_config = {
    'NAME': "Oct9_100pct_CW_Laptop",            # Experiment name
    'RANDOM_SEED': 42,                             # Seed for reproducibility
    'PROBLEM_TYPE': 'Multi-Output',                # Problem type: Binary, Multi-Class, Multi-Output, Multi-Label
}

model_config = {
    'IMG_SIZE': 224,                               # Image input size
    'BATCH_SIZE': 16,                              # Batch size for training
    'TRAIN_SIZE': 0.8,                             # Fraction of data to use for training
    'VAL_SIZE': 0.5,                               # Fraction of data to use for validation
    'EPOCHS': 100,                                 # Number of training epochs
    'LEARNING_RATE': 0.001,                        # Learning rate 1e-3
    'EARLY_STOPPING_PATIENCE': 50,                 # Early stopping patience
    'REDUCE_LR_PATIENCE': 3,                       # Reduce learning rate on plateau patience
    'MIN_LR': 1e-6,                                # Minimum learning rate
}

label_mappings = {
    'Focus_Label': {'SharpFocus': 0, 'SlightlyBlurred': 1, 'HighlyBlurred': 2},
    'StigX_Label': {'OptimalStig_X': 0, 'ModerateStig_X': 1, 'SevereStig_X': 2},
    'StigY_Label': {'OptimalStig_Y': 0, 'ModerateStig_Y': 1, 'SevereStig_Y': 2},
}

augmentation_config = {
    'rotation_factor': 0.002,  # Specifies the rotation range applied to the data (in radians).
    'height_factor': (-0.18, 0.18),  # Specifies the range of random vertical shifts applied to the data.
    'width_factor': (-0.18, 0.18),  # Specifies the range of random horizontal shifts applied to the data.
    'contrast_factor': 0.5,  # Specifies the range of random contrast adjustments applied to the data.
}

# Combine Experiment, Model, Labels, and Augmentation Configurations
config = {
    'Experiment': experiment_config,
    'Model': model_config,
    'Labels': {'MAPPINGS': label_mappings},
    'Augmentation': augmentation_config
}

# Dataset Creation Configuration
csv_config = {
    'CSV': {
        'COLUMNS_TO_READ': ['ImageFile', 'Focus_Offset (V)', 'Stig_Offset_X (V)', 'Stig_Offset_Y (V)']
    },
    'Thresholds': {
        'FOCUS_LOW': 30,                              # Lower focus threshold
        'FOCUS_HIGH': 60,                             # Upper focus threshold
        
        'STIGX_LOW': 1,                               # Lower astigmatism threshold
        'STIGX_HIGH': 2,                              # Upper astigmatism threshold
        
        'STIGY_LOW': 1,                               # Lower astigmatism threshold
        'STIGY_HIGH': 2,                              # Upper astigmatism threshold
    },
    'Paths': {
        'OLD_BASE_PATH': "D:\\DOE\\",
        
        # On Simulation Computer
        # 'DATA_FILE': "combined_output.csv",
        # 'NEW_BASE_PATH': "Y:\\User\\Aaron-HX38\\DOE\\", 
        
        # On Laptop
        'DATA_FILE': "combined_output_cleaned.csv",
        'NEW_BASE_PATH': "C:\\Users\\aaron.woods\\OneDrive - Thermo Fisher Scientific\\Desktop\\Dec 24\\",
    },
    'SAMPLE_FRAC': 1.0,                                # Fraction of the data for quicker prototyping (1.0 means use all data)
}

# Update the main configuration dictionary with the dataset configuration
config.update(csv_config)

# Set random seed for reproducibility
np.random.seed(config['Experiment']['RANDOM_SEED'])
tf.random.set_seed(config['Experiment']['RANDOM_SEED'])

# %% [markdown]
# ## Data Loading

# %%
### Functions for Preparation of CSV

def read_csv(config: Dict):
    # Functionality to read the data
    data_file_path = os.path.join(config['Paths']['NEW_BASE_PATH'], config['Paths']['DATA_FILE'])
    if not os.path.exists(data_file_path):
        raise FileNotFoundError(f"Error: File does not exist - {data_file_path}")
    try:
        data = pd.read_csv(data_file_path, usecols=config['CSV']['COLUMNS_TO_READ'])
        print("---> Data read successfully.")
        sample_frac = config.get('SAMPLE_FRAC', 1.0)
        if 0 < sample_frac < 1.0:
            data = data.sample(frac=sample_frac).reset_index(drop=True)
            print(f"---> Data sampled: Using {sample_frac * 100}% of the available data.")
    except Exception as e:
        raise ValueError(f"Error: Could not read data - {e}") from e
    return data

def update_image_paths(df):
    old_base_path = config['Paths']['OLD_BASE_PATH']
    new_base_path = config['Paths']['NEW_BASE_PATH']
    df['ImageFile'] = df['ImageFile'].str.replace(old_base_path, new_base_path, regex=False)
    print("---> Image paths updated.")
    return df


def clean_csv(df: pd.DataFrame, save_cleaned: bool = False) -> pd.DataFrame:
    def is_valid_string(image_path) -> bool:
        return isinstance(image_path, str)
    
    def does_file_exist(image_path) -> bool:
        return os.path.exists(image_path)
    
    def can_image_be_read(image_path) -> bool:
        img = cv2.imread(image_path)
        return img is not None
    
    removal_reasons = defaultdict(list)
    total_rows = len(df)
    csv_file_path = os.path.join(config['Paths']['NEW_BASE_PATH'], config['Paths']['DATA_FILE'])
    print("Cleaning CSV file...")
    for index, row in enumerate(df.itertuples()):
        progress = (index + 1) / total_rows * 100
        print(f"\rProgress: {progress:.2f}%", end="")
        
        image_path = row.ImageFile
        reason = None
        
        if not is_valid_string(image_path):
            reason = "Invalid ImageFile value - not a string"
        elif not does_file_exist(image_path):
            reason = "File does not exist"
        elif not can_image_be_read(image_path):
            reason = "Image can't be read"
        
        if reason:
            removal_reasons[reason].append(index)
    
    invalid_rows = [index for indices in removal_reasons.values() for index in indices]
    df.drop(index=invalid_rows, inplace=True)
    df.reset_index(drop=True, inplace=True)
    
    print("\n\nSummary of row removals:")
    for reason, indices in removal_reasons.items():
        print(f"{len(indices)} rows removed due to: {reason}")
        print(f"Row indices: {indices}")
    
    if save_cleaned and csv_file_path:
        cleaned_csv_file_path = f"{os.path.splitext(csv_file_path)[0]}_cleaned.csv"
        df.to_csv(cleaned_csv_file_path, index=False)
        print(f"Cleaned CSV saved to: {cleaned_csv_file_path}")
    
    return df

# %%
### Generating labels

def generate_thresholds(label_key):
    low_key = f"{label_key.split('_')[0].upper()}_LOW"
    high_key = f"{label_key.split('_')[0].upper()}_HIGH"
    return config.get('Thresholds', {}).get(low_key, 0), config.get('Thresholds', {}).get(high_key, 0)

def generate_single_label(df_copy, label_key, offset_column, choices_dict):
    low_threshold, high_threshold = generate_thresholds(label_key)
    conditions = [
        (df_copy[offset_column].abs() <= low_threshold),
        (df_copy[offset_column].abs() > low_threshold) & (df_copy[offset_column].abs() <= high_threshold),
        (df_copy[offset_column].abs() > high_threshold)
    ]
    choices = list(choices_dict.keys())
    df_copy[label_key] = np.select(conditions, choices, default='Unknown')
    le = LabelEncoder()
    df_copy[label_key] = le.fit_transform(df_copy[label_key])
    return le

def generate_labels(df: pd.DataFrame):
    print("---> Generating labels for Focus, StigX, and StigY...")
    labels_config = config.get('Labels', {}).get('MAPPINGS', {})
    offset_column_mapping = {'Focus_Label': 'Focus_Offset (V)', 'StigX_Label': 'Stig_Offset_X (V)', 'StigY_Label': 'Stig_Offset_Y (V)'}

    df_copy = df.copy()
    label_encoders = {}

    for label_key, choices_dict in labels_config.items():
        offset_column = offset_column_mapping.get(label_key)
        if not offset_column:
            print(f"Warning: No offset column mapping found for '{label_key}'. Skipping label generation.")
            continue
        if offset_column not in df.columns:
            print(f"Warning: Column '{offset_column}' not found in DataFrame. Skipping label generation for '{label_key}'.")
            continue
        label_encoders[label_key] = generate_single_label(df_copy, label_key, offset_column, choices_dict)
        print(f"---> Labels generated for {label_key}")

    if config.get('Experiment', {}).get('PROBLEM_TYPE') == 'Multi-Output':
        df_copy['Multi_Output_Labels'] = df_copy.apply(lambda row: [row[key] for key in labels_config.keys()], axis=1)
        print("---> Multi-Output Labels generated.")
        
    return df_copy, label_encoders

# %%
### Shuffling and Splitting the Data

def shuffle_and_reset_index(data):
    print("---> Shuffling and resetting index...")
    shuffled_df = data.sample(frac=1, random_state=config['Experiment']['RANDOM_SEED']).reset_index(drop=True)
    print("---> Data shuffled and index reset.")
    return shuffled_df

def prepare_datasets(df: pd.DataFrame):
    """Prepare training, validation, and test datasets."""
    # Check if DataFrame is empty
    if df is None or df.empty:
        print("Warning: DataFrame is empty. Cannot proceed with data preparation.")
        return {'train': None, 'valid': None, 'test': None}
    # Split Data
    try:
        train_df, temp_df = train_test_split(df, test_size=1 - config['Model']['TRAIN_SIZE'], random_state=config['Experiment']['RANDOM_SEED'])
        val_df, test_df = train_test_split(temp_df, test_size=1 - config['Model']['VAL_SIZE'], random_state=config['Experiment']['RANDOM_SEED'])
    except ValueError:
        print("Not enough data to split into training, validation, and test sets.")
        return {'train': None, 'valid': None, 'test': None}
    print("---> Data split into training, validation, and test sets.")
    return {'train': train_df, 'valid': val_df, 'test': test_df}

# %%
### Computting Class Weights

def compute_class_weights_for_label(split: str, df: pd.DataFrame, label: str, label_encoders: Dict[str, LabelEncoder], all_records: List[Dict], is_multi_label: bool = False) -> None:
    y_data = df[label].values if is_multi_label else df[label]
    unique_labels = np.unique(y_data)
    class_weights = compute_class_weight('balanced', classes=unique_labels, y=y_data)
    class_weights_dict = dict(zip(unique_labels, class_weights))
    
    for cls, weight in class_weights_dict.items():
        cnt = Counter(y_data)[cls]
        original_class = label_encoders[label].inverse_transform([cls])[0]
        all_records.append({
            'split': split,
            'label': label,
            'class': original_class,
            'Count': cnt,
            'Weight': weight
        })

def compute_and_store_class_weights(datasets: Dict[str, pd.DataFrame], label_encoders: Dict[str, LabelEncoder]) -> pd.DataFrame:
    problem_type = config.get('Experiment', {}).get('PROBLEM_TYPE', 'Binary')
    all_records = []
    
    for split, df in datasets.items():
        if df is None:
            continue
        for label in config['Labels']['MAPPINGS']:
            compute_class_weights_for_label(
                split, df, label, label_encoders, all_records, 
                is_multi_label=(problem_type == 'Multi-label')
            )
                
    df_class_weights = pd.DataFrame.from_records(all_records)
    df_class_weights.set_index(['split', 'label', 'class'], inplace=True)
    return df_class_weights

# %%
### Creating Tensorflow Datasets

def create_tf_datasets_from_dfs(dfs: Dict[str, pd.DataFrame], include_offset: bool = False) -> Dict[str, Dict[str, Any]]:
    """
    Create TensorFlow datasets from DataFrames for training, validation, and testing.
    """
    problem_type = config.get('Experiment', {}).get('PROBLEM_TYPE')
    batch_size = config.get('Model', {}).get('BATCH_SIZE', 32)
    AUTOTUNE = tf.data.AUTOTUNE
    
    preprocessing_layers = create_preprocessing_layers()
    augmentation_layers = create_augmentation_layers()
    
    def load_and_preprocess_image(file_path: tf.Tensor, label: tf.Tensor, offset: Optional[tf.Tensor], augment: bool = False) -> Tuple:
        file_path_str = file_path.numpy().decode('utf-8')
        image = read_and_convert_image(file_path_str)
        image = preprocessing_layers(image)
        if augment:
            image = augmentation_layers(image)
            image = tf.clip_by_value(image, 0.0, 1.0)
        label = tf.cast(label, tf.int32)
        offset = tf.cast(offset, tf.float32) if offset is not None else None
        return (image, label, offset) if include_offset else (image, label)

    def prepare_dataset(file_paths, labels, offsets, augment):
        ds = tf.data.Dataset.from_tensor_slices((file_paths, labels, offsets))
        ds = ds.map(lambda file_path, label, offset: tf.py_function(
            func=load_and_preprocess_image,
            inp=[file_path, label, offset if offset is not None else tf.constant([], dtype=tf.float32), augment],
            Tout=[tf.float32, label.dtype, tf.float32] if include_offset else [tf.float32, label.dtype]
        ))
        return ds.batch(batch_size).prefetch(buffer_size=AUTOTUNE) # If I have a lot of memory, I can use cache() here.

    tf_datasets = {'train': {}, 'valid': {}, 'test': {}}
    offset_column_mapping = {
        'Focus_Label': 'Focus_Offset (V)',
        'StigX_Label': 'Stig_Offset_X (V)',
        'StigY_Label': 'Stig_Offset_Y (V)'
    }

    for split, df in dfs.items():
        augment_data = (split == 'train')
        if problem_type in ['Multi-Class', 'Binary']:
            for label in ['Focus_Label', 'StigX_Label', 'StigY_Label']:
                offset_column = offset_column_mapping.get(label)
                offsets = df[offset_column].values if include_offset else None
                tf_datasets[split][label] = prepare_dataset(df['ImageFile'].values, df[label].values, offsets, augment_data)
        
        elif problem_type == 'Multi-Output':
            labels = df[['Focus_Label', 'StigX_Label', 'StigY_Label']].values
            offsets = df[['Focus_Offset (V)', 'Stig_Offset_X (V)', 'Stig_Offset_Y (V)']].values if include_offset else None
            tf_datasets[split]['Multi_Output'] = prepare_dataset(df['ImageFile'].values, labels, offsets, augment_data)
        
        else:
            print("Unknown problem type specified in config. Please check.")

    return tf_datasets

### Image Augmentation and Preprocessing

def create_preprocessing_layers() -> keras.Sequential:
    """Create preprocessing layers for resizing and rescaling images."""
    img_size = config['Model']['IMG_SIZE']
    return keras.Sequential([
        layers.Resizing(img_size, img_size),
        layers.Rescaling(1./255)
    ])

def create_augmentation_layers() -> keras.Sequential:
    """Create data augmentation layers."""
    aug_config = config['Augmentation']
    try:
        return keras.Sequential([
            layers.RandomFlip("horizontal"),
            layers.RandomFlip("vertical"),
            layers.RandomRotation(aug_config['rotation_factor']),
            layers.RandomTranslation(
                height_factor=aug_config['height_factor'],
                width_factor=aug_config['width_factor'],
                fill_mode="reflect"
            ),
            layers.RandomContrast(aug_config['contrast_factor']),
        ])
        
    except Exception as e:
        print(f"An error occurred while creating augmentation layers: {e}")
        return None

def read_and_convert_image(file_path: str) -> tf.Tensor:
    """Read an image from a file and convert it to a 3-channel tensor."""
    image = cv2.imread(file_path, cv2.IMREAD_GRAYSCALE)
    if image is None:
        print("Failed to read the image.")
        return None
    image = tf.convert_to_tensor(image, dtype=tf.float32)
    image = tf.expand_dims(image, axis=-1)
    return tf.image.grayscale_to_rgb(image)

# %%
### Resample Datasets to deal with Imbalances (Optional)

def validate_inputs(datasets: Dict[str, pd.DataFrame], resample_label: str, resample_strategy: str) -> None:
    if not isinstance(datasets, dict):
        raise ValueError("Input datasets should be a dictionary.")
    if resample_strategy not in ["upsample", "downsample", "combined"]:
        raise ValueError("Invalid resample_strategy. Choose from 'upsample', 'downsample', or 'combined'.")
    for key, df in datasets.items():
        if resample_label not in df.columns:
            raise ValueError(f"'{resample_label}' is not a valid column in the {key} dataset.")

def target_count_for_strategy(label_counts: pd.Series, strategy: str) -> int:
    if strategy == "downsample":
        return label_counts.min()
    elif strategy == "upsample":
        return label_counts.max()
    return int(label_counts.median())

def iterative_resampling(df: pd.DataFrame, resample_strategy: str, resample_label: str) -> pd.DataFrame:
    label_counts = df[resample_label].apply(tuple).value_counts()
    target_count = target_count_for_strategy(label_counts, resample_strategy)
    subsets = [
        resample(
            df[df[resample_label].apply(tuple) == unique_label],
            replace=(label_counts[unique_label] < target_count),
            n_samples=target_count
        )
        for unique_label in label_counts.keys()
    ]
    return pd.concat(subsets).sample(frac=1).reset_index(drop=True)

def resample_datasets(datasets: Dict[str, pd.DataFrame], resample_label='Multi_Output_Labels', resample_strategy="downsample") -> Dict[str, pd.DataFrame]:
    validate_inputs(datasets, resample_label, resample_strategy)
    
    int32_columns = [col for col, dtype in datasets.get('train', pd.DataFrame()).dtypes.items() if dtype == 'int32']
    
    def process_dataset(key: str, df: pd.DataFrame) -> pd.DataFrame:
        if key != 'train':
            return df
        resampled_data = iterative_resampling(df, resample_strategy, resample_label)
        for col in int32_columns:
            resampled_data[col] = resampled_data[col].astype('int32')
        return resampled_data
    
    return {key: process_dataset(key, df) for key, df in datasets.items()}

# %% [markdown]
# ### Data Loading Main Function

# %%
# 🚀 Enhanced Data Loading and Preprocessing Workflow

print("\n🔍 [START] Preprocessing CSV Data...")
data = read_csv(config)
data = update_image_paths(data)
# Uncomment the below line if you want to clean the CSV
# data = clean_csv(data, save_cleaned=False)
data, label_encoders = generate_labels(data)
data = shuffle_and_reset_index(data)

print("\n📊 [LOAD] Preparing TensorFlow Datasets...")
datasets = prepare_datasets(data)
print("  🏋️‍♂️ Computing class weights for original datasets...")
df_class_weights = compute_and_store_class_weights(datasets, label_encoders)

print("\n  🔁 Resampling datasets... (Optional)")
resampled_datasets = resample_datasets(datasets, resample_label='Multi_Output_Labels', resample_strategy="upsample")
print("  🏋️‍♀️ Computing class weights for resampled datasets...")
rdf_class_weights = compute_and_store_class_weights(resampled_datasets, label_encoders)

print("\n🔧 [BUILD] Creating TensorFlow datasets from DataFrames...")
datasets = create_tf_datasets_from_dfs(datasets, include_offset=True)
resampled_datasets = create_tf_datasets_from_dfs(resampled_datasets, include_offset=True)

print("\n✅ [DONE] Preprocessing Complete!\n")
# Out:
# 🔍 [START] Preprocessing CSV Data...
# ---> Data read successfully.
# ---> Image paths updated.
# ---> Generating labels for Focus, StigX, and StigY...
# ---> Labels generated for Focus_Label
# ---> Labels generated for StigX_Label
# ---> Labels generated for StigY_Label
# ---> Multi-Output Labels generated.
# ---> Shuffling and resetting index...
# ---> Data shuffled and index reset.
#
# 📊 [LOAD] Preparing TensorFlow Datasets...
# ---> Data split into training, validation, and test sets.
#   🏋️‍♂️ Computing class weights for original datasets...
#
#   🔁 Resampling datasets... (Optional)
#   🏋️‍♀️ Computing class weights for resampled datasets...
#
# 🔧 [BUILD] Creating TensorFlow datasets from DataFrames...
#
# ✅ [DONE] Preprocessing Complete!

# %% [markdown]
# ## Visualizing the Data

# %%
### Class Distributions
import matplotlib.pyplot as plt

def add_annotations(ax, bars, sub_df):
    """
    Adds annotations to the bars.
    """
    for bar, (_, row) in zip(bars, sub_df.iterrows()):
        x = bar.get_x() + bar.get_width() / 2.0
        y = bar.get_height() + 0.5  # Shift annotation slightly above the bar for clarity
        ax.annotate(f"C: {int(row['Count'])}\nW: {row['Weight']:.2f}", 
                    (x, y), 
                    ha='center', 
                    va='bottom', 
                    fontsize=8)

def plot_single_split(ax, df, split):
    """
    Plots the class distribution for a single split (train/test/valid).
    """
    filtered_df = df.loc[split]
    x_ticks = []
    x_tick_locs = []
    current_x = 0  # Keep track of the current x-location for ticks
    
    labels = filtered_df.index.get_level_values('label').unique()
    for label in labels:
        sub_df = filtered_df.loc[label]
        bars = ax.bar(sub_df.index, sub_df['Count'], label=f"{label}")
        add_annotations(ax, bars, sub_df)
        
        x_ticks.extend([f"{label}_{cls}" for cls in sub_df.index])
        x_tick_locs.extend([current_x + i for i in range(len(sub_df.index))])
        current_x += len(sub_df.index)  # Update the x-location for the next set of bars
    
    ax.legend()
    ax.set_xticks(x_tick_locs)  # Set tick locations
    ax.set_xticklabels(x_ticks, rotation=90, fontsize=8)  # Set tick labels
    ax.set_title(f"{split.capitalize()} Data")
    ax.set_ylabel("Count")  # Indicate that the bars represent counts


def plot_dataset_info(df):
    """
    Plots the class distribution for train, valid, and test splits.
    """
    splits = ['train', 'valid', 'test']
    fig, axs = plt.subplots(1, len(splits), figsize=(20, 8))
    
    for i, split in enumerate(splits):
        plot_single_split(axs[i], df, split)
        
    plt.tight_layout()
    plt.show()

# Example usage
plot_dataset_info(df_class_weights)
plot_dataset_info(rdf_class_weights)

# %%
### Plot Images from Dataset

import textwrap
import matplotlib.pyplot as plt

def plot_single_image(ax, image, label_names, offsets):
    """
    Plots a single image with associated labels and offsets.
    """
    ax.imshow(image)
    title_text = ", ".join(f"{name} ({offset})" for name, offset in zip(label_names, offsets))
    ax.set_title("\n".join(textwrap.wrap(title_text, 30)))  # Wrap text to fit into the subplot
    ax.axis("off")

def extract_and_transform_labels(labels, label_keys, label_encoders):
    """
    Extracts and transforms labels using label encoders.
    """
    label_names = []
    for label_value, label_key in zip(labels, label_keys):
        label_encoder = label_encoders.get(label_key, None)
        if label_encoder:
            label_names.append(label_encoder.inverse_transform([label_value])[0])
        else:
            label_names.append(str(label_value))
    return label_names

def plot_images_from_dataset(label_encoders, config, datasets):
    """
    Plots images, labels, and offsets (if available) from the provided datasets.
    
    Args:
        label_encoders (dict): Dictionary of label encoders for each label key.
        config (dict): Configuration dictionary containing problem type and other parameters.
        datasets (dict): Dictionary of datasets, containing training data for each label key.
    """
    label_keys = ['Focus_Label', 'StigX_Label', 'StigY_Label']
    problem_type = config['Experiment']['PROBLEM_TYPE']

    plt.rcParams.update({'font.size': 8})
    fig, axes = plt.subplots(3, 3, figsize=(12, 12))

    # Helper function to get relevant dataset based on problem type
    def get_relevant_dataset(problem_type, label_key):
        return datasets['train'][label_key if problem_type in ['Multi-Class', 'Binary'] else 'Multi_Output']

    # If problem type is not Multi-Output, re-use the same logic for both Binary and Multi-Class
    relevant_datasets = [label_keys] if problem_type != "Multi-Output" else ["Multi_Output"]

    for label_key in relevant_datasets:
        label_encoder = label_encoders.get(label_key, None)
        fig.suptitle(f"Images for {label_key}")

        for data in get_relevant_dataset(problem_type, label_key).take(1):
            images, labels = data[:2]
            offsets = data[2] if len(data) > 2 else None

            for i in range(min(len(images), 9)):
                ax = axes[i // 3, i % 3]
                current_labels = labels[i].numpy() if problem_type == "Multi-Output" else [labels[i].numpy()]
                current_offsets = offsets[i].numpy() if offsets is not None else ["N/A"] * len(label_keys)
                # Round offsets to 2 decimal places
                current_offsets = [f"{offset:.2f}" for offset in current_offsets]

                label_names = extract_and_transform_labels(current_labels, label_keys, label_encoders)
                plot_single_image(ax, images[i].numpy(), label_names, current_offsets)

        plt.tight_layout(rect=[0, 0.03, 1, 0.95])
        plt.show()

    if problem_type not in ["Multi-Class", "Binary", "Multi-Output"]:
        print("Unknown problem type specified in config. Please check.")

# Example usage (assuming label_encoders, config, and datasets are defined elsewhere)
plot_images_from_dataset(label_encoders, config, datasets)

# %%
### Removing Offset Labels from the Dataset and Splitting (Doesn't Incorporate Changes from SIMv9)

def inspect_dataset_content(dataset, name, num_batches=3):
    """
    Inspect the content of the dataset to determine the nature of the tensors.
    """
    print(f"Inspecting first few records of {name} dataset...")
    
    for i, record in enumerate(dataset.take(num_batches)):
        summary = {k: (v.shape, v.dtype) for k, v in record.items()}
        print(f"{name} record {i + 1}: {summary}")
        
    print(f"Inspecting unique values in {name} dataset...")
    
    for i, batch in enumerate(dataset.take(num_batches)):
        print(f"Batch {i + 1} content:")
        
        for tensor_name, tensor in batch.items():
            unique_values = tf.unique(tf.reshape(tensor, [-1])).y.numpy()
            print(f"Unique values in {tensor_name}: {unique_values}")
        
        print("------")

def select_tensors(*tensors):
    return tensors[0], tensors[1]  # Return only the image and label tensors
    # return tensors[0], tensors[1], tensors[2]  # Return image, label, and offset tensors

def get_dataset(raw_datasets, dataset_type):
    """Retrieve specific dataset type (train, valid, test) from the raw datasets dictionary."""
    return raw_datasets.get(dataset_type, {}).get('Multi_Output')

def prepare_and_inspect_dataset(dataset, dataset_name):
    """Apply transformations and inspect a dataset."""
    if dataset is None:
        print(f"{dataset_name} dataset is None. Skipping.")
        return None

    dataset = dataset.map(select_tensors)
    # inspect_dataset_content(dataset, dataset_name)
    
    return dataset

def prepare_datasets_for_training(raw_datasets):
    """
    Prepare and inspect datasets for training.

    Returns:
    - A tuple containing prepared TensorFlow datasets for training, validation, and testing.
    """
    if raw_datasets is None:
        print("Datasets dictionary is None. Exiting.")
        return None, None, None

    train_dataset = prepare_and_inspect_dataset(get_dataset(raw_datasets, 'train'), 'Train')
    valid_dataset = prepare_and_inspect_dataset(get_dataset(raw_datasets, 'valid'), 'Validation')
    test_dataset = prepare_and_inspect_dataset(get_dataset(raw_datasets, 'test'), 'Test')
    
    return train_dataset, valid_dataset, test_dataset

# Uncomment this line to run the function with your datasets
train_dataset, valid_dataset, test_dataset = prepare_datasets_for_training(datasets)
# train_dataset, valid_dataset, test_dataset = prepare_datasets_for_training(resampled_datasets)

# %% [markdown]
# ## Creating Classification Models

# %%
### Model Building (Define the Model)

def add_multi_output_heads(base_layer, num_classes: int, output_names: List[str]) -> List[keras.layers.Layer]:
    """Creates multiple output heads for a given base layer."""
    outputs = []
    for i in range(num_classes):
        x = layers.Dense(128, activation="relu")(base_layer)
        x = layers.Dropout(0.5)(x)
        x = layers.Dense(3, activation="softmax", name=output_names[i])(x)  # Naming each output layer
        outputs.append(x)
    return outputs

def determine_activation_and_units(num_classes: int) -> Tuple[List[str], List[int]]:
    """Determines the activation functions and units based on the number of classes and config settings."""
    problem_type = config.get('Experiment').get('PROBLEM_TYPE')
    if problem_type in ['Multi-Label', 'Binary', 'Multi-Class', 'Multi-Output']:
        return {
            'Multi-Label': (["sigmoid"] * num_classes, [1] * num_classes),
            'Binary': (["sigmoid"], [1]),
            'Multi-Class': (["softmax"], [num_classes]),
            'Multi-Output': (["softmax"] * num_classes, [3] * num_classes)  # Assuming each output has 3 classes
        }[problem_type]
    raise ValueError(f"Invalid problem_type: {problem_type}")

def create_transfer_model(base_model, input_shape: Tuple[int, int, int], num_classes: int, hidden_units: List[int], dropout_rate: float, regularizer_rate: float, output_names: List[str] = None) -> keras.Model:
    """Creates a transfer learning model based on the provided base model."""
    base_model.trainable = False
    model = keras.Sequential([
        base_model,
        layers.GlobalAveragePooling2D()
    ])
    for units in hidden_units:
        model.add(layers.Dense(units, kernel_regularizer=keras.regularizers.l2(regularizer_rate), bias_regularizer=keras.regularizers.l2(regularizer_rate)))
        model.add(layers.LeakyReLU())
        model.add(layers.Dropout(dropout_rate))
    
    activations, units_list = determine_activation_and_units(num_classes)
    if len(activations) == 1:
        model.add(layers.Dense(units_list[0], activation=activations[0]))
        return model
    
    # output_names = output_names or list(config['Labels']['MAPPINGS'].keys())
    output_names = list(config['Labels']['MAPPINGS'].keys())

    outputs = add_multi_output_heads(model.layers[-1].output, num_classes, output_names)
    return keras.Model(inputs=model.input, outputs=outputs)

def create_specific_transfer_model(base_model_class, input_shape: Tuple[int, int, int], num_classes: int) -> keras.Model:
    """Helper function to create specific transfer models."""
    base_model = base_model_class(input_shape=input_shape, include_top=False, weights='imagenet')
    return create_transfer_model(base_model, input_shape, num_classes, [128, 64], 0.5, 0.001, output_names=config['Labels']['MAPPINGS'].keys())

def create_mobilenetv2_transfer_model(input_shape: Tuple[int, int, int], num_classes: int) -> keras.Model:
    return create_specific_transfer_model(tf.keras.applications.MobileNetV2, input_shape, num_classes)

def create_inceptionv3_transfer_model(input_shape: Tuple[int, int, int], num_classes: int) -> keras.Model:
    return create_specific_transfer_model(tf.keras.applications.InceptionV3, input_shape, num_classes)

def create_resnet50_transfer_model(input_shape: Tuple[int, int, int], num_classes: int) -> keras.Model:
    return create_specific_transfer_model(tf.keras.applications.ResNet50, input_shape, num_classes)

# Define the function to create a basic CNN model
def create_basic_cnn_model(input_shape, num_classes):
    conv2d_filter_size = (3, 3)
    conv2d_activation = 'relu'
    dense_activation = 'relu'
    num_conv_blocks = 3

    inputs = keras.Input(shape=input_shape)

    x = inputs

    for _ in range(num_conv_blocks):
        x = layers.Conv2D(32 * (2**_), conv2d_filter_size, activation=conv2d_activation, padding='same')(x)
        x = layers.BatchNormalization()(x)
        x = layers.MaxPooling2D((2, 2))(x)

    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(128, activation=dense_activation)(x)

    activations, units_list = determine_activation_and_units(num_classes)
    if len(activations) == 1:
        # Single output
        x = layers.Dense(units_list[0], activation=activations[0])(x)
        return keras.Model(inputs=inputs, outputs=x)
    else:
        # Multiple outputs
        outputs = add_multi_output_heads(x, num_classes, output_names=list(config['Labels']['MAPPINGS'].keys()))
        return keras.Model(inputs=inputs, outputs=outputs)

# Define the function to create a small version of the Xception network
def create_small_xception_model(input_shape, num_classes):
    # Input layer
    inputs = keras.Input(shape=input_shape)

    # Entry block: Initial Convolution and BatchNormalization
    x = layers.Rescaling(1.0 / 255)(inputs)
    x = layers.Conv2D(128, 3, strides=2, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    previous_block_activation = x  # Set aside residual for later use

    # Middle flow: Stacking Separable Convolution blocks
    for size in [256, 512, 728]:
        # ReLU activation
        x = layers.Activation("relu")(x)
        # Separable Convolution
        x = layers.SeparableConv2D(size, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        # ReLU activation
        x = layers.Activation("relu")(x)
        # Separable Convolution
        x = layers.SeparableConv2D(size, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        # Max Pooling
        x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

        # Project residual from previous block and add it to the current block
        residual = layers.Conv2D(size, 1, strides=2, padding="same")(previous_block_activation)
        x = layers.add([x, residual])  # Add back residual
        previous_block_activation = x  # Set aside next residual

    # Exit flow: Final Separable Convolution, BatchNormalization, and Global Average Pooling
    x = layers.SeparableConv2D(1024, 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.GlobalAveragePooling2D()(x)

    activations, units_list = determine_activation_and_units(num_classes)
    if len(activations) == 1:
        # Single output
        x = layers.Dense(units_list[0], activation=activations[0])(x)
        return keras.Model(inputs=inputs, outputs=x)
    else:
        # Multiple outputs
        outputs = add_multi_output_heads(x, num_classes, output_names=list(config['Labels']['MAPPINGS'].keys()))
        return keras.Model(inputs=inputs, outputs=outputs)

# Model Selection function to select which model to use
def select_model(model_name: str, input_shape: Tuple[int, int, int], num_classes: int) -> keras.Model:
    """Selects a model to use based on the given model name."""
    model_map = {
        "mobilenetv2": create_mobilenetv2_transfer_model,
        "inceptionv3": create_inceptionv3_transfer_model,
        "resnet50": create_resnet50_transfer_model,
        "small_xception": create_small_xception_model,
        "basic_cnn": create_basic_cnn_model
    }
    if model_name not in model_map:
        raise ValueError("Invalid model name")

    return model_map[model_name](input_shape, num_classes)

# %%
### Model Initialization (Compile the Model)

# # Constants & Configurations
LOSS_CONFIG = {
    'Binary': 'binary_crossentropy',
    'Multi-Class': 'categorical_crossentropy',
    'Multi-Output': ['categorical_crossentropy'] * len(config['Labels']['MAPPINGS']),
    'Multi-Label': 'binary_crossentropy'
}

RECOMMENDED_METRICS = {
    'Binary': ['accuracy', 'binary_crossentropy', 'mean_squared_error'],
    'Multi-Class': ['categorical_accuracy', 'categorical_crossentropy', 'mean_squared_error'],
    'Multi-Output': ['categorical_accuracy'] * len(config['Labels']['MAPPINGS']) + 
                    ['categorical_crossentropy'] * len(config['Labels']['MAPPINGS']) + 
                    ['mean_squared_error'] * len(config['Labels']['MAPPINGS']),
    'Multi-Label': ['binary_accuracy', 'binary_crossentropy', 'mean_squared_error']
}

# Helper Functions
def get_accuracy_metric(problem_type: str) -> str:
    """Determine the accuracy metric based on the problem type."""
    return {'Binary': "accuracy", 'Multi-Label': "binary_accuracy"}.get(problem_type, "categorical_accuracy")

def create_directory(path: str):
    """Create a directory if it doesn't exist."""
    os.makedirs(path, exist_ok=True)

# Callback Setup Functions
def setup_common_callbacks() -> List[callbacks.Callback]:
    """Set up common callbacks."""
    return [
        callbacks.EarlyStopping(patience=config['Model']['EARLY_STOPPING_PATIENCE'], restore_best_weights=True),
        callbacks.ReduceLROnPlateau(patience=config['Model']['REDUCE_LR_PATIENCE'], min_lr=config['Model']['MIN_LR'])
    ]

def setup_specific_callbacks(model_name: str, model_dir: str, problem_type: str) -> List[callbacks.Callback]:
    """Set up model-specific callbacks."""
    datetime_str = datetime.now().strftime("%Y%m%d-%I%M%S%p")
    acc_metric = get_accuracy_metric(problem_type)
    checkpoint_path = os.path.join(model_dir, f"saved_model_{datetime_str}_epoch_{{epoch}}_val_loss_{{val_loss:.2f}}_{acc_metric}_{{{{val_{acc_metric}:.2f}}}}.h5")
    return [
        callbacks.ModelCheckpoint(checkpoint_path, save_best_only=True),
        callbacks.TensorBoard(log_dir=os.path.join(model_dir, "logs", datetime_str))
    ]

def compile_model(model_name: str, input_shape: tuple, num_classes: int, problem_type: str) -> tf.keras.Model:
    """Compile and return a model."""
    model = select_model(model_name, input_shape, num_classes)
    metrics_to_use = list(set(RECOMMENDED_METRICS.get(problem_type, ['accuracy'])))
    loss_to_use = LOSS_CONFIG.get(problem_type, 'categorical_crossentropy')
    model.compile(
        optimizer=tf.keras.optimizers.Adam(config['Model']['LEARNING_RATE']), 
        loss=loss_to_use, 
        metrics=metrics_to_use
    )
    # model.summary()
    
    return model

def compile_and_initialize_models() -> Dict[str, Dict[str, tf.keras.Model]]:
    """Main function to compile and initialize models."""
    input_shape = (config['Model']['IMG_SIZE'], config['Model']['IMG_SIZE'], 3)
    num_classes = 3
    problem_type = config['Experiment']['PROBLEM_TYPE']

    experiment_name = config['Experiment']['NAME']
    base_dir = f"./{experiment_name}"
    create_directory(base_dir)

    common_callbacks = setup_common_callbacks()
    label_names = config['Labels']['MAPPINGS'].keys() if problem_type in ['Multi-Class', 'Multi-Output'] else ['']

    compiled_models = {}
    for label_name in label_names:
        label_dir = os.path.join(base_dir, label_name)
        create_directory(label_dir)

        for model_name in ['mobilenetv2', 'inceptionv3', 'resnet50', 'small_xception', 'basic_cnn']:
            model_dir = os.path.join(label_dir, model_name)
            create_directory(model_dir)
            
            specific_callbacks = setup_specific_callbacks(model_name, model_dir, problem_type)
            all_callbacks = common_callbacks + specific_callbacks
            
            model = compile_model(model_name, input_shape, num_classes, problem_type)
            compiled_models[model_name] = {'model': model, 'callbacks': all_callbacks}
    
    return compiled_models

# Execution
compiled_models = compile_and_initialize_models()
print("Models compiled and initialized successfully.")
# Out:
# Models compiled and initialized successfully.

# %%
### Investigating Model Outputs


for label_category, encoder in label_encoders.items():
    print(f'Mapping for {label_category}:')
    for index, class_label in enumerate(encoder.classes_):
        print(f'{index}: {class_label}')
    print()  # print a blank line between categories



def analyze_model_outputs(compiled_models, train_dataset):
    model_output_details = []
    
    # Assuming train_dataset is an iterable that yields batches of data,
    # We'll take the first batch of images from the training dataset for analysis.
    for images, labels in train_dataset.take(1):
        image_batch = images.numpy()  # Convert tensors to numpy arrays if necessary

    # Order of label encoders corresponding to the outputs
    encoder_order = ['Focus_Label', 'StigX_Label', 'StigY_Label']
    
    for model_name, model_details in compiled_models.items():
        model = model_details['model']
        output = model.predict(image_batch)
        
        if not isinstance(output, list):
            output = [output]  # Ensure output is a list for consistency
        
        for i, output_to_check in enumerate(output):
            one_hot_encoded = all((np.sum(row) > 0.99 and np.sum(row) < 1.01) for row in output_to_check)
            suggested_loss = 'categorical_crossentropy' if one_hot_encoded else 'sparse_categorical_crossentropy'
            max_prob_class = np.argmax(output_to_check, axis=-1)
            
            # Get the label encoder for the current output
            encoder_key = encoder_order[i] if i < len(encoder_order) else None
            label_encoder = label_encoders[encoder_key] if encoder_key else None
            
            # Decode the sample output
            sample_output = output_to_check[0] if len(output_to_check) > 0 else "No Output"
            sample_output_decoded = label_encoder.inverse_transform([np.argmax(sample_output)])[0] if label_encoder else "No Decoder"
            
            model_output_details.append({
                "Model Name": model_name,
                # Include Output Layer Name 
                "Output Layer Name": model.output_names[i],
                "Output": f'Output {i+1}',
                "Input Shape": model.input_shape,
                "Output Shape": output_to_check.shape,
                "Output Type": type(output).__name__,
                "Is One-Hot Encoded": one_hot_encoded,
                "Suggested Loss": suggested_loss,
                "Max Probability Class": max_prob_class,
                "Sample Output": sample_output,
                "Sample Output (Decoded)": sample_output_decoded
            })

    return pd.DataFrame(model_output_details).style.set_table_styles(
        [{"selector": "th", "props": [("font-size", "100%"), ("text-align", "center")]},
         {"selector": "td", "props": [("font-size", "100%"), ("text-align", "center")]}]
    )

# Assuming train_dataset is already defined and loaded with your training data
# Display the analysis
# analyze_model_outputs(compiled_models, train_dataset)

# %% [markdown]
# ## Training Classification Models

# %%
### Prepare class weights for multi-output problems (Optional)

def prepare_class_weights_for_multi_output(info: pd.DataFrame) -> Union[Dict[str, Dict[int, float]], None]:
    """
    Prepare class weights for multi-output problems for Keras and TensorFlow.
    
    Parameters:
    - info: DataFrame containing the class weights information
    - config: Configuration dictionary.
    
    Returns:
    - Dictionary mapping output layer names to their respective class weight dictionaries or None
    """
    if not config.get('USE_CLASS_WEIGHTS', True):
        print("Configuration says not to use class weights. Returning None.")
        return None

    class_weights = {}
    for label in info.index.get_level_values('label').unique():
        class_weights[label] = {}
        sub_df = info.loc[(slice(None), label), :]
        for idx, row in sub_df.iterrows():
            class_idx = label_encoders[label].transform([idx[2]])[0]  # Transforming class name to class index
            class_weights[label][class_idx] = row['Weight']
    return class_weights

# Additions to the config
config['USE_CLASS_WEIGHTS'] = True  # Decide whether to use class weights or not
prepared_class_weights = prepare_class_weights_for_multi_output(df_class_weights)
# print(prepared_class_weights)

# %% [markdown]
# ### Training Main Function

# %%
from tensorflow.keras import backend as K
import gc
import os
import pandas as pd

class ExcelMetricsSaver(Callback):
    def __init__(self, writer, sheet_name):
        super().__init__()
        self.writer = writer
        self.sheet_name = sheet_name

    def on_epoch_end(self, epoch, logs=None):
        self._save_metrics_to_excel(epoch, logs or {})

    def _save_metrics_to_excel(self, epoch, logs):
        logs['epoch'] = epoch + 1
        epoch_df = pd.DataFrame([logs])

        try:
            if epoch == 0:
                epoch_df.to_excel(self.writer, sheet_name=self.sheet_name, index=False)
            else:
                writer_sheets = self.writer.sheets
                start_row = writer_sheets[self.sheet_name].max_row
                epoch_df.to_excel(self.writer, sheet_name=self.sheet_name, startrow=start_row, header=False, index=False)
        except Exception as e:
            print(f"Error while saving metrics: {e}")


def handle_memory_after_training(model):
    K.clear_session()
    del model
    gc.collect()


def train_and_save_metrics(train_dataset, valid_dataset, test_dataset, compiled_models, prepared_class_weights):
    if not all([train_dataset, valid_dataset, test_dataset]):
        print("One or more datasets are None. Exiting.")
        return

    excel_filename = f"{config['Experiment']['NAME']}.xlsx"
    excel_path = os.path.join("./", excel_filename)

    with pd.ExcelWriter(excel_path, engine='openpyxl') as writer:
        pd.DataFrame().to_excel(writer, sheet_name="InitializationSheet")

        for model_name, model_info in compiled_models.items():
            if not _process_single_model(writer, model_name, model_info, train_dataset, valid_dataset, prepared_class_weights):
                continue
            _autosave_excel(writer, excel_path)

        print(f"\nSaved all metrics to {excel_path}")


def _process_single_model(writer, model_name, model_info, train_dataset, valid_dataset, prepared_class_weights):
    model = model_info.get('model')
    callbacks = model_info.get('callbacks')

    if model is None or callbacks is None:
        print(f"Model or callbacks for {model_name} are None. Skipping.")
        return False

    print(f"Training {model_name} for multi-output...")

    excel_saver = ExcelMetricsSaver(writer, sheet_name=model_name)
    callbacks.append(excel_saver)

    model_output_names = [layer.name for layer in model.layers if 'output' in layer.name]
    current_class_weights = {name: prepared_class_weights[name] for name in model_output_names}

    model.fit(
        train_dataset,
        validation_data=valid_dataset,
        epochs=config['Model']['EPOCHS'],
        callbacks=callbacks,
        class_weight=current_class_weights
    )

    handle_memory_after_training(model)

    print(f"\nTraining for {model_name} completed.")
    return True


def _autosave_excel(writer, excel_path):
    try:
        temp_excel_path = excel_path.replace('.xlsx', '_temp.xlsx')
        
        # Save the Excel file
        writer.path = temp_excel_path  # Set the save path to the temporary path
        writer.close()  # Close (and save) the Excel file
        
        # Backup the original Excel file if it exists
        if os.path.exists(excel_path):
            backup_path = excel_path.replace('.xlsx', '_backup.xlsx')
            os.replace(excel_path, backup_path)
        
        # Replace the temporary Excel file with the original name
        os.replace(temp_excel_path, excel_path)
    except Exception as e:
        print(f"An error occurred: {e}. Continuing...")



# Assuming you've already defined and initialized all your datasets and configs
train_and_save_metrics(train_dataset, valid_dataset, test_dataset, compiled_models, prepared_class_weights)
# Out:
# Training mobilenetv2 for multi-output...
# Epoch 1/100
# 511/511 [==============================] - 176s 339ms/step - loss: 9.2531 - Focus_Label_loss: 2.9877 - StigX_Label_loss: 2.9921 - StigY_Label_loss: 3.0090 - Focus_Label_categorical_accuracy: 0.5455 - Focus_Label_mean_squared_error: 0.6134 - Focus_Label_categorical_crossentropy: 2.9877 - StigX_Label_categorical_accuracy: 0.5280 - StigX_Label_mean_squared_error: 0.6153 - StigX_Label_categorical_crossentropy: 2.9921 - StigY_Label_categorical_accuracy: 0.5306 - StigY_Label_mean_squared_error: 0.6168 - StigY_Label_categorical_crossentropy: 3.0090 - val_loss: 8.9395 - val_Focus_Label_loss: 2.9004 - val_StigX_Label_loss: 2.9037 - val_StigY_Label_loss: 2.9075 - val_Focus_Label_categorical_accuracy: 0.8306 - val_Focus_Label_mean_squared_error: 0.6359 - val_Focus_Label_categorical_crossentropy: 2.9004 - val_StigX_Label_categorical_accuracy: 0.7679 - val_StigX_Label_mean_squared_error: 0.6371 - val_StigX_Label_categorical_crossentropy: 2.9037 - val_StigY_Label_categorical_accuracy: 0.8452 - val_StigY_Label_mean_squared_error: 0.6384 - val_StigY_Label_categorical_crossentropy: 2.9075 - lr: 0.0010 - epoch: 1.0000
# Epoch 2/100
# 511/511 [==============================] - 175s 343ms/step - loss: 8.9132 - Focus_Label_loss: 2.9073 - StigX_Label_loss: 2.9026 - StigY_Label_loss: 2.9018 - Focus_Label_categorical_accuracy: 0.7071 - Focus_Label_mean_squared_error: 0.6053 - Focus_Label_categorical_crossentropy: 2.9073 - StigX_Label_categorical_accuracy: 0.7141 - StigX_Label_mean_squared_error: 0.6043 - StigX_Label_categorical_crossentropy: 2.9026 - StigY_Label_categorical_accuracy: 0.6977 - StigY_Label_mean_squared_error: 0.6039 - StigY_Label_categorical_crossentropy: 2.9018 - val_loss: 8.8819 - val_Focus_Label_loss: 2.9004 - val_StigX_Label_loss: 2.9021 - val_StigY_Label_loss: 2.9011 - val_Focus_Label_categorical_accuracy: 0.8452 - val_Focus_Label_mean_squared_error: 0.6331 - val_Focus_Label_categorical_crossentropy: 2.9004 - val_StigX_Label_categorical_accuracy: 0.8462 - val_StigX_Label_mean_squared_error: 0.6330 - val_StigX_Label_categorical_crossentropy: 2.9021 - val_StigY_Label_categorical_accuracy: 0.8492 - val_StigY_Label_mean_squared_error: 0.6340 - val_StigY_Label_categorical_crossentropy: 2.9011 - lr: 0.0010 - epoch: 2.0000
# Epoch 3/100
# 511/511 [==============================] - 177s 347ms/step - loss: 8.8471 - Focus_Label_loss: 2.8937 - StigX_Label_loss: 2.8948 - StigY_Label_loss: 2.8953 - Focus_Label_categorical_accuracy: 0.7718 - Focus_Label_mean_squared_error: 0.6022 - Focus_Label_categorical_crossentropy: 2.8937 - StigX_Label_categorical_accuracy: 0.7690 - StigX_Label_mean_squared_error: 0.6025 - StigX_Label_categorical_crossentropy: 2.8948 - StigY_Label_categorical_accuracy: 0.7698 - StigY_Label_mean_squared_error: 0.6024 - StigY_Label_categorical_crossentropy: 2.8953 - val_loss: 8.8539 - val_Focus_Label_loss: 2.9015 - val_StigX_Label_loss: 2.9029 - val_StigY_Label_loss: 2.9008 - val_Focus_Label_categorical_accuracy: 0.8335 - val_Focus_Label_mean_squared_error: 0.6338 - val_Focus_Label_categorical_crossentropy: 2.9015 - val_StigX_Label_categorical_accuracy: 0.8472 - val_StigX_Label_mean_squared_error: 0.6341 - val_StigX_Label_categorical_crossentropy: 2.9029 - val_StigY_Label_categorical_accuracy: 0.7982 - val_StigY_Label_mean_squared_error: 0.6347 - val_StigY_Label_categorical_crossentropy: 2.9008 - lr: 0.0010 - epoch: 3.0000
# Epoch 4/100
# 511/511 [==============================] - 180s 353ms/step - loss: 8.8150 - Focus_Label_loss: 2.8928 - StigX_Label_loss: 2.8905 - StigY_Label_loss: 2.8949 - Focus_Label_categorical_accuracy: 0.7913 - Focus_Label_mean_squared_error: 0.6023 - Focus_Label_categorical_crossentropy: 2.8928 - StigX_Label_categorical_accuracy: 0.7977 - StigX_Label_mean_squared_error: 0.6013 - StigX_Label_categorical_crossentropy: 2.8905 - StigY_Label_categorical_accuracy: 0.7975 - StigY_Label_mean_squared_error: 0.6021 - StigY_Label_categorical_crossentropy: 2.8949 - val_loss: 8.9091 - val_Focus_Label_loss: 2.9266 - val_StigX_Label_loss: 2.9294 - val_StigY_Label_loss: 2.9266 - val_Focus_Label_categorical_accuracy: 0.7591 - val_Focus_Label_mean_squared_error: 0.6353 - val_Focus_Label_categorical_crossentropy: 2.9266 - val_StigX_Label_categorical_accuracy: 0.7796 - val_StigX_Label_mean_squared_error: 0.6345 - val_StigX_Label_categorical_crossentropy: 2.9294 - val_StigY_Label_categorical_accuracy: 0.8325 - val_StigY_Label_mean_squared_error: 0.6349 - val_StigY_Label_categorical_crossentropy: 2.9266 - lr: 0.0010 - epoch: 4.0000
# Epoch 5/100
# 511/511 [==============================] - 178s 349ms/step - loss: 8.7658 - Focus_Label_loss: 2.8847 - StigX_Label_loss: 2.8832 - StigY_Label_loss: 2.8820 - Focus_Label_categorical_accuracy: 0.8060 - Focus_Label_mean_squared_error: 0.6020 - Focus_Label_categorical_crossentropy: 2.8847 - StigX_Label_categorical_accuracy: 0.8031 - StigX_Label_mean_squared_error: 0.6016 - StigX_Label_categorical_crossentropy: 2.8832 - StigY_Label_categorical_accuracy: 0.8102 - StigY_Label_mean_squared_error: 0.6017 - StigY_Label_categorical_crossentropy: 2.8820 - val_loss: 8.8039 - val_Focus_Label_loss: 2.8999 - val_StigX_Label_loss: 2.8982 - val_StigY_Label_loss: 2.8991 - val_Focus_Label_categorical_accuracy: 0.8472 - val_Focus_Label_mean_squared_error: 0.6345 - val_Focus_Label_categorical_crossentropy: 2.8999 - val_StigX_Label_categorical_accuracy: 0.8472 - val_StigX_Label_mean_squared_error: 0.6340 - val_StigX_Label_categorical_crossentropy: 2.8982 - val_StigY_Label_categorical_accuracy: 0.8394 - val_StigY_Label_mean_squared_error: 0.6342 - val_StigY_Label_categorical_crossentropy: 2.8991 - lr: 0.0010 - epoch: 5.0000
# Epoch 6/100
# 511/511 [==============================] - 182s 356ms/step - loss: 8.7412 - Focus_Label_loss: 2.8822 - StigX_Label_loss: 2.8801 - StigY_Label_loss: 2.8803 - Focus_Label_categorical_accuracy: 0.8150 - Focus_Label_mean_squared_error: 0.6008 - Focus_Label_categorical_crossentropy: 2.8822 - StigX_Label_categorical_accuracy: 0.8171 - StigX_Label_mean_squared_error: 0.6000 - StigX_Label_categorical_crossentropy: 2.8801 - StigY_Label_categorical_accuracy: 0.8142 - StigY_Label_mean_squared_error: 0.6006 - StigY_Label_categorical_crossentropy: 2.8803 - val_loss: 8.7985 - val_Focus_Label_loss: 2.9014 - val_StigX_Label_loss: 2.9029 - val_StigY_Label_loss: 2.9021 - val_Focus_Label_categorical_accuracy: 0.7640 - val_Focus_Label_mean_squared_error: 0.6340 - val_Focus_Label_categorical_crossentropy: 2.9014 - val_StigX_Label_categorical_accuracy: 0.7865 - val_StigX_Label_mean_squared_error: 0.6333 - val_StigX_Label_categorical_crossentropy: 2.9029 - val_StigY_Label_categorical_accuracy: 0.7689 - val_StigY_Label_mean_squared_error: 0.6337 - val_StigY_Label_categorical_crossentropy: 2.9021 - lr: 0.0010 - epoch: 6.0000
# Epoch 7/100
# 511/511 [==============================] - 183s 358ms/step - loss: 8.7337 - Focus_Label_loss: 2.8817 - StigX_Label_loss: 2.8827 - StigY_Label_loss: 2.8810 - Focus_Label_categorical_accuracy: 0.8149 - Focus_Label_mean_squared_error: 0.6008 - Focus_Label_categorical_crossentropy: 2.8817 - StigX_Label_categorical_accuracy: 0.8170 - StigX_Label_mean_squared_error: 0.6009 - StigX_Label_categorical_crossentropy: 2.8827 - StigY_Label_categorical_accuracy: 0.8175 - StigY_Label_mean_squared_error: 0.6005 - StigY_Label_categorical_crossentropy: 2.8810 - val_loss: 8.7647 - val_Focus_Label_loss: 2.8947 - val_StigX_Label_loss: 2.8943 - val_StigY_Label_loss: 2.8915 - val_Focus_Label_categorical_accuracy: 0.7894 - val_Focus_Label_mean_squared_error: 0.6320 - val_Focus_Label_categorical_crossentropy: 2.8947 - val_StigX_Label_categorical_accuracy: 0.8384 - val_StigX_Label_mean_squared_error: 0.6320 - val_StigX_Label_categorical_crossentropy: 2.8943 - val_StigY_Label_categorical_accuracy: 0.7963 - val_StigY_Label_mean_squared_error: 0.6319 - val_StigY_Label_categorical_crossentropy: 2.8915 - lr: 0.0010 - epoch: 7.0000
# Epoch 8/100
# 511/511 [==============================] - 181s 355ms/step - loss: 8.7229 - Focus_Label_loss: 2.8799 - StigX_Label_loss: 2.8800 - StigY_Label_loss: 2.8810 - Focus_Label_categorical_accuracy: 0.8203 - Focus_Label_mean_squared_error: 0.6005 - Focus_Label_categorical_crossentropy: 2.8799 - StigX_Label_categorical_accuracy: 0.8162 - StigX_Label_mean_squared_error: 0.6005 - StigX_Label_categorical_crossentropy: 2.8800 - StigY_Label_categorical_accuracy: 0.8184 - StigY_Label_mean_squared_error: 0.6004 - StigY_Label_categorical_crossentropy: 2.8810 - val_loss: 8.7541 - val_Focus_Label_loss: 2.8917 - val_StigX_Label_loss: 2.8939 - val_StigY_Label_loss: 2.8897 - val_Focus_Label_categorical_accuracy: 0.8541 - val_Focus_Label_mean_squared_error: 0.6331 - val_Focus_Label_categorical_crossentropy: 2.8917 - val_StigX_Label_categorical_accuracy: 0.8266 - val_StigX_Label_mean_squared_error: 0.6330 - val_StigX_Label_categorical_crossentropy: 2.8939 - val_StigY_Label_categorical_accuracy: 0.7963 - val_StigY_Label_mean_squared_error: 0.6323 - val_StigY_Label_categorical_crossentropy: 2.8897 - lr: 0.0010 - epoch: 8.0000
# Epoch 9/100
# 511/511 [==============================] - 173s 339ms/step - loss: 8.7424 - Focus_Label_loss: 2.8874 - StigX_Label_loss: 2.8882 - StigY_Label_loss: 2.8886 - Focus_Label_categorical_accuracy: 0.8214 - Focus_Label_mean_squared_error: 0.6021 - Focus_Label_categorical_crossentropy: 2.8874 - StigX_Label_categorical_accuracy: 0.8216 - StigX_Label_mean_squared_error: 0.6018 - StigX_Label_categorical_crossentropy: 2.8882 - StigY_Label_categorical_accuracy: 0.8284 - StigY_Label_mean_squared_error: 0.6022 - StigY_Label_categorical_crossentropy: 2.8886 - val_loss: 8.7568 - val_Focus_Label_loss: 2.8933 - val_StigX_Label_loss: 2.8954 - val_StigY_Label_loss: 2.8941 - val_Focus_Label_categorical_accuracy: 0.7943 - val_Focus_Label_mean_squared_error: 0.6348 - val_Focus_Label_categorical_crossentropy: 2.8933 - val_StigX_Label_categorical_accuracy: 0.7855 - val_StigX_Label_mean_squared_error: 0.6354 - val_StigX_Label_categorical_crossentropy: 2.8954 - val_StigY_Label_categorical_accuracy: 0.8296 - val_StigY_Label_mean_squared_error: 0.6349 - val_StigY_Label_categorical_crossentropy: 2.8941 - lr: 0.0010 - epoch: 9.0000
# Epoch 10/100
# 511/511 [==============================] - 176s 345ms/step - loss: 8.7102 - Focus_Label_loss: 2.8795 - StigX_Label_loss: 2.8784 - StigY_Label_loss: 2.8787 - Focus_Label_categorical_accuracy: 0.8204 - Focus_Label_mean_squared_error: 0.6008 - Focus_Label_categorical_crossentropy: 2.8795 - StigX_Label_categorical_accuracy: 0.8179 - StigX_Label_mean_squared_error: 0.6011 - StigX_Label_categorical_crossentropy: 2.8784 - StigY_Label_categorical_accuracy: 0.8214 - StigY_Label_mean_squared_error: 0.6008 - StigY_Label_categorical_crossentropy: 2.8787 - val_loss: 8.7728 - val_Focus_Label_loss: 2.9009 - val_StigX_Label_loss: 2.8983 - val_StigY_Label_loss: 2.9005 - val_Focus_Label_categorical_accuracy: 0.7738 - val_Focus_Label_mean_squared_error: 0.6326 - val_Focus_Label_categorical_crossentropy: 2.9009 - val_StigX_Label_categorical_accuracy: 0.7786 - val_StigX_Label_mean_squared_error: 0.6320 - val_StigX_Label_categorical_crossentropy: 2.8983 - val_StigY_Label_categorical_accuracy: 0.8090 - val_StigY_Label_mean_squared_error: 0.6320 - val_StigY_Label_categorical_crossentropy: 2.9005 - lr: 0.0010 - epoch: 10.0000
# Epoch 11/100
# 511/511 [==============================] - 175s 343ms/step - loss: 8.7060 - Focus_Label_loss: 2.8787 - StigX_Label_loss: 2.8788 - StigY_Label_loss: 2.8780 - Focus_Label_categorical_accuracy: 0.8214 - Focus_Label_mean_squared_error: 0.6003 - Focus_Label_categorical_crossentropy: 2.8787 - StigX_Label_categorical_accuracy: 0.8165 - StigX_Label_mean_squared_error: 0.6003 - StigX_Label_categorical_crossentropy: 2.8788 - StigY_Label_categorical_accuracy: 0.8155 - StigY_Label_mean_squared_error: 0.6003 - StigY_Label_categorical_crossentropy: 2.8780 - val_loss: 8.7504 - val_Focus_Label_loss: 2.8952 - val_StigX_Label_loss: 2.8898 - val_StigY_Label_loss: 2.8918 - val_Focus_Label_categorical_accuracy: 0.8276 - val_Focus_Label_mean_squared_error: 0.6328 - val_Focus_Label_categorical_crossentropy: 2.8952 - val_StigX_Label_categorical_accuracy: 0.8041 - val_StigX_Label_mean_squared_error: 0.6321 - val_StigX_Label_categorical_crossentropy: 2.8898 - val_StigY_Label_categorical_accuracy: 0.8080 - val_StigY_Label_mean_squared_error: 0.6321 - val_StigY_Label_categorical_crossentropy: 2.8918 - lr: 0.0010 - epoch: 11.0000
# Epoch 12/100
# 511/511 [==============================] - 181s 354ms/step - loss: 8.7049 - Focus_Label_loss: 2.8768 - StigX_Label_loss: 2.8783 - StigY_Label_loss: 2.8781 - Focus_Label_categorical_accuracy: 0.8208 - Focus_Label_mean_squared_error: 0.5997 - Focus_Label_categorical_crossentropy: 2.8768 - StigX_Label_categorical_accuracy: 0.8213 - StigX_Label_mean_squared_error: 0.5998 - StigX_Label_categorical_crossentropy: 2.8783 - StigY_Label_categorical_accuracy: 0.8269 - StigY_Label_mean_squared_error: 0.5998 - StigY_Label_categorical_crossentropy: 2.8781 - val_loss: 8.7326 - val_Focus_Label_loss: 2.8865 - val_StigX_Label_loss: 2.8843 - val_StigY_Label_loss: 2.8890 - val_Focus_Label_categorical_accuracy: 0.8159 - val_Focus_Label_mean_squared_error: 0.6306 - val_Focus_Label_categorical_crossentropy: 2.8865 - val_StigX_Label_categorical_accuracy: 0.8227 - val_StigX_Label_mean_squared_error: 0.6302 - val_StigX_Label_categorical_crossentropy: 2.8843 - val_StigY_Label_categorical_accuracy: 0.7845 - val_StigY_Label_mean_squared_error: 0.6314 - val_StigY_Label_categorical_crossentropy: 2.8890 - lr: 0.0010 - epoch: 12.0000
# Epoch 13/100
# 511/511 [==============================] - 187s 366ms/step - loss: 8.7255 - Focus_Label_loss: 2.8843 - StigX_Label_loss: 2.8844 - StigY_Label_loss: 2.8842 - Focus_Label_categorical_accuracy: 0.8222 - Focus_Label_mean_squared_error: 0.6002 - Focus_Label_categorical_crossentropy: 2.8843 - StigX_Label_categorical_accuracy: 0.8259 - StigX_Label_mean_squared_error: 0.6005 - StigX_Label_categorical_crossentropy: 2.8844 - StigY_Label_categorical_accuracy: 0.8170 - StigY_Label_mean_squared_error: 0.6006 - StigY_Label_categorical_crossentropy: 2.8842 - val_loss: 8.7491 - val_Focus_Label_loss: 2.8924 - val_StigX_Label_loss: 2.8937 - val_StigY_Label_loss: 2.8928 - val_Focus_Label_categorical_accuracy: 0.7992 - val_Focus_Label_mean_squared_error: 0.6291 - val_Focus_Label_categorical_crossentropy: 2.8924 - val_StigX_Label_categorical_accuracy: 0.8178 - val_StigX_Label_mean_squared_error: 0.6290 - val_StigX_Label_categorical_crossentropy: 2.8937 - val_StigY_Label_categorical_accuracy: 0.8129 - val_StigY_Label_mean_squared_error: 0.6299 - val_StigY_Label_categorical_crossentropy: 2.8928 - lr: 0.0010 - epoch: 13.0000
# Epoch 14/100
# 511/511 [==============================] - 188s 368ms/step - loss: 8.7085 - Focus_Label_loss: 2.8767 - StigX_Label_loss: 2.8828 - StigY_Label_loss: 2.8783 - Focus_Label_categorical_accuracy: 0.8179 - Focus_Label_mean_squared_error: 0.5999 - Focus_Label_categorical_crossentropy: 2.8767 - StigX_Label_categorical_accuracy: 0.8184 - StigX_Label_mean_squared_error: 0.6009 - StigX_Label_categorical_crossentropy: 2.8828 - StigY_Label_categorical_accuracy: 0.8133 - StigY_Label_mean_squared_error: 0.6000 - StigY_Label_categorical_crossentropy: 2.8783 - val_loss: 8.7934 - val_Focus_Label_loss: 2.9164 - val_StigX_Label_loss: 2.9028 - val_StigY_Label_loss: 2.9045 - val_Focus_Label_categorical_accuracy: 0.7708 - val_Focus_Label_mean_squared_error: 0.6309 - val_Focus_Label_categorical_crossentropy: 2.9164 - val_StigX_Label_categorical_accuracy: 0.7708 - val_StigX_Label_mean_squared_error: 0.6308 - val_StigX_Label_categorical_crossentropy: 2.9028 - val_StigY_Label_categorical_accuracy: 0.7835 - val_StigY_Label_mean_squared_error: 0.6304 - val_StigY_Label_categorical_crossentropy: 2.9045 - lr: 0.0010 - epoch: 14.0000
# Epoch 15/100
# 511/511 [==============================] - 184s 360ms/step - loss: 8.6930 - Focus_Label_loss: 2.8751 - StigX_Label_loss: 2.8757 - StigY_Label_loss: 2.8747 - Focus_Label_categorical_accuracy: 0.8373 - Focus_Label_mean_squared_error: 0.5978 - Focus_Label_categorical_crossentropy: 2.8751 - StigX_Label_categorical_accuracy: 0.8330 - StigX_Label_mean_squared_error: 0.5987 - StigX_Label_categorical_crossentropy: 2.8757 - StigY_Label_categorical_accuracy: 0.8355 - StigY_Label_mean_squared_error: 0.5980 - StigY_Label_categorical_crossentropy: 2.8747 - val_loss: 8.7555 - val_Focus_Label_loss: 2.8876 - val_StigX_Label_loss: 2.9062 - val_StigY_Label_loss: 2.8943 - val_Focus_Label_categorical_accuracy: 0.8051 - val_Focus_Label_mean_squared_error: 0.6279 - val_Focus_Label_categorical_crossentropy: 2.8876 - val_StigX_Label_categorical_accuracy: 0.7718 - val_StigX_Label_mean_squared_error: 0.6307 - val_StigX_Label_categorical_crossentropy: 2.9062 - val_StigY_Label_categorical_accuracy: 0.7894 - val_StigY_Label_mean_squared_error: 0.6289 - val_StigY_Label_categorical_crossentropy: 2.8943 - lr: 0.0010 - epoch: 15.0000
# Epoch 16/100
# 511/511 [==============================] - 187s 366ms/step - loss: 8.6602 - Focus_Label_loss: 2.8633 - StigX_Label_loss: 2.8692 - StigY_Label_loss: 2.8629 - Focus_Label_categorical_accuracy: 0.8481 - Focus_Label_mean_squared_error: 0.5963 - Focus_Label_categorical_crossentropy: 2.8633 - StigX_Label_categorical_accuracy: 0.8377 - StigX_Label_mean_squared_error: 0.5969 - StigX_Label_categorical_crossentropy: 2.8692 - StigY_Label_categorical_accuracy: 0.8446 - StigY_Label_mean_squared_error: 0.5959 - StigY_Label_categorical_crossentropy: 2.8629 - val_loss: 8.6877 - val_Focus_Label_loss: 2.8721 - val_StigX_Label_loss: 2.8778 - val_StigY_Label_loss: 2.8748 - val_Focus_Label_categorical_accuracy: 0.8345 - val_Focus_Label_mean_squared_error: 0.6257 - val_Focus_Label_categorical_crossentropy: 2.8721 - val_StigX_Label_categorical_accuracy: 0.8208 - val_StigX_Label_mean_squared_error: 0.6271 - val_StigX_Label_categorical_crossentropy: 2.8778 - val_StigY_Label_categorical_accuracy: 0.8306 - val_StigY_Label_mean_squared_error: 0.6262 - val_StigY_Label_categorical_crossentropy: 2.8748 - lr: 1.0000e-04 - epoch: 16.0000
# Epoch 17/100
# 511/511 [==============================] - 183s 359ms/step - loss: 8.6412 - Focus_Label_loss: 2.8601 - StigX_Label_loss: 2.8601 - StigY_Label_loss: 2.8596 - Focus_Label_categorical_accuracy: 0.8522 - Focus_Label_mean_squared_error: 0.5942 - Focus_Label_categorical_crossentropy: 2.8601 - StigX_Label_categorical_accuracy: 0.8489 - StigX_Label_mean_squared_error: 0.5949 - StigX_Label_categorical_crossentropy: 2.8601 - StigY_Label_categorical_accuracy: 0.8527 - StigY_Label_mean_squared_error: 0.5938 - StigY_Label_categorical_crossentropy: 2.8596 - val_loss: 8.6616 - val_Focus_Label_loss: 2.8658 - val_StigX_Label_loss: 2.8689 - val_StigY_Label_loss: 2.8669 - val_Focus_Label_categorical_accuracy: 0.8306 - val_Focus_Label_mean_squared_error: 0.6244 - val_Focus_Label_categorical_crossentropy: 2.8658 - val_StigX_Label_categorical_accuracy: 0.8227 - val_StigX_Label_mean_squared_error: 0.6250 - val_StigX_Label_categorical_crossentropy: 2.8689 - val_StigY_Label_categorical_accuracy: 0.8355 - val_StigY_Label_mean_squared_error: 0.6245 - val_StigY_Label_categorical_crossentropy: 2.8669 - lr: 1.0000e-04 - epoch: 17.0000
# Epoch 18/100
# 511/511 [==============================] - 185s 363ms/step - loss: 8.6311 - Focus_Label_loss: 2.8570 - StigX_Label_loss: 2.8587 - StigY_Label_loss: 2.8567 - Focus_Label_categorical_accuracy: 0.8568 - Focus_Label_mean_squared_error: 0.5930 - Focus_Label_categorical_crossentropy: 2.8570 - StigX_Label_categorical_accuracy: 0.8542 - StigX_Label_mean_squared_error: 0.5934 - StigX_Label_categorical_crossentropy: 2.8587 - StigY_Label_categorical_accuracy: 0.8593 - StigY_Label_mean_squared_error: 0.5930 - StigY_Label_categorical_crossentropy: 2.8567 - val_loss: 8.6534 - val_Focus_Label_loss: 2.8647 - val_StigX_Label_loss: 2.8657 - val_StigY_Label_loss: 2.8655 - val_Focus_Label_categorical_accuracy: 0.8325 - val_Focus_Label_mean_squared_error: 0.6245 - val_Focus_Label_categorical_crossentropy: 2.8647 - val_StigX_Label_categorical_accuracy: 0.8276 - val_StigX_Label_mean_squared_error: 0.6246 - val_StigX_Label_categorical_crossentropy: 2.8657 - val_StigY_Label_categorical_accuracy: 0.8374 - val_StigY_Label_mean_squared_error: 0.6246 - val_StigY_Label_categorical_crossentropy: 2.8655 - lr: 1.0000e-04 - epoch: 18.0000
# Epoch 19/100
# 511/511 [==============================] - 183s 358ms/step - loss: 8.6049 - Focus_Label_loss: 2.8489 - StigX_Label_loss: 2.8493 - StigY_Label_loss: 2.8502 - Focus_Label_categorical_accuracy: 0.8571 - Focus_Label_mean_squared_error: 0.5912 - Focus_Label_categorical_crossentropy: 2.8489 - StigX_Label_categorical_accuracy: 0.8522 - StigX_Label_mean_squared_error: 0.5914 - StigX_Label_categorical_crossentropy: 2.8493 - StigY_Label_categorical_accuracy: 0.8571 - StigY_Label_mean_squared_error: 0.5917 - StigY_Label_categorical_crossentropy: 2.8502 - val_loss: 8.6420 - val_Focus_Label_loss: 2.8613 - val_StigX_Label_loss: 2.8622 - val_StigY_Label_loss: 2.8627 - val_Focus_Label_categorical_accuracy: 0.8355 - val_Focus_Label_mean_squared_error: 0.6226 - val_Focus_Label_categorical_crossentropy: 2.8613 - val_StigX_Label_categorical_accuracy: 0.8286 - val_StigX_Label_mean_squared_error: 0.6225 - val_StigX_Label_categorical_crossentropy: 2.8622 - val_StigY_Label_categorical_accuracy: 0.8423 - val_StigY_Label_mean_squared_error: 0.6230 - val_StigY_Label_categorical_crossentropy: 2.8627 - lr: 1.0000e-04 - epoch: 19.0000
# Epoch 20/100
# 511/511 [==============================] - 179s 351ms/step - loss: 8.6014 - Focus_Label_loss: 2.8499 - StigX_Label_loss: 2.8494 - StigY_Label_loss: 2.8472 - Focus_Label_categorical_accuracy: 0.8541 - Focus_Label_mean_squared_error: 0.5910 - Focus_Label_categorical_crossentropy: 2.8499 - StigX_Label_categorical_accuracy: 0.8527 - StigX_Label_mean_squared_error: 0.5908 - StigX_Label_categorical_crossentropy: 2.8494 - StigY_Label_categorical_accuracy: 0.8576 - StigY_Label_mean_squared_error: 0.5908 - StigY_Label_categorical_crossentropy: 2.8472 - val_loss: 8.6324 - val_Focus_Label_loss: 2.8586 - val_StigX_Label_loss: 2.8597 - val_StigY_Label_loss: 2.8600 - val_Focus_Label_categorical_accuracy: 0.8296 - val_Focus_Label_mean_squared_error: 0.6221 - val_Focus_Label_categorical_crossentropy: 2.8586 - val_StigX_Label_categorical_accuracy: 0.8286 - val_StigX_Label_mean_squared_error: 0.6221 - val_StigX_Label_categorical_crossentropy: 2.8597 - val_StigY_Label_categorical_accuracy: 0.8433 - val_StigY_Label_mean_squared_error: 0.6221 - val_StigY_Label_categorical_crossentropy: 2.8600 - lr: 1.0000e-04 - epoch: 20.0000
# Epoch 21/100
# 511/511 [==============================] - 177s 346ms/step - loss: 8.5888 - Focus_Label_loss: 2.8447 - StigX_Label_loss: 2.8448 - StigY_Label_loss: 2.8459 - Focus_Label_categorical_accuracy: 0.8487 - Focus_Label_mean_squared_error: 0.5902 - Focus_Label_categorical_crossentropy: 2.8447 - StigX_Label_categorical_accuracy: 0.8481 - StigX_Label_mean_squared_error: 0.5902 - StigX_Label_categorical_crossentropy: 2.8448 - StigY_Label_categorical_accuracy: 0.8526 - StigY_Label_mean_squared_error: 0.5905 - StigY_Label_categorical_crossentropy: 2.8459 - val_loss: 8.6342 - val_Focus_Label_loss: 2.8592 - val_StigX_Label_loss: 2.8607 - val_StigY_Label_loss: 2.8614 - val_Focus_Label_categorical_accuracy: 0.8335 - val_Focus_Label_mean_squared_error: 0.6205 - val_Focus_Label_categorical_crossentropy: 2.8592 - val_StigX_Label_categorical_accuracy: 0.8335 - val_StigX_Label_mean_squared_error: 0.6207 - val_StigX_Label_categorical_crossentropy: 2.8607 - val_StigY_Label_categorical_accuracy: 0.8345 - val_StigY_Label_mean_squared_error: 0.6209 - val_StigY_Label_categorical_crossentropy: 2.8614 - lr: 1.0000e-04 - epoch: 21.0000
# Epoch 22/100
# 511/511 [==============================] - 179s 351ms/step - loss: 8.5848 - Focus_Label_loss: 2.8436 - StigX_Label_loss: 2.8432 - StigY_Label_loss: 2.8455 - Focus_Label_categorical_accuracy: 0.8532 - Focus_Label_mean_squared_error: 0.5893 - Focus_Label_categorical_crossentropy: 2.8436 - StigX_Label_categorical_accuracy: 0.8475 - StigX_Label_mean_squared_error: 0.5892 - StigX_Label_categorical_crossentropy: 2.8432 - StigY_Label_categorical_accuracy: 0.8499 - StigY_Label_mean_squared_error: 0.5896 - StigY_Label_categorical_crossentropy: 2.8455 - val_loss: 8.6200 - val_Focus_Label_loss: 2.8556 - val_StigX_Label_loss: 2.8554 - val_StigY_Label_loss: 2.8570 - val_Focus_Label_categorical_accuracy: 0.8296 - val_Focus_Label_mean_squared_error: 0.6190 - val_Focus_Label_categorical_crossentropy: 2.8556 - val_StigX_Label_categorical_accuracy: 0.8266 - val_StigX_Label_mean_squared_error: 0.6193 - val_StigX_Label_categorical_crossentropy: 2.8554 - val_StigY_Label_categorical_accuracy: 0.8325 - val_StigY_Label_mean_squared_error: 0.6195 - val_StigY_Label_categorical_crossentropy: 2.8570 - lr: 1.0000e-04 - epoch: 22.0000
# Epoch 23/100
# 511/511 [==============================] - 174s 341ms/step - loss: 8.5735 - Focus_Label_loss: 2.8410 - StigX_Label_loss: 2.8405 - StigY_Label_loss: 2.8405 - Focus_Label_categorical_accuracy: 0.8429 - Focus_Label_mean_squared_error: 0.5884 - Focus_Label_categorical_crossentropy: 2.8410 - StigX_Label_categorical_accuracy: 0.8405 - StigX_Label_mean_squared_error: 0.5884 - StigX_Label_categorical_crossentropy: 2.8405 - StigY_Label_categorical_accuracy: 0.8434 - StigY_Label_mean_squared_error: 0.5883 - StigY_Label_categorical_crossentropy: 2.8405 - val_loss: 8.6171 - val_Focus_Label_loss: 2.8554 - val_StigX_Label_loss: 2.8543 - val_StigY_Label_loss: 2.8564 - val_Focus_Label_categorical_accuracy: 0.8227 - val_Focus_Label_mean_squared_error: 0.6198 - val_Focus_Label_categorical_crossentropy: 2.8554 - val_StigX_Label_categorical_accuracy: 0.8237 - val_StigX_Label_mean_squared_error: 0.6198 - val_StigX_Label_categorical_crossentropy: 2.8543 - val_StigY_Label_categorical_accuracy: 0.8227 - val_StigY_Label_mean_squared_error: 0.6201 - val_StigY_Label_categorical_crossentropy: 2.8564 - lr: 1.0000e-04 - epoch: 23.0000
# Epoch 24/100
# 511/511 [==============================] - 179s 351ms/step - loss: 8.5736 - Focus_Label_loss: 2.8409 - StigX_Label_loss: 2.8413 - StigY_Label_loss: 2.8410 - Focus_Label_categorical_accuracy: 0.8377 - Focus_Label_mean_squared_error: 0.5887 - Focus_Label_categorical_crossentropy: 2.8409 - StigX_Label_categorical_accuracy: 0.8374 - StigX_Label_mean_squared_error: 0.5885 - StigX_Label_categorical_crossentropy: 2.8413 - StigY_Label_categorical_accuracy: 0.8375 - StigY_Label_mean_squared_error: 0.5887 - StigY_Label_categorical_crossentropy: 2.8410 - val_loss: 8.6168 - val_Focus_Label_loss: 2.8560 - val_StigX_Label_loss: 2.8547 - val_StigY_Label_loss: 2.8560 - val_Focus_Label_categorical_accuracy: 0.8159 - val_Focus_Label_mean_squared_error: 0.6194 - val_Focus_Label_categorical_crossentropy: 2.8560 - val_StigX_Label_categorical_accuracy: 0.8198 - val_StigX_Label_mean_squared_error: 0.6196 - val_StigX_Label_categorical_crossentropy: 2.8547 - val_StigY_Label_categorical_accuracy: 0.8188 - val_StigY_Label_mean_squared_error: 0.6194 - val_StigY_Label_categorical_crossentropy: 2.8560 - lr: 1.0000e-04 - epoch: 24.0000
# Epoch 25/100
# 511/511 [==============================] - 179s 350ms/step - loss: 8.5710 - Focus_Label_loss: 2.8406 - StigX_Label_loss: 2.8413 - StigY_Label_loss: 2.8396 - Focus_Label_categorical_accuracy: 0.8404 - Focus_Label_mean_squared_error: 0.5876 - Focus_Label_categorical_crossentropy: 2.8406 - StigX_Label_categorical_accuracy: 0.8375 - StigX_Label_mean_squared_error: 0.5883 - StigX_Label_categorical_crossentropy: 2.8413 - StigY_Label_categorical_accuracy: 0.8364 - StigY_Label_mean_squared_error: 0.5877 - StigY_Label_categorical_crossentropy: 2.8396 - val_loss: 8.6159 - val_Focus_Label_loss: 2.8543 - val_StigX_Label_loss: 2.8563 - val_StigY_Label_loss: 2.8561 - val_Focus_Label_categorical_accuracy: 0.8247 - val_Focus_Label_mean_squared_error: 0.6182 - val_Focus_Label_categorical_crossentropy: 2.8543 - val_StigX_Label_categorical_accuracy: 0.8217 - val_StigX_Label_mean_squared_error: 0.6188 - val_StigX_Label_categorical_crossentropy: 2.8563 - val_StigY_Label_categorical_accuracy: 0.8217 - val_StigY_Label_mean_squared_error: 0.6185 - val_StigY_Label_categorical_crossentropy: 2.8561 - lr: 1.0000e-04 - epoch: 25.0000
# Epoch 26/100
# 511/511 [==============================] - 179s 350ms/step - loss: 8.5575 - Focus_Label_loss: 2.8357 - StigX_Label_loss: 2.8373 - StigY_Label_loss: 2.8357 - Focus_Label_categorical_accuracy: 0.8377 - Focus_Label_mean_squared_error: 0.5861 - Focus_Label_categorical_crossentropy: 2.8357 - StigX_Label_categorical_accuracy: 0.8377 - StigX_Label_mean_squared_error: 0.5866 - StigX_Label_categorical_crossentropy: 2.8373 - StigY_Label_categorical_accuracy: 0.8364 - StigY_Label_mean_squared_error: 0.5863 - StigY_Label_categorical_crossentropy: 2.8357 - val_loss: 8.6096 - val_Focus_Label_loss: 2.8538 - val_StigX_Label_loss: 2.8536 - val_StigY_Label_loss: 2.8534 - val_Focus_Label_categorical_accuracy: 0.8208 - val_Focus_Label_mean_squared_error: 0.6178 - val_Focus_Label_categorical_crossentropy: 2.8538 - val_StigX_Label_categorical_accuracy: 0.8247 - val_StigX_Label_mean_squared_error: 0.6179 - val_StigX_Label_categorical_crossentropy: 2.8536 - val_StigY_Label_categorical_accuracy: 0.8227 - val_StigY_Label_mean_squared_error: 0.6178 - val_StigY_Label_categorical_crossentropy: 2.8534 - lr: 1.0000e-04 - epoch: 26.0000
# Epoch 27/100
# 511/511 [==============================] - 175s 342ms/step - loss: 8.5593 - Focus_Label_loss: 2.8381 - StigX_Label_loss: 2.8363 - StigY_Label_loss: 2.8368 - Focus_Label_categorical_accuracy: 0.8302 - Focus_Label_mean_squared_error: 0.5861 - Focus_Label_categorical_crossentropy: 2.8381 - StigX_Label_categorical_accuracy: 0.8321 - StigX_Label_mean_squared_error: 0.5861 - StigX_Label_categorical_crossentropy: 2.8363 - StigY_Label_categorical_accuracy: 0.8306 - StigY_Label_mean_squared_error: 0.5862 - StigY_Label_categorical_crossentropy: 2.8368 - val_loss: 8.5780 - val_Focus_Label_loss: 2.8432 - val_StigX_Label_loss: 2.8434 - val_StigY_Label_loss: 2.8434 - val_Focus_Label_categorical_accuracy: 0.8306 - val_Focus_Label_mean_squared_error: 0.6171 - val_Focus_Label_categorical_crossentropy: 2.8432 - val_StigX_Label_categorical_accuracy: 0.8315 - val_StigX_Label_mean_squared_error: 0.6169 - val_StigX_Label_categorical_crossentropy: 2.8434 - val_StigY_Label_categorical_accuracy: 0.8286 - val_StigY_Label_mean_squared_error: 0.6167 - val_StigY_Label_categorical_crossentropy: 2.8434 - lr: 1.0000e-04 - epoch: 27.0000
# Epoch 28/100
# 511/511 [==============================] - 175s 343ms/step - loss: 8.5523 - Focus_Label_loss: 2.8360 - StigX_Label_loss: 2.8347 - StigY_Label_loss: 2.8341 - Focus_Label_categorical_accuracy: 0.8189 - Focus_Label_mean_squared_error: 0.5865 - Focus_Label_categorical_crossentropy: 2.8360 - StigX_Label_categorical_accuracy: 0.8226 - StigX_Label_mean_squared_error: 0.5862 - StigX_Label_categorical_crossentropy: 2.8347 - StigY_Label_categorical_accuracy: 0.8205 - StigY_Label_mean_squared_error: 0.5861 - StigY_Label_categorical_crossentropy: 2.8341 - val_loss: 8.5916 - val_Focus_Label_loss: 2.8485 - val_StigX_Label_loss: 2.8480 - val_StigY_Label_loss: 2.8478 - val_Focus_Label_categorical_accuracy: 0.8178 - val_Focus_Label_mean_squared_error: 0.6178 - val_Focus_Label_categorical_crossentropy: 2.8485 - val_StigX_Label_categorical_accuracy: 0.8188 - val_StigX_Label_mean_squared_error: 0.6179 - val_StigX_Label_categorical_crossentropy: 2.8480 - val_StigY_Label_categorical_accuracy: 0.8178 - val_StigY_Label_mean_squared_error: 0.6177 - val_StigY_Label_categorical_crossentropy: 2.8478 - lr: 1.0000e-04 - epoch: 28.0000
# Epoch 29/100
# 511/511 [==============================] - 173s 339ms/step - loss: 8.5367 - Focus_Label_loss: 2.8294 - StigX_Label_loss: 2.8307 - StigY_Label_loss: 2.8293 - Focus_Label_categorical_accuracy: 0.8227 - Focus_Label_mean_squared_error: 0.5847 - Focus_Label_categorical_crossentropy: 2.8294 - StigX_Label_categorical_accuracy: 0.8264 - StigX_Label_mean_squared_error: 0.5847 - StigX_Label_categorical_crossentropy: 2.8307 - StigY_Label_categorical_accuracy: 0.8244 - StigY_Label_mean_squared_error: 0.5844 - StigY_Label_categorical_crossentropy: 2.8293 - val_loss: 8.5716 - val_Focus_Label_loss: 2.8410 - val_StigX_Label_loss: 2.8420 - val_StigY_Label_loss: 2.8416 - val_Focus_Label_categorical_accuracy: 0.8139 - val_Focus_Label_mean_squared_error: 0.6168 - val_Focus_Label_categorical_crossentropy: 2.8410 - val_StigX_Label_categorical_accuracy: 0.7865 - val_StigX_Label_mean_squared_error: 0.6173 - val_StigX_Label_categorical_crossentropy: 2.8420 - val_StigY_Label_categorical_accuracy: 0.8012 - val_StigY_Label_mean_squared_error: 0.6170 - val_StigY_Label_categorical_crossentropy: 2.8416 - lr: 1.0000e-04 - epoch: 29.0000
# Epoch 30/100
# 511/511 [==============================] - 174s 340ms/step - loss: 8.5376 - Focus_Label_loss: 2.8319 - StigX_Label_loss: 2.8290 - StigY_Label_loss: 2.8299 - Focus_Label_categorical_accuracy: 0.8253 - Focus_Label_mean_squared_error: 0.5849 - Focus_Label_categorical_crossentropy: 2.8319 - StigX_Label_categorical_accuracy: 0.8279 - StigX_Label_mean_squared_error: 0.5848 - StigX_Label_categorical_crossentropy: 2.8290 - StigY_Label_categorical_accuracy: 0.8242 - StigY_Label_mean_squared_error: 0.5847 - StigY_Label_categorical_crossentropy: 2.8299 - val_loss: 8.5667 - val_Focus_Label_loss: 2.8398 - val_StigX_Label_loss: 2.8401 - val_StigY_Label_loss: 2.8403 - val_Focus_Label_categorical_accuracy: 0.8266 - val_Focus_Label_mean_squared_error: 0.6170 - val_Focus_Label_categorical_crossentropy: 2.8398 - val_StigX_Label_categorical_accuracy: 0.8247 - val_StigX_Label_mean_squared_error: 0.6172 - val_StigX_Label_categorical_crossentropy: 2.8401 - val_StigY_Label_categorical_accuracy: 0.8286 - val_StigY_Label_mean_squared_error: 0.6170 - val_StigY_Label_categorical_crossentropy: 2.8403 - lr: 1.0000e-04 - epoch: 30.0000
# Epoch 31/100
# 511/511 [==============================] - 178s 348ms/step - loss: 8.5441 - Focus_Label_loss: 2.8324 - StigX_Label_loss: 2.8333 - StigY_Label_loss: 2.8320 - Focus_Label_categorical_accuracy: 0.8217 - Focus_Label_mean_squared_error: 0.5855 - Focus_Label_categorical_crossentropy: 2.8324 - StigX_Label_categorical_accuracy: 0.8237 - StigX_Label_mean_squared_error: 0.5856 - StigX_Label_categorical_crossentropy: 2.8333 - StigY_Label_categorical_accuracy: 0.8235 - StigY_Label_mean_squared_error: 0.5853 - StigY_Label_categorical_crossentropy: 2.8320 - val_loss: 8.5609 - val_Focus_Label_loss: 2.8376 - val_StigX_Label_loss: 2.8384 - val_StigY_Label_loss: 2.8387 - val_Focus_Label_categorical_accuracy: 0.7904 - val_Focus_Label_mean_squared_error: 0.6158 - val_Focus_Label_categorical_crossentropy: 2.8376 - val_StigX_Label_categorical_accuracy: 0.7718 - val_StigX_Label_mean_squared_error: 0.6157 - val_StigX_Label_categorical_crossentropy: 2.8384 - val_StigY_Label_categorical_accuracy: 0.8080 - val_StigY_Label_mean_squared_error: 0.6157 - val_StigY_Label_categorical_crossentropy: 2.8387 - lr: 1.0000e-04 - epoch: 31.0000
# Epoch 32/100
# 511/511 [==============================] - 175s 342ms/step - loss: 8.5370 - Focus_Label_loss: 2.8302 - StigX_Label_loss: 2.8310 - StigY_Label_loss: 2.8297 - Focus_Label_categorical_accuracy: 0.8186 - Focus_Label_mean_squared_error: 0.5845 - Focus_Label_categorical_crossentropy: 2.8302 - StigX_Label_categorical_accuracy: 0.8149 - StigX_Label_mean_squared_error: 0.5844 - StigX_Label_categorical_crossentropy: 2.8310 - StigY_Label_categorical_accuracy: 0.8203 - StigY_Label_mean_squared_error: 0.5842 - StigY_Label_categorical_crossentropy: 2.8297 - val_loss: 8.5789 - val_Focus_Label_loss: 2.8429 - val_StigX_Label_loss: 2.8452 - val_StigY_Label_loss: 2.8448 - val_Focus_Label_categorical_accuracy: 0.7493 - val_Focus_Label_mean_squared_error: 0.6160 - val_Focus_Label_categorical_crossentropy: 2.8429 - val_StigX_Label_categorical_accuracy: 0.7238 - val_StigX_Label_mean_squared_error: 0.6164 - val_StigX_Label_categorical_crossentropy: 2.8452 - val_StigY_Label_categorical_accuracy: 0.7493 - val_StigY_Label_mean_squared_error: 0.6163 - val_StigY_Label_categorical_crossentropy: 2.8448 - lr: 1.0000e-04 - epoch: 32.0000
# Epoch 33/100
# 511/511 [==============================] - 172s 337ms/step - loss: 8.5223 - Focus_Label_loss: 2.8241 - StigX_Label_loss: 2.8271 - StigY_Label_loss: 2.8253 - Focus_Label_categorical_accuracy: 0.8122 - Focus_Label_mean_squared_error: 0.5826 - Focus_Label_categorical_crossentropy: 2.8241 - StigX_Label_categorical_accuracy: 0.8115 - StigX_Label_mean_squared_error: 0.5833 - StigX_Label_categorical_crossentropy: 2.8271 - StigY_Label_categorical_accuracy: 0.8097 - StigY_Label_mean_squared_error: 0.5828 - StigY_Label_categorical_crossentropy: 2.8253 - val_loss: 8.5524 - val_Focus_Label_loss: 2.8352 - val_StigX_Label_loss: 2.8359 - val_StigY_Label_loss: 2.8357 - val_Focus_Label_categorical_accuracy: 0.7747 - val_Focus_Label_mean_squared_error: 0.6153 - val_Focus_Label_categorical_crossentropy: 2.8352 - val_StigX_Label_categorical_accuracy: 0.7463 - val_StigX_Label_mean_squared_error: 0.6159 - val_StigX_Label_categorical_crossentropy: 2.8359 - val_StigY_Label_categorical_accuracy: 0.7767 - val_StigY_Label_mean_squared_error: 0.6156 - val_StigY_Label_categorical_crossentropy: 2.8357 - lr: 1.0000e-04 - epoch: 33.0000
# Epoch 34/100
# 511/511 [==============================] - 177s 347ms/step - loss: 8.5277 - Focus_Label_loss: 2.8273 - StigX_Label_loss: 2.8275 - StigY_Label_loss: 2.8274 - Focus_Label_categorical_accuracy: 0.8144 - Focus_Label_mean_squared_error: 0.5833 - Focus_Label_categorical_crossentropy: 2.8273 - StigX_Label_categorical_accuracy: 0.8128 - StigX_Label_mean_squared_error: 0.5835 - StigX_Label_categorical_crossentropy: 2.8275 - StigY_Label_categorical_accuracy: 0.8134 - StigY_Label_mean_squared_error: 0.5833 - StigY_Label_categorical_crossentropy: 2.8274 - val_loss: 8.5562 - val_Focus_Label_loss: 2.8363 - val_StigX_Label_loss: 2.8377 - val_StigY_Label_loss: 2.8369 - val_Focus_Label_categorical_accuracy: 0.7689 - val_Focus_Label_mean_squared_error: 0.6152 - val_Focus_Label_categorical_crossentropy: 2.8363 - val_StigX_Label_categorical_accuracy: 0.7385 - val_StigX_Label_mean_squared_error: 0.6155 - val_StigX_Label_categorical_crossentropy: 2.8377 - val_StigY_Label_categorical_accuracy: 0.7698 - val_StigY_Label_mean_squared_error: 0.6154 - val_StigY_Label_categorical_crossentropy: 2.8369 - lr: 1.0000e-04 - epoch: 34.0000
# Epoch 35/100
# 511/511 [==============================] - 171s 334ms/step - loss: 8.5270 - Focus_Label_loss: 2.8281 - StigX_Label_loss: 2.8266 - StigY_Label_loss: 2.8273 - Focus_Label_categorical_accuracy: 0.8244 - Focus_Label_mean_squared_error: 0.5838 - Focus_Label_categorical_crossentropy: 2.8281 - StigX_Label_categorical_accuracy: 0.8279 - StigX_Label_mean_squared_error: 0.5832 - StigX_Label_categorical_crossentropy: 2.8266 - StigY_Label_categorical_accuracy: 0.8199 - StigY_Label_mean_squared_error: 0.5834 - StigY_Label_categorical_crossentropy: 2.8273 - val_loss: 8.5623 - val_Focus_Label_loss: 2.8388 - val_StigX_Label_loss: 2.8391 - val_StigY_Label_loss: 2.8396 - val_Focus_Label_categorical_accuracy: 0.7218 - val_Focus_Label_mean_squared_error: 0.6162 - val_Focus_Label_categorical_crossentropy: 2.8388 - val_StigX_Label_categorical_accuracy: 0.6885 - val_StigX_Label_mean_squared_error: 0.6164 - val_StigX_Label_categorical_crossentropy: 2.8391 - val_StigY_Label_categorical_accuracy: 0.7120 - val_StigY_Label_mean_squared_error: 0.6165 - val_StigY_Label_categorical_crossentropy: 2.8396 - lr: 1.0000e-04 - epoch: 35.0000
# Epoch 36/100
# 511/511 [==============================] - 171s 335ms/step - loss: 8.5288 - Focus_Label_loss: 2.8302 - StigX_Label_loss: 2.8271 - StigY_Label_loss: 2.8269 - Focus_Label_categorical_accuracy: 0.8133 - Focus_Label_mean_squared_error: 0.5840 - Focus_Label_categorical_crossentropy: 2.8302 - StigX_Label_categorical_accuracy: 0.8122 - StigX_Label_mean_squared_error: 0.5834 - StigX_Label_categorical_crossentropy: 2.8271 - StigY_Label_categorical_accuracy: 0.8129 - StigY_Label_mean_squared_error: 0.5834 - StigY_Label_categorical_crossentropy: 2.8269 - val_loss: 8.5617 - val_Focus_Label_loss: 2.8382 - val_StigX_Label_loss: 2.8404 - val_StigY_Label_loss: 2.8385 - val_Focus_Label_categorical_accuracy: 0.7228 - val_Focus_Label_mean_squared_error: 0.6149 - val_Focus_Label_categorical_crossentropy: 2.8382 - val_StigX_Label_categorical_accuracy: 0.6758 - val_StigX_Label_mean_squared_error: 0.6152 - val_StigX_Label_categorical_crossentropy: 2.8404 - val_StigY_Label_categorical_accuracy: 0.7042 - val_StigY_Label_mean_squared_error: 0.6146 - val_StigY_Label_categorical_crossentropy: 2.8385 - lr: 1.0000e-04 - epoch: 36.0000
# Epoch 37/100
# 511/511 [==============================] - 169s 332ms/step - loss: 8.5174 - Focus_Label_loss: 2.8249 - StigX_Label_loss: 2.8245 - StigY_Label_loss: 2.8236 - Focus_Label_categorical_accuracy: 0.8175 - Focus_Label_mean_squared_error: 0.5824 - Focus_Label_categorical_crossentropy: 2.8249 - StigX_Label_categorical_accuracy: 0.8096 - StigX_Label_mean_squared_error: 0.5819 - StigX_Label_categorical_crossentropy: 2.8245 - StigY_Label_categorical_accuracy: 0.8155 - StigY_Label_mean_squared_error: 0.5818 - StigY_Label_categorical_crossentropy: 2.8236 - val_loss: 8.5502 - val_Focus_Label_loss: 2.8348 - val_StigX_Label_loss: 2.8358 - val_StigY_Label_loss: 2.8353 - val_Focus_Label_categorical_accuracy: 0.6934 - val_Focus_Label_mean_squared_error: 0.6154 - val_Focus_Label_categorical_crossentropy: 2.8348 - val_StigX_Label_categorical_accuracy: 0.6464 - val_StigX_Label_mean_squared_error: 0.6156 - val_StigX_Label_categorical_crossentropy: 2.8358 - val_StigY_Label_categorical_accuracy: 0.6758 - val_StigY_Label_mean_squared_error: 0.6153 - val_StigY_Label_categorical_crossentropy: 2.8353 - lr: 1.0000e-05 - epoch: 37.0000
# Epoch 38/100
# 511/511 [==============================] - 170s 332ms/step - loss: 8.5141 - Focus_Label_loss: 2.8228 - StigX_Label_loss: 2.8242 - StigY_Label_loss: 2.8227 - Focus_Label_categorical_accuracy: 0.8189 - Focus_Label_mean_squared_error: 0.5825 - Focus_Label_categorical_crossentropy: 2.8228 - StigX_Label_categorical_accuracy: 0.8142 - StigX_Label_mean_squared_error: 0.5823 - StigX_Label_categorical_crossentropy: 2.8242 - StigY_Label_categorical_accuracy: 0.8186 - StigY_Label_mean_squared_error: 0.5820 - StigY_Label_categorical_crossentropy: 2.8227 - val_loss: 8.5550 - val_Focus_Label_loss: 2.8363 - val_StigX_Label_loss: 2.8372 - val_StigY_Label_loss: 2.8372 - val_Focus_Label_categorical_accuracy: 0.6425 - val_Focus_Label_mean_squared_error: 0.6157 - val_Focus_Label_categorical_crossentropy: 2.8363 - val_StigX_Label_categorical_accuracy: 0.6082 - val_StigX_Label_mean_squared_error: 0.6158 - val_StigX_Label_categorical_crossentropy: 2.8372 - val_StigY_Label_categorical_accuracy: 0.6190 - val_StigY_Label_mean_squared_error: 0.6157 - val_StigY_Label_categorical_crossentropy: 2.8372 - lr: 1.0000e-05 - epoch: 38.0000
# Epoch 39/100
# 511/511 [==============================] - 173s 338ms/step - loss: 8.5121 - Focus_Label_loss: 2.8229 - StigX_Label_loss: 2.8223 - StigY_Label_loss: 2.8227 - Focus_Label_categorical_accuracy: 0.8068 - Focus_Label_mean_squared_error: 0.5824 - Focus_Label_categorical_crossentropy: 2.8229 - StigX_Label_categorical_accuracy: 0.8106 - StigX_Label_mean_squared_error: 0.5822 - StigX_Label_categorical_crossentropy: 2.8223 - StigY_Label_categorical_accuracy: 0.8075 - StigY_Label_mean_squared_error: 0.5822 - StigY_Label_categorical_crossentropy: 2.8227 - val_loss: 8.5505 - val_Focus_Label_loss: 2.8348 - val_StigX_Label_loss: 2.8358 - val_StigY_Label_loss: 2.8358 - val_Focus_Label_categorical_accuracy: 0.6523 - val_Focus_Label_mean_squared_error: 0.6154 - val_Focus_Label_categorical_crossentropy: 2.8348 - val_StigX_Label_categorical_accuracy: 0.6102 - val_StigX_Label_mean_squared_error: 0.6155 - val_StigX_Label_categorical_crossentropy: 2.8358 - val_StigY_Label_categorical_accuracy: 0.6210 - val_StigY_Label_mean_squared_error: 0.6154 - val_StigY_Label_categorical_crossentropy: 2.8358 - lr: 1.0000e-05 - epoch: 39.0000
# Epoch 40/100
# 511/511 [==============================] - 176s 344ms/step - loss: 8.5200 - Focus_Label_loss: 2.8253 - StigX_Label_loss: 2.8261 - StigY_Label_loss: 2.8245 - Focus_Label_categorical_accuracy: 0.8142 - Focus_Label_mean_squared_error: 0.5828 - Focus_Label_categorical_crossentropy: 2.8253 - StigX_Label_categorical_accuracy: 0.8118 - StigX_Label_mean_squared_error: 0.5828 - StigX_Label_categorical_crossentropy: 2.8261 - StigY_Label_categorical_accuracy: 0.8073 - StigY_Label_mean_squared_error: 0.5824 - StigY_Label_categorical_crossentropy: 2.8245 - val_loss: 8.5504 - val_Focus_Label_loss: 2.8347 - val_StigX_Label_loss: 2.8358 - val_StigY_Label_loss: 2.8358 - val_Focus_Label_categorical_accuracy: 0.6670 - val_Focus_Label_mean_squared_error: 0.6152 - val_Focus_Label_categorical_crossentropy: 2.8347 - val_StigX_Label_categorical_accuracy: 0.6239 - val_StigX_Label_mean_squared_error: 0.6153 - val_StigX_Label_categorical_crossentropy: 2.8358 - val_StigY_Label_categorical_accuracy: 0.6435 - val_StigY_Label_mean_squared_error: 0.6152 - val_StigY_Label_categorical_crossentropy: 2.8358 - lr: 1.0000e-05 - epoch: 40.0000
# Epoch 41/100
# 511/511 [==============================] - 171s 334ms/step - loss: 8.5089 - Focus_Label_loss: 2.8220 - StigX_Label_loss: 2.8212 - StigY_Label_loss: 2.8216 - Focus_Label_categorical_accuracy: 0.8193 - Focus_Label_mean_squared_error: 0.5817 - Focus_Label_categorical_crossentropy: 2.8220 - StigX_Label_categorical_accuracy: 0.8178 - StigX_Label_mean_squared_error: 0.5812 - StigX_Label_categorical_crossentropy: 2.8212 - StigY_Label_categorical_accuracy: 0.8187 - StigY_Label_mean_squared_error: 0.5812 - StigY_Label_categorical_crossentropy: 2.8216 - val_loss: 8.5514 - val_Focus_Label_loss: 2.8350 - val_StigX_Label_loss: 2.8362 - val_StigY_Label_loss: 2.8361 - val_Focus_Label_categorical_accuracy: 0.6425 - val_Focus_Label_mean_squared_error: 0.6153 - val_Focus_Label_categorical_crossentropy: 2.8350 - val_StigX_Label_categorical_accuracy: 0.6043 - val_StigX_Label_mean_squared_error: 0.6155 - val_StigX_Label_categorical_crossentropy: 2.8362 - val_StigY_Label_categorical_accuracy: 0.6229 - val_StigY_Label_mean_squared_error: 0.6154 - val_StigY_Label_categorical_crossentropy: 2.8361 - lr: 1.0000e-06 - epoch: 41.0000
# Epoch 42/100
# 511/511 [==============================] - 171s 335ms/step - loss: 8.5047 - Focus_Label_loss: 2.8204 - StigX_Label_loss: 2.8200 - StigY_Label_loss: 2.8202 - Focus_Label_categorical_accuracy: 0.8190 - Focus_Label_mean_squared_error: 0.5817 - Focus_Label_categorical_crossentropy: 2.8204 - StigX_Label_categorical_accuracy: 0.8084 - StigX_Label_mean_squared_error: 0.5816 - StigX_Label_categorical_crossentropy: 2.8200 - StigY_Label_categorical_accuracy: 0.8082 - StigY_Label_mean_squared_error: 0.5814 - StigY_Label_categorical_crossentropy: 2.8202 - val_loss: 8.5505 - val_Focus_Label_loss: 2.8347 - val_StigX_Label_loss: 2.8359 - val_StigY_Label_loss: 2.8358 - val_Focus_Label_categorical_accuracy: 0.6454 - val_Focus_Label_mean_squared_error: 0.6153 - val_Focus_Label_categorical_crossentropy: 2.8347 - val_StigX_Label_categorical_accuracy: 0.6063 - val_StigX_Label_mean_squared_error: 0.6154 - val_StigX_Label_categorical_crossentropy: 2.8359 - val_StigY_Label_categorical_accuracy: 0.6229 - val_StigY_Label_mean_squared_error: 0.6153 - val_StigY_Label_categorical_crossentropy: 2.8358 - lr: 1.0000e-06 - epoch: 42.0000
# Epoch 43/100
# ...
# Epoch 91/100
# 511/511 [==============================] - 176s 344ms/step - loss: 8.5010 - Focus_Label_loss: 2.8197 - StigX_Label_loss: 2.8189 - StigY_Label_loss: 2.8187 - Focus_Label_categorical_accuracy: 0.8118 - Focus_Label_mean_squared_error: 0.5815 - Focus_Label_categorical_crossentropy: 2.8197 - StigX_Label_categorical_accuracy: 0.8137 - StigX_Label_mean_squared_error: 0.5815 - StigX_Label_categorical_crossentropy: 2.8189 - StigY_Label_categorical_accuracy: 0.8121 - StigY_Label_mean_squared_error: 0.5812 - StigY_Label_categorical_crossentropy: 2.8187 - val_loss: 8.5476 - val_Focus_Label_loss: 2.8341 - val_StigX_Label_loss: 2.8350 - val_StigY_Label_loss: 2.8348 - val_Focus_Label_categorical_accuracy: 0.6239 - val_Focus_Label_mean_squared_error: 0.6148 - val_Focus_Label_categorical_crossentropy: 2.8341 - val_StigX_Label_categorical_accuracy: 0.5896 - val_StigX_Label_mean_squared_error: 0.6150 - val_StigX_Label_categorical_crossentropy: 2.8350 - val_StigY_Label_categorical_accuracy: 0.6092 - val_StigY_Label_mean_squared_error: 0.6148 - val_StigY_Label_categorical_crossentropy: 2.8348 - lr: 1.0000e-06 - epoch: 91.0000
# Epoch 92/100
# 511/511 [==============================] - 178s 348ms/step - loss: 8.5047 - Focus_Label_loss: 2.8210 - StigX_Label_loss: 2.8198 - StigY_Label_loss: 2.8203 - Focus_Label_categorical_accuracy: 0.8079 - Focus_Label_mean_squared_error: 0.5817 - Focus_Label_categorical_crossentropy: 2.8210 - StigX_Label_categorical_accuracy: 0.8090 - StigX_Label_mean_squared_error: 0.5814 - StigX_Label_categorical_crossentropy: 2.8198 - StigY_Label_categorical_accuracy: 0.8105 - StigY_Label_mean_squared_error: 0.5815 - StigY_Label_categorical_crossentropy: 2.8203 - val_loss: 8.5471 - val_Focus_Label_loss: 2.8339 - val_StigX_Label_loss: 2.8349 - val_StigY_Label_loss: 2.8346 - val_Focus_Label_categorical_accuracy: 0.6239 - val_Focus_Label_mean_squared_error: 0.6148 - val_Focus_Label_categorical_crossentropy: 2.8339 - val_StigX_Label_categorical_accuracy: 0.5906 - val_StigX_Label_mean_squared_error: 0.6150 - val_StigX_Label_categorical_crossentropy: 2.8349 - val_StigY_Label_categorical_accuracy: 0.6102 - val_StigY_Label_mean_squared_error: 0.6148 - val_StigY_Label_categorical_crossentropy: 2.8346 - lr: 1.0000e-06 - epoch: 92.0000
# Epoch 93/100
# 511/511 [==============================] - 182s 357ms/step - loss: 8.5157 - Focus_Label_loss: 2.8239 - StigX_Label_loss: 2.8237 - StigY_Label_loss: 2.8243 - Focus_Label_categorical_accuracy: 0.8127 - Focus_Label_mean_squared_error: 0.5820 - Focus_Label_categorical_crossentropy: 2.8239 - StigX_Label_categorical_accuracy: 0.8116 - StigX_Label_mean_squared_error: 0.5821 - StigX_Label_categorical_crossentropy: 2.8237 - StigY_Label_categorical_accuracy: 0.8088 - StigY_Label_mean_squared_error: 0.5817 - StigY_Label_categorical_crossentropy: 2.8243 - val_loss: 8.5462 - val_Focus_Label_loss: 2.8336 - val_StigX_Label_loss: 2.8346 - val_StigY_Label_loss: 2.8343 - val_Focus_Label_categorical_accuracy: 0.6337 - val_Focus_Label_mean_squared_error: 0.6147 - val_Focus_Label_categorical_crossentropy: 2.8336 - val_StigX_Label_categorical_accuracy: 0.5984 - val_StigX_Label_mean_squared_error: 0.6149 - val_StigX_Label_categorical_crossentropy: 2.8346 - val_StigY_Label_categorical_accuracy: 0.6200 - val_StigY_Label_mean_squared_error: 0.6147 - val_StigY_Label_categorical_crossentropy: 2.8343 - lr: 1.0000e-06 - epoch: 93.0000
# Epoch 94/100
# 511/511 [==============================] - 179s 350ms/step - loss: 8.5111 - Focus_Label_loss: 2.8214 - StigX_Label_loss: 2.8247 - StigY_Label_loss: 2.8214 - Focus_Label_categorical_accuracy: 0.8186 - Focus_Label_mean_squared_error: 0.5816 - Focus_Label_categorical_crossentropy: 2.8214 - StigX_Label_categorical_accuracy: 0.8127 - StigX_Label_mean_squared_error: 0.5822 - StigX_Label_categorical_crossentropy: 2.8247 - StigY_Label_categorical_accuracy: 0.8077 - StigY_Label_mean_squared_error: 0.5816 - StigY_Label_categorical_crossentropy: 2.8214 - val_loss: 8.5471 - val_Focus_Label_loss: 2.8339 - val_StigX_Label_loss: 2.8349 - val_StigY_Label_loss: 2.8346 - val_Focus_Label_categorical_accuracy: 0.6278 - val_Focus_Label_mean_squared_error: 0.6148 - val_Focus_Label_categorical_crossentropy: 2.8339 - val_StigX_Label_categorical_accuracy: 0.5926 - val_StigX_Label_mean_squared_error: 0.6150 - val_StigX_Label_categorical_crossentropy: 2.8349 - val_StigY_Label_categorical_accuracy: 0.6131 - val_StigY_Label_mean_squared_error: 0.6148 - val_StigY_Label_categorical_crossentropy: 2.8346 - lr: 1.0000e-06 - epoch: 94.0000
# Epoch 95/100
# 511/511 [==============================] - 174s 341ms/step - loss: 8.5109 - Focus_Label_loss: 2.8230 - StigX_Label_loss: 2.8221 - StigY_Label_loss: 2.8222 - Focus_Label_categorical_accuracy: 0.8119 - Focus_Label_mean_squared_error: 0.5816 - Focus_Label_categorical_crossentropy: 2.8230 - StigX_Label_categorical_accuracy: 0.8045 - StigX_Label_mean_squared_error: 0.5815 - StigX_Label_categorical_crossentropy: 2.8221 - StigY_Label_categorical_accuracy: 0.8078 - StigY_Label_mean_squared_error: 0.5816 - StigY_Label_categorical_crossentropy: 2.8222 - val_loss: 8.5470 - val_Focus_Label_loss: 2.8339 - val_StigX_Label_loss: 2.8349 - val_StigY_Label_loss: 2.8345 - val_Focus_Label_categorical_accuracy: 0.6278 - val_Focus_Label_mean_squared_error: 0.6148 - val_Focus_Label_categorical_crossentropy: 2.8339 - val_StigX_Label_categorical_accuracy: 0.5906 - val_StigX_Label_mean_squared_error: 0.6150 - val_StigX_Label_categorical_crossentropy: 2.8349 - val_StigY_Label_categorical_accuracy: 0.6131 - val_StigY_Label_mean_squared_error: 0.6148 - val_StigY_Label_categorical_crossentropy: 2.8345 - lr: 1.0000e-06 - epoch: 95.0000
# Epoch 96/100
# 511/511 [==============================] - 177s 346ms/step - loss: 8.5032 - Focus_Label_loss: 2.8208 - StigX_Label_loss: 2.8193 - StigY_Label_loss: 2.8194 - Focus_Label_categorical_accuracy: 0.8072 - Focus_Label_mean_squared_error: 0.5817 - Focus_Label_categorical_crossentropy: 2.8208 - StigX_Label_categorical_accuracy: 0.8039 - StigX_Label_mean_squared_error: 0.5815 - StigX_Label_categorical_crossentropy: 2.8193 - StigY_Label_categorical_accuracy: 0.8056 - StigY_Label_mean_squared_error: 0.5815 - StigY_Label_categorical_crossentropy: 2.8194 - val_loss: 8.5479 - val_Focus_Label_loss: 2.8342 - val_StigX_Label_loss: 2.8352 - val_StigY_Label_loss: 2.8349 - val_Focus_Label_categorical_accuracy: 0.6278 - val_Focus_Label_mean_squared_error: 0.6148 - val_Focus_Label_categorical_crossentropy: 2.8342 - val_StigX_Label_categorical_accuracy: 0.5935 - val_StigX_Label_mean_squared_error: 0.6150 - val_StigX_Label_categorical_crossentropy: 2.8352 - val_StigY_Label_categorical_accuracy: 0.6131 - val_StigY_Label_mean_squared_error: 0.6148 - val_StigY_Label_categorical_crossentropy: 2.8349 - lr: 1.0000e-06 - epoch: 96.0000
# Epoch 97/100
# 511/511 [==============================] - 183s 359ms/step - loss: 8.5124 - Focus_Label_loss: 2.8232 - StigX_Label_loss: 2.8230 - StigY_Label_loss: 2.8226 - Focus_Label_categorical_accuracy: 0.8068 - Focus_Label_mean_squared_error: 0.5822 - Focus_Label_categorical_crossentropy: 2.8232 - StigX_Label_categorical_accuracy: 0.8063 - StigX_Label_mean_squared_error: 0.5819 - StigX_Label_categorical_crossentropy: 2.8230 - StigY_Label_categorical_accuracy: 0.8105 - StigY_Label_mean_squared_error: 0.5818 - StigY_Label_categorical_crossentropy: 2.8226 - val_loss: 8.5485 - val_Focus_Label_loss: 2.8344 - val_StigX_Label_loss: 2.8354 - val_StigY_Label_loss: 2.8351 - val_Focus_Label_categorical_accuracy: 0.6229 - val_Focus_Label_mean_squared_error: 0.6148 - val_Focus_Label_categorical_crossentropy: 2.8344 - val_StigX_Label_categorical_accuracy: 0.5837 - val_StigX_Label_mean_squared_error: 0.6150 - val_StigX_Label_categorical_crossentropy: 2.8354 - val_StigY_Label_categorical_accuracy: 0.6004 - val_StigY_Label_mean_squared_error: 0.6148 - val_StigY_Label_categorical_crossentropy: 2.8351 - lr: 1.0000e-06 - epoch: 97.0000
# Epoch 98/100
# 511/511 [==============================] - 178s 348ms/step - loss: 8.5134 - Focus_Label_loss: 2.8229 - StigX_Label_loss: 2.8233 - StigY_Label_loss: 2.8236 - Focus_Label_categorical_accuracy: 0.8086 - Focus_Label_mean_squared_error: 0.5820 - Focus_Label_categorical_crossentropy: 2.8229 - StigX_Label_categorical_accuracy: 0.8003 - StigX_Label_mean_squared_error: 0.5820 - StigX_Label_categorical_crossentropy: 2.8233 - StigY_Label_categorical_accuracy: 0.8055 - StigY_Label_mean_squared_error: 0.5818 - StigY_Label_categorical_crossentropy: 2.8236 - val_loss: 8.5482 - val_Focus_Label_loss: 2.8343 - val_StigX_Label_loss: 2.8353 - val_StigY_Label_loss: 2.8350 - val_Focus_Label_categorical_accuracy: 0.6278 - val_Focus_Label_mean_squared_error: 0.6148 - val_Focus_Label_categorical_crossentropy: 2.8343 - val_StigX_Label_categorical_accuracy: 0.5886 - val_StigX_Label_mean_squared_error: 0.6150 - val_StigX_Label_categorical_crossentropy: 2.8353 - val_StigY_Label_categorical_accuracy: 0.6082 - val_StigY_Label_mean_squared_error: 0.6148 - val_StigY_Label_categorical_crossentropy: 2.8350 - lr: 1.0000e-06 - epoch: 98.0000
# Epoch 99/100
# 511/511 [==============================] - 177s 347ms/step - loss: 8.5046 - Focus_Label_loss: 2.8205 - StigX_Label_loss: 2.8199 - StigY_Label_loss: 2.8206 - Focus_Label_categorical_accuracy: 0.8044 - Focus_Label_mean_squared_error: 0.5815 - Focus_Label_categorical_crossentropy: 2.8205 - StigX_Label_categorical_accuracy: 0.8000 - StigX_Label_mean_squared_error: 0.5812 - StigX_Label_categorical_crossentropy: 2.8199 - StigY_Label_categorical_accuracy: 0.8030 - StigY_Label_mean_squared_error: 0.5811 - StigY_Label_categorical_crossentropy: 2.8206 - val_loss: 8.5485 - val_Focus_Label_loss: 2.8344 - val_StigX_Label_loss: 2.8354 - val_StigY_Label_loss: 2.8351 - val_Focus_Label_categorical_accuracy: 0.6288 - val_Focus_Label_mean_squared_error: 0.6148 - val_Focus_Label_categorical_crossentropy: 2.8344 - val_StigX_Label_categorical_accuracy: 0.5877 - val_StigX_Label_mean_squared_error: 0.6150 - val_StigX_Label_categorical_crossentropy: 2.8354 - val_StigY_Label_categorical_accuracy: 0.6121 - val_StigY_Label_mean_squared_error: 0.6148 - val_StigY_Label_categorical_crossentropy: 2.8351 - lr: 1.0000e-06 - epoch: 99.0000
# Epoch 100/100
# 511/511 [==============================] - 185s 362ms/step - loss: 8.4991 - Focus_Label_loss: 2.8197 - StigX_Label_loss: 2.8169 - StigY_Label_loss: 2.8188 - Focus_Label_categorical_accuracy: 0.8117 - Focus_Label_mean_squared_error: 0.5815 - Focus_Label_categorical_crossentropy: 2.8197 - StigX_Label_categorical_accuracy: 0.8093 - StigX_Label_mean_squared_error: 0.5810 - StigX_Label_categorical_crossentropy: 2.8169 - StigY_Label_categorical_accuracy: 0.8072 - StigY_Label_mean_squared_error: 0.5814 - StigY_Label_categorical_crossentropy: 2.8188 - val_loss: 8.5479 - val_Focus_Label_loss: 2.8342 - val_StigX_Label_loss: 2.8352 - val_StigY_Label_loss: 2.8349 - val_Focus_Label_categorical_accuracy: 0.6327 - val_Focus_Label_mean_squared_error: 0.6147 - val_Focus_Label_categorical_crossentropy: 2.8342 - val_StigX_Label_categorical_accuracy: 0.5935 - val_StigX_Label_mean_squared_error: 0.6149 - val_StigX_Label_categorical_crossentropy: 2.8352 - val_StigY_Label_categorical_accuracy: 0.6131 - val_StigY_Label_mean_squared_error: 0.6148 - val_StigY_Label_categorical_crossentropy: 2.8349 - lr: 1.0000e-06 - epoch: 100.0000
#
# Training for mobilenetv2 completed.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\aaron.woods\OneDrive - Thermo Fisher Scientific\Documents\GitHub\Image-Classification\DOE_Fiduciary_Classifier_Laptop.ipynb Cell 27 line 9
#      <a href='vscode-notebook-cell:/c%3A/Users/aaron.woods/OneDrive%20-%20Thermo%20Fisher%20Scientific/Documents/GitHub/Image-Classification/DOE_Fiduciary_Classifier_Laptop.ipynb#X35sZmlsZQ%3D%3D?line=90'>91</a>     os.replace(temp_excel_path, excel_path)
#      <a href='vscode-notebook-cell:/c%3A/Users/aaron.woods/OneDrive%20-%20Thermo%20Fisher%20Scientific/Documents/GitHub/Image-Classification/DOE_Fiduciary_Classifier_Laptop.ipynb#X35sZmlsZQ%3D%3D?line=93'>94</a> # Assuming you've already defined and initialized all your datasets and configs
# ---> <a href='vscode-notebook-cell:/c%3A/Users/aaron.woods/OneDrive%20-%20Thermo%20Fisher%20Scientific/Documents/GitHub/Image-Classification/DOE_Fiduciary_Classifier_Laptop.ipynb#X35sZmlsZQ%3D%3D?line=94'>95</a> train_and_save_metrics(train_dataset, valid_dataset, test_dataset, compiled_models, prepared_class_weights)
#
# c:\Users\aaron.woods\OneDrive - Thermo Fisher Scientific\Documents\GitHub\Image-Classification\DOE_Fiduciary_Classifier_Laptop.ipynb Cell 27 line 5
#      <a href='vscode-notebook-cell:/c%3A/Users/aaron.woods/OneDrive%20-%20Thermo%20Fisher%20Scientific/Documents/GitHub/Image-Classification/DOE_Fiduciary_Classifier_Laptop.ipynb#X35sZmlsZQ%3D%3D?line=47'>48</a>     if not _process_single_model(writer, model_name, model_info, train_dataset, valid_dataset, prepared_class_weights):
#      <a href='vscode-notebook-cell:/c%3A/Users/aaron.woods/OneDrive%20-%20Thermo%20Fisher%20Scientific/Documents/GitHub/Image-Classification/DOE_Fiduciary_Classifier_Laptop.ipynb#X35sZmlsZQ%3D%3D?line=48'>49</a>         continue
# ---> <a href='vscode-notebook-cell:/c%3A/Users/aaron.woods/OneDrive%20-%20Thermo%20Fisher%20Scientific/Documents/GitHub/Image-Classification/DOE_Fiduciary_Classifier_Laptop.ipynb#X35sZmlsZQ%3D%3D?line=49'>50</a>     _autosave_excel(writer, excel_path)
#      <a href='vscode-notebook-cell:/c%3A/Users/aaron.woods/OneDrive%20-%20Thermo%20Fisher%20Scientific/Documents/GitHub/Image-Classification/DOE_Fiduciary_Classifier_Laptop.ipynb#X35sZmlsZQ%3D%3D?line=51'>52</a> print(f"\nSaved all metrics to {excel_path}")
#
# c:\Users\aaron.woods\OneDrive - Thermo Fisher Scientific\Documents\GitHub\Image-Classification\DOE_Fiduciary_Classifier_Laptop.ipynb Cell 27 line 8
#      <a href='vscode-notebook-cell:/c%3A/Users/aaron.woods/OneDrive%20-%20Thermo%20Fisher%20Scientific/Documents/GitHub/Image-Classification/DOE_Fiduciary_Classifier_Laptop.ipynb#X35sZmlsZQ%3D%3D?line=84'>85</a> def _autosave_excel(writer, excel_path):
#      <a href='vscode-notebook-cell:/c%3A/Users/aaron.woods/OneDrive%20-%20Thermo%20Fisher%20Scientific/Documents/GitHub/Image-Classification/DOE_Fiduciary_Classifier_Laptop.ipynb#X35sZmlsZQ%3D%3D?line=85'>86</a>     temp_excel_path = excel_path.replace('.xlsx', '_temp.xlsx')
# ---> <a href='vscode-notebook-cell:/c%3A/Users/aaron.woods/OneDrive%20-%20Thermo%20Fisher%20Scientific/Documents/GitHub/Image-Classification/DOE_Fiduciary_Classifier_Laptop.ipynb#X35sZmlsZQ%3D%3D?line=86'>87</a>     writer.save(temp_excel_path)
#      <a href='vscode-notebook-cell:/c%3A/Users/aaron.woods/OneDrive%20-%20Thermo%20Fisher%20Scientific/Documents/GitHub/Image-Classification/DOE_Fiduciary_Classifier_Laptop.ipynb#X35sZmlsZQ%3D%3D?line=87'>88</a>     if os.path.exists(excel_path):
#      <a href='vscode-notebook-cell:/c%3A/Users/aaron.woods/OneDrive%20-%20Thermo%20Fisher%20Scientific/Documents/GitHub/Image-Classification/DOE_Fiduciary_Classifier_Laptop.ipynb#X35sZmlsZQ%3D%3D?line=88'>89</a>         backup_path = excel_path.replace('.xlsx', '_backup.xlsx')
#
# AttributeError: 'OpenpyxlWriter' object has no attribute 'save'

# %% [markdown]
# Mixed Precision Training: This involves using a mix of float16 and float32 data types during training to reduce memory usage and speed up training. Modern GPUs are optimized for float16 arithmetic, so this can lead to significant speedups as well.
#
# Check Other GPU Processes: Ensure that no other processes are using the GPU memory. Use the nvidia-smi command to check GPU memory usage. If other processes are running on the GPU, consider stopping them or moving your training to another time.
#
# Free Up GPU Memory: Ensure that any previous models or tensors that you no longer need are deleted and that you've called tf.keras.backend.clear_session() to clear any remnants from the GPU memory.

# %% [markdown]
# ## Evaluating Classification Models

# %%
# Define all the necessary functions and classes from the provided code


# Now, execute the function and plot the metrics using the uploaded Excel file
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.legend_handler import HandlerTuple
import numpy as np

# Custom handler for vertical legend tuples
class HandlerTupleVertical(HandlerTuple):
    def create_artists(self, legend, orig_handle, xdescent, ydescent, width, height, fontsize, trans):
        numlines = len(orig_handle)
        handler_map = legend.get_legend_handler_map()
        height_y = (height / numlines)
        leglines = []
        for i, handle in enumerate(orig_handle):
            handler = legend.get_legend_handler(handler_map, handle)
            legline = handler.create_artists(legend, handle, xdescent, (2*i + 1)*height_y, width, 2*height, fontsize, trans)
            leglines.extend(legline)
        return leglines


# 1. Data Loading and Parsing
def get_metrics_from_dataframe(df):
    LABELS = list(LABEL_MAPPING.keys())
    METRICS = list(METRIC_MAPPING.keys())
    return [col for col in METRICS if any(f"{label}_{col}" in df for label in LABELS)]

def get_dataframes_from_excel(xls):
    model_names = xls.sheet_names
    return {model_name: pd.read_excel(xls, model_name) for model_name in model_names}

def load_plotting_data(excel_path):
    xls = pd.ExcelFile(excel_path)
    dfs = get_dataframes_from_excel(xls)
    metrics = get_metrics_from_dataframe(next(iter(dfs.values())))
    return dfs, metrics


# 2. Visualization Setup and Configuration
def setup_colors(model_names):
    readable_model_names = [MODEL_NAME_MAPPING.get(name, name) for name in model_names]
    model_palette = sns.color_palette("tab10", len(model_names))
    return {
        readable_name: model_palette[i]
        for i, readable_name in enumerate(readable_model_names)}

def configure_plot_grid(metrics):
    LABELS = list(LABEL_MAPPING.keys())
    fig, axes = plt.subplots(len(metrics), len(LABELS), figsize=(18, 18 * len(metrics)/len(LABELS)))
    for j, label in enumerate(LABELS):
        readable_label = LABEL_MAPPING.get(label, label)
        axes[0, j].set_title(readable_label, fontsize=25, fontweight='bold', pad=45)
    for i, metric in enumerate(metrics):
        axes[i, 0].set_ylabel(METRIC_MAPPING.get(metric, metric.capitalize()), fontsize=25, fontweight='bold', labelpad=25)
    return fig, axes

def configure_axis(ax, i, j, metrics, epoch_range=None):
    """Configure the properties of a given axis."""
    ax.grid(True, which='both', linestyle='--', linewidth=0.5, alpha=0.7)
    if epoch_range:
        ax.set_xlim(epoch_range)
    if j != 0:
        ax.set_yticklabels([])
    else:
        ax.tick_params(axis='y', labelsize=18)
    if i != len(metrics) - 1:
        ax.set_xticklabels([])
    else:
        ax.tick_params(axis='x', labelsize=18)
        ax.set_xlabel('Epoch', fontsize=20)


# 3. Plotting and Finalization
def plot_data(ax, df, model_name, label, metric, smoothing_window, model_color_dict):
    readable_model_name = MODEL_NAME_MAPPING.get(model_name, model_name)
    color = model_color_dict[readable_model_name]
    if smoothing_window:
        train_data = df[f'{label}_{metric}'].rolling(window=smoothing_window).mean()
        val_data = df[f'val_{label}_{metric}'].rolling(window=smoothing_window).mean()
    else:
        train_data = df[f'{label}_{metric}']
        val_data = df[f'val_{label}_{metric}']
    ax.plot(df['epoch'], train_data, '--', color=color, label=f"{readable_model_name}", linewidth=3)
    ax.plot(df['epoch'], val_data, '-', color=color, label=f"{readable_model_name} (Validation)", linewidth=3)

def finalize_plot(fig, ax, dfs):
    handles, labels = ax.get_legend_handles_labels()
    new_handles = [(handles[j], handles[j + 1]) for j in range(0, len(handles), 2)]
    fig.legend(new_handles, labels[::2], handler_map={tuple: HandlerTupleVertical()}, loc="lower center", 
               borderaxespad=0.1, ncol=len(dfs), fontsize=15, frameon=True, bbox_to_anchor=(0.5, 0.02))
    fig.tight_layout()
    fig.subplots_adjust(top=0.93, bottom=0.10)  
    fig.suptitle('Model Metrics Comparison', fontsize=30, fontweight='bold', y=1.03)
    plt.show()


# 4. Utility Functions

def calculate_y_limits(dfs, metric):
    LABELS = list(LABEL_MAPPING.keys())
    """Calculate y-limits based on the metric data in the dataframes."""
    all_values = [value for df in dfs.values() for label in LABELS for value in df[f'{label}_{metric}'].tolist() + df[f'val_{label}_{metric}'].tolist()]
    lower_bound = np.percentile(all_values, 5)
    upper_bound = np.percentile(all_values, 90)
    buffer = (upper_bound - lower_bound) * 0.5
    return lower_bound - buffer, upper_bound + buffer


# Main Plotting Function
def publication_ready_plot(excel_path, epoch_range=None, smoothing_window=None):
    LABELS = list(LABEL_MAPPING.keys())
    """Generate a truly publication-ready grid of plots with all adjustments."""
    dfs, metrics = load_plotting_data(excel_path)
    model_color_dict = setup_colors(dfs.keys())
    fig, axes = configure_plot_grid(metrics)
    for i, metric in enumerate(metrics):
        y_min, y_max = calculate_y_limits(dfs, metric)
        for j, label in enumerate(LABELS):
            ax = axes[i, j]
            ax.set_ylim(y_min, y_max)
            configure_axis(ax, i, j, metrics, epoch_range)
            for model_name, df in dfs.items():
                plot_data(ax, df, model_name, label, metric, smoothing_window, model_color_dict)
    finalize_plot(fig, ax, dfs)


# Global variables
MODEL_NAME_MAPPING = {
    "mobilenetv2": "MobileNetV2 Transfer",
    "inceptionv3": "InceptionV3 Transfer",
    "resnet50": "ResNet50 Transfer",
    "small_xception": "Small Xception",
    "basic_cnn": "Basic CNN"
}
METRIC_MAPPING = {
    'loss': 'Loss',
    'categorical_accuracy': 'Categorical Accuracy',
    'categorical_crossentropy': 'Categorical Cross-Entropy',
    'mean_squared_error': 'Mean Squared Error'
}

LABEL_MAPPING = {
    'Focus_Label': 'Focus',
    'StigX_Label': 'Stigmatism X',
    'StigY_Label': 'Stigmatism Y'
}

excel_path = 'DOE_v1_SIM_noclw.xlsx'

publication_ready_plot(excel_path, epoch_range=(20, 100), smoothing_window=5)

# %%
### Comparing Experiment Results (Refactored GraphVersion)

# Constants
FILE_PATHS = [
    "SIM_Unbalanced.xlsx",
    "V9_Laptop - Multi-Output.xlsx",
    "V9.1_Laptop - Multi-Output.xlsx",
]

METRIC_VISUALIZATION_KEYS_WITH_EPOCHS = [
    (
        "Max Validation Categorical Accuracy",
        "Max Validation Categorical Accuracy Across Experiments",
        "Epoch at Max Validation Categorical Accuracy",
    ),
    (
        "Min Validation Loss",
        "Min Validation Loss Across Experiments",
        "Epoch at Min Validation Loss",
    ),
    (
        "Min Validation Categorical Crossentropy",
        "Min Validation Categorical Crossentropy Across Experiments",
        "Epoch at Min Validation Categorical Crossentropy",
    ),
    (
        "Min Validation Mean Squared Error",
        "Min Validation Mean Squared Error Across Experiments",
        "Epoch at Min Validation Mean Squared Error",
    ),
]

def extract_key_metrics_updated(excel_path):
    """Extract key metrics from the provided Excel file without using determine_engine."""
    # Load the Excel file and get DataFrames
    xls = pd.ExcelFile(excel_path, engine="openpyxl")
    dfs = get_dataframes_from_excel(xls)

    return {
        model_name: {
            "Min Validation Loss": df["val_loss"].min(),
            "Epoch at Min Validation Loss": df["epoch"].iloc[
                df["val_loss"].idxmin()
            ],
            "Max Validation Categorical Accuracy": df[
                "val_categorical_accuracy"
            ].max(),
            "Epoch at Max Validation Categorical Accuracy": df["epoch"].iloc[
                df["val_categorical_accuracy"].idxmax()
            ],
            "Min Validation Categorical Crossentropy": df[
                "val_categorical_crossentropy"
            ].min(),
            "Epoch at Min Validation Categorical Crossentropy": df[
                "epoch"
            ].iloc[df["val_categorical_crossentropy"].idxmin()],
            "Min Validation Mean Squared Error": df[
                "val_mean_squared_error"
            ].min(),
            "Epoch at Min Validation Mean Squared Error": df["epoch"].iloc[
                df["val_mean_squared_error"].idxmin()
            ],
        }
        for model_name, df in dfs.items()
    }


def extract_and_map_metrics(excel_path, name_mapping, metric_key, epoch_key):
    """Extract and map metrics using the provided name mapping."""
    experiment_name = os.path.basename(excel_path).replace(".xlsx", "")
    metrics = extract_key_metrics_updated(excel_path)

    # Use the name_mapping to rename models
    mapped_metric_values = {
        name_mapping.get(model, model): data[metric_key] for model, data in metrics.items()
    }
    mapped_epoch_values = {
        name_mapping.get(model, model): data[epoch_key] for model, data in metrics.items()
    }

    return experiment_name, mapped_metric_values, mapped_epoch_values


def visualize_mapped_metrics(metric_data, epoch_data, metric_title, metric_key):
    """Visualize a specific metric across experiments and annotate bars with epoch numbers."""
    metric_df = pd.DataFrame(metric_data).transpose()

    # Create the plot
    plt.figure(figsize=(15, 10))
    ax = metric_df.plot(kind="bar", ax=plt.gca(), colormap="viridis")
    plt.title(metric_title, fontsize=18)
    plt.ylabel(metric_key, fontsize=16)
    plt.xlabel("Experiment", fontsize=16)
    plt.legend(title="Models", bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=12, title_fontsize=14)
    plt.xticks(rotation=45, fontsize=14)
    plt.yticks(fontsize=14)
    ax.grid(axis='y')
    
    # Annotate bars with epoch numbers
    for idx, rect in enumerate(ax.patches):
        experiment_idx = idx // len(metric_df.columns)
        model_idx = idx % len(metric_df.columns)
        experiment_name = metric_df.index[experiment_idx]
        model_name = metric_df.columns[model_idx]
        epoch_value = epoch_data[experiment_name][model_name]
        ax.text(rect.get_x() + rect.get_width() / 2, rect.get_height(), f'Ep {epoch_value}', ha='center', va='bottom', fontsize=10)
    
    plt.tight_layout()
    plt.show()


def main_visualization(file_paths, name_mapping, metric_visualization_keys_with_epochs):
    """Main function for visualization."""
    for metric_key, metric_title, epoch_key in metric_visualization_keys_with_epochs:
        metric_data = {}
        epoch_data = {}

        for excel_path in file_paths:
            experiment_name, mapped_metric_values, mapped_epoch_values = extract_and_map_metrics(
                excel_path, name_mapping, metric_key, epoch_key
            )
            metric_data[experiment_name] = mapped_metric_values
            epoch_data[experiment_name] = mapped_epoch_values

        visualize_mapped_metrics(metric_data, epoch_data, metric_title, metric_key)


# Execute the main function
main_visualization(
    FILE_PATHS, model_name_mapping, METRIC_VISUALIZATION_KEYS_WITH_EPOCHS
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\aaron.woods\OneDrive - Thermo Fisher Scientific\Documents\GitHub\Image-Classification\DOE_Fiduciary_Classifier.ipynb Cell 32 line 1
#     <a href='vscode-notebook-cell:/c%3A/Users/aaron.woods/OneDrive%20-%20Thermo%20Fisher%20Scientific/Documents/GitHub/Image-Classification/DOE_Fiduciary_Classifier.ipynb#X44sZmlsZQ%3D%3D?line=124'>125</a>         visualize_mapped_metrics(metric_data, epoch_data, metric_title, metric_key)
#     <a href='vscode-notebook-cell:/c%3A/Users/aaron.woods/OneDrive%20-%20Thermo%20Fisher%20Scientific/Documents/GitHub/Image-Classification/DOE_Fiduciary_Classifier.ipynb#X44sZmlsZQ%3D%3D?line=127'>128</a> # Execute the main function
#     <a href='vscode-notebook-cell:/c%3A/Users/aaron.woods/OneDrive%20-%20Thermo%20Fisher%20Scientific/Documents/GitHub/Image-Classification/DOE_Fiduciary_Classifier.ipynb#X44sZmlsZQ%3D%3D?line=128'>129</a> main_visualization(
# --> <a href='vscode-notebook-cell:/c%3A/Users/aaron.woods/OneDrive%20-%20Thermo%20Fisher%20Scientific/Documents/GitHub/Image-Classification/DOE_Fiduciary_Classifier.ipynb#X44sZmlsZQ%3D%3D?line=129'>130</a>     FILE_PATHS, model_name_mapping, METRIC_VISUALIZATION_KEYS_WITH_EPOCHS
#     <a href='vscode-notebook-cell:/c%3A/Users/aaron.woods/OneDrive%20-%20Thermo%20Fisher%20Scientific/Documents/GitHub/Image-Classification/DOE_Fiduciary_Classifier.ipynb#X44sZmlsZQ%3D%3D?line=130'>131</a> )
#
# NameError: name 'model_name_mapping' is not defined

# %% [markdown]
# ## Loading and Testing Classification Models

# %%
### Loading the Best Model from Directories

def get_best_model_filename(directory):
    """Identify the best model filename based on the minimum validation loss from the directory."""
    model_files = [f for f in os.listdir(directory) if f.endswith('.h5')]
    if not model_files:
        print(f"No model files found in {directory}")
        return None
    return min(model_files, key=lambda x: float(x.split('val_loss_')[1].split('_')[0]))

def load_best_model(directory):
    """Loads the best model from the specified directory."""
    best_model_file = get_best_model_filename(directory)
    if not best_model_file:
        return None
    best_model_path = os.path.join(directory, best_model_file)
    # return load_model(best_model_path)
    return load_model(best_model_path, compile=False)

def get_label_directories(experiment_directory):
    """Determine label directories or just model directories in the experiment directory."""
    first_level_dirs = [os.path.join(experiment_directory, d) for d in os.listdir(experiment_directory) 
                        if os.path.isdir(os.path.join(experiment_directory, d))]
    if any('mobilenetv2' in dir_name for dir_name in first_level_dirs):
        return [experiment_directory]
    return first_level_dirs

def load_all_best_models(experiment_directory):
    """Load the best model for each model type within the experiment directory."""
    best_models = {}
    label_dirs = get_label_directories(experiment_directory)
    for label_dir in label_dirs:
        for model_name in ['mobilenetv2', 'inceptionv3', 'resnet50', 'small_xception', 'basic_cnn']:
            model_dir = os.path.join(label_dir, model_name)
            best_model = load_best_model(model_dir)
            if best_model:
                key_name = f"{os.path.basename(label_dir)}_{model_name}"
                best_models[key_name] = best_model
    return best_models

# Example Usage
experiment_directory = "SIM_Unbalanced"
all_best_models = load_all_best_models(experiment_directory)
print(all_best_models.keys())  # This will display the keys of the loaded models.

# %% [markdown]
# ## Investigating and Debugging

# %%
### Displaying Model Outputs in a Table (Refactored GraphVersion)

from tabulate import tabulate

def predict_with_model(model, sample_input):
    """Predict the output using the given model and input."""
    output = model.predict(sample_input)
    
    # Convert TensorFlow tensor to numpy array if needed
    if hasattr(output, 'numpy'):
        output = output.numpy()
    
    return output

def capture_model_output_details(model_name, model, sample_input):
    """Capture details of model's output for a given input."""
    output = predict_with_model(model, sample_input)
    return {
        "Model Name": model_name,
        "Input Shape": model.input_shape,
        "Output Shape": output.shape,
        "Output Type": type(output).__name__,
        "Sample Output": output[0] if len(output) > 0 else "No Output"
    }

def display_model_outputs_in_table(all_best_models, sample_input):
    """Display details of model's outputs in a tabular format."""
    model_output_details = [capture_model_output_details(model_name, model, sample_input) 
                            for model_name, model in all_best_models.items()]
    
    print(tabulate(model_output_details, headers="keys", tablefmt="grid"))

# Sample Usage
sample_input = test_images
display_model_outputs_in_table(all_best_models, sample_input)

# %%
### Inspecting the first few samples from the test dataset (Refactored GraphVersion)

def inspect_test_samples(test_dataset, label_encoders, num_samples_to_inspect=3):
    """
    Inspect a specified number of samples from a test dataset.
    
    Args:
    - test_dataset (tf.data.Dataset): The test dataset to inspect.
    - label_encoders (dict): A dictionary of label encoders.
    - num_samples_to_inspect (int, optional): Number of samples to inspect. Defaults to 3.
    
    Returns:
    - df: Styled DataFrame with inspected samples.
    """
    
    # Load a batch of test images, labels, and offset values
    test_images, test_labels_list, test_offsets = next(iter(test_dataset.take(1)))
    # test_images, test_labels_list = next(iter(test_dataset.take(1)))
    test_labels_array = np.stack([np.array(label) for label in test_labels_list])

    # Prepare data for DataFrame
    data = []
    for i in range(num_samples_to_inspect):
        sample_data = {
            "Sample": i + 1,
            "Image shape": str(test_images[i].shape),
            "Image values (first few)": f"{str(test_images[i].numpy().flatten()[:10])}...",
            "Labels shape": str(test_labels_array[i].shape),
            "Labels values": str(test_labels_array[i]),
        }

        for label, value in zip(label_encoders.keys(), test_labels_array[i]):
            sample_data[f"{label} (Decoded)"] = label_encoders[label].inverse_transform([value])[0]

        data.append(sample_data)

    # Create and display DataFrame
    df = pd.DataFrame(data).set_index("Sample")
    return df.style.hide_index()

# Sample Usage
styled_df = inspect_test_samples(train_dataset, label_encoders)
display(styled_df)

# %%
### Displaying Images from the Test Dataset (Refactored GraphVersion)

import numpy as np
import matplotlib.pyplot as plt

def decode_single_label(value, label, label_encoders):
    """Decode a single label."""
    decoded_label = label_encoders[label].inverse_transform([value])[0]
    
    simple_mappings = {
        'SharpFocus': 'Optimal',
        'SlightlyBlurred': 'Moderate',
        'HighlyBlurred': 'Severe',
        'OptimalStig_X': 'Optimal',
        'ModerateStig_X': 'Moderate',
        'SevereStig_X': 'Severe',
        'OptimalStig_Y': 'Optimal',
        'ModerateStig_Y': 'Moderate',
        'SevereStig_Y': 'Severe'
    }
    
    return simple_mappings.get(decoded_label, decoded_label)

def decode_labels(encoded_labels, label_encoders):
    """Decode a set of labels."""
    return [decode_single_label(value, label, label_encoders) for label, value in zip(label_encoders.keys(), encoded_labels)]

def format_label_for_display(label, value, offset):
    """Format the label for display on the image."""
    label = label.replace("_Label", "").replace("StigX", "Astigmatism (X direction)").replace("StigY", "Astigmatism (Y direction)")
    return f"{label}: {value} (Offset: {offset:.2f})"

def display_samples_with_labels(images, decoded_labels, offsets):
    """Display images with their decoded labels."""
    num_samples_to_display = min(3, len(images))
    fig, axes = plt.subplots(1, num_samples_to_display, figsize=(15, 5))
    for img, labels, offset, ax in zip(images[:num_samples_to_display], 
                                       decoded_labels[:num_samples_to_display], 
                                       offsets[:num_samples_to_display], 
                                       axes):
        ax.imshow(img.numpy())
        formatted_title = [format_label_for_display(label, value, off) for label, value, off in zip(label_encoders.keys(), labels, offset.numpy())]
        ax.set_title("\n".join(formatted_title))
        ax.axis('off')
    plt.tight_layout()
    plt.show()

# Decode the labels of the test samples
test_images, test_labels_list, test_offsets = next(iter(test_dataset.take(1)))
# test_images, test_labels_list = next(iter(test_dataset.take(1)))

test_labels_array = np.stack([np.array(label) for label in test_labels_list])
decoded_labels = [decode_labels(labels, label_encoders) for labels in test_labels_array]

# Display the test samples
display_samples_with_labels(test_images, decoded_labels, test_offsets)

# %%
### Showing True Labels for Test Samples (Refactored GraphVersion)

def format_column_name(column_name):
    """Format the column name."""
    return column_name.replace("_Label", "").replace("StigX", "Astigmatism (X direction)").replace("StigY", "Astigmatism (Y direction)")

def format_row_data(labels, offsets, label_encoders):
    """Format the row data."""
    return [f"{label} (Offset: {offset:.2f})" for label, offset, column_name in zip(labels, offsets, label_encoders.keys())]

def style_dataframe(df):
    """Style the DataFrame for a nicer display."""
    return df.style.set_table_styles(
        [
            {"selector": "th", "props": [("font-size", "100%"), ("text-align", "center")]},
            {"selector": "td", "props": [("font-size", "100%"), ("text-align", "center")]}
        ]
    )

# Decode labels and extract offsets
decoded_labels = [decode_labels(labels, label_encoders) for labels in test_labels_array]
offsets_list = [list(offset.numpy()) for offset in test_offsets]

# Prepare data and columns for DataFrame
data = [format_row_data(labels, offsets, label_encoders) for labels, offsets in zip(decoded_labels, offsets_list)]
columns = [format_column_name(column_name) for column_name in label_encoders.keys()]

# Create and style DataFrame
df = pd.DataFrame(data, columns=columns)
styled_df = style_dataframe(df)

styled_df

# %% [markdown]
# ## Beta Testing

# %%
# Graph Version Code for Confusion Matrix

from sklearn.metrics import confusion_matrix

def make_confusion_matrix(y_true, y_pred, classes=None, encoder=None, figsize=(10, 10), text_size=15, norm=False, savefig=False, output_num=None):
    """
    Makes a labelled confusion matrix comparing predictions and ground truth labels.

    Args:
    y_true: Array of truth labels.
    y_pred: Array of predicted labels.
    classes: Array of class labels (e.g. string form). If `None`, integer labels are used.
    encoder: Fitted LabelEncoder to transform integer labels back to original string labels.
    ... (other arguments as before)

    Returns:
    A labelled confusion matrix plot comparing y_true and y_pred.
    """
    
    # Error handling for array shapes
    if y_true.shape != y_pred.shape:
        print(f"Error: Mismatch in shapes of y_true ({y_true.shape}) and y_pred ({y_pred.shape}). Skipping this output.")
        return
    
    if encoder:
        y_true = encoder.inverse_transform(y_true)
        y_pred = encoder.inverse_transform(y_pred)
    
    # Create the confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    cm_norm = cm.astype("float") / cm.sum(axis=1)[:, np.newaxis]  # normalize it
    n_classes = cm.shape[0]  # find the number of classes we're dealing with

    # Plot the figure and make it pretty
    fig, ax = plt.subplots(figsize=figsize)
    cax = ax.matshow(cm, cmap=plt.cm.Blues)  # colors will represent how 'correct' a class is, darker == better
    fig.colorbar(cax)

    # Are there a list of classes?
    labels = classes if classes else np.arange(cm.shape[0])
    
    # Label the axes
    ax.set(title="Confusion Matrix",
           xlabel="Predicted label",
           ylabel="True label",
           xticks=np.arange(n_classes),
           yticks=np.arange(n_classes),
           xticklabels=labels,
           yticklabels=labels)

    # Make x-axis labels appear on bottom
    ax.xaxis.set_label_position("bottom")
    ax.xaxis.tick_bottom()

    # Set the threshold for different colors
    threshold = (cm.max() + cm.min()) / 2.

    # Plot the text on each cell
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        text = f"{cm[i, j]}" if not norm else f"{cm[i, j]} ({cm_norm[i, j]*100:.1f}%)"
        color = "white" if cm[i, j] > threshold else "black"
        plt.text(j, i, text, horizontalalignment="center", color=color, size=text_size)

    # Save the figure to the current working directory
    if savefig and output_num is not None:
        fig.savefig(f"confusion_matrix_output_{output_num + 1}.png")




def make_confusion_matrix_multi_output(y_true, y_preds, classes=None, encoders=None, figsize=(10, 10), text_size=15, norm=False, savefig=False): 
    """
    Makes a labelled confusion matrix comparing predictions and ground truth labels for multi-output models.

    Args:
    y_true: 2D array of truth labels for multiple outputs.
    y_preds: 2D array of predicted labels for multiple outputs.
    classes: List of arrays of class labels (e.g. string form) for each output. If `None`, integer labels are used.
    encoders: List of fitted LabelEncoders to transform integer labels back to original string labels for each output.
    ... (other arguments as before)

    Returns:
    A list of labelled confusion matrix plots comparing y_true and y_preds for each output.
    """
    
    # Error handling for array shapes
    if y_true.shape != y_preds.shape:
        print(f"Error: Mismatch in shapes of y_true ({y_true.shape}) and y_preds ({y_preds.shape}). Cannot proceed.")
        return
    
    num_outputs = y_true.shape[1]
    
    for i in range(num_outputs):
        print(f"Confusion Matrix for Output {i + 1}:")
        encoder = encoders[i] if encoders else None
        make_confusion_matrix(y_true[:, i], np.argmax(y_preds[:, i], axis=1), classes[i] if classes else None, encoder, figsize, text_size, norm, savefig, i)
        plt.show()

# %%
### Function for Confusion Matrix

def make_confusion_matrix_multi_output(y_true, y_preds, classes=None, figsize=(10, 10), text_size=15, norm=False, savefig=False): 
    """
    Makes a labelled confusion matrix comparing predictions and ground truth labels for multi-output models.

    Args:
    y_true: List of arrays of truth labels (must be same shape as y_preds).
    y_preds: List of arrays of predicted labels (must be same shape as y_true).
    classes: List of arrays of class labels (e.g. string form). If `None`, integer labels are used.
    ... (other arguments as before)

    Returns:
    A list of labelled confusion matrix plots comparing y_true and y_preds for each output.
    """
    # Check if y_true and y_preds are lists, if not, convert them to lists (for single-output compatibility)
    if not isinstance(y_true, list):
        y_true = [y_true]
    if not isinstance(y_preds, list):
        y_preds = [y_preds]
    
    for i, (true, pred) in enumerate(zip(y_true, y_preds)):
        print(f"Output {i + 1}:")
        make_confusion_matrix(true, pred, classes[i] if classes else None, figsize, text_size, norm, savefig)
        plt.show()

def make_confusion_matrix(y_true, y_pred, classes=None, figsize=(10, 10), text_size=15, norm=False, savefig=False):
    # (The function content remains the same as you provided)

    # Create the confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    cm_norm = cm.astype("float") / cm.sum(axis=1)[:, np.newaxis]  # normalize it
    n_classes = cm.shape[0]  # find the number of classes we're dealing with

    # Plot the figure and make it pretty
    fig, ax = plt.subplots(figsize=figsize)
    cax = ax.matshow(cm, cmap=plt.cm.Blues)  # colors will represent how 'correct' a class is, darker == better
    fig.colorbar(cax)

    # Are there a list of classes?
    labels = classes if classes else np.arange(cm.shape[0])
    
    # Label the axes
    ax.set(title="Confusion Matrix",
           xlabel="Predicted label",
           ylabel="True label",
           xticks=np.arange(n_classes),
           yticks=np.arange(n_classes),
           xticklabels=labels,
           yticklabels=labels)

    # Make x-axis labels appear on bottom
    ax.xaxis.set_label_position("bottom")
    ax.xaxis.tick_bottom()

    # Set the threshold for different colors
    threshold = (cm.max() + cm.min()) / 2.

    # Plot the text on each cell
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if norm:
            plt.text(j, i, f"{cm[i, j]} ({cm_norm[i, j]*100:.1f}%)",
                     horizontalalignment="center",
                     color="white" if cm[i, j] > threshold else "black",
                     size=text_size)
        else:
            plt.text(j, i, f"{cm[i, j]}",
                     horizontalalignment="center",
                     color="white" if cm[i, j] > threshold else "black",
                     size=text_size)

    # Save the figure to the current working directory
    if savefig:
        fig.savefig(f"confusion_matrix_output_{i + 1}.png")
        
        
        
### Attempt at Using the Confusion Matrix Function

def extract_labels_from_dataset(dataset, problem_type):
    """
    Extract labels from a TensorFlow dataset based on the problem type.
    
    Args:
    - dataset (tf.data.Dataset): The TensorFlow dataset to extract labels from.
    - problem_type (str): The type of problem ('Multi-Output', 'Multi-Class', or 'Binary').
    
    Returns:
    - numpy array or dict: If 'Multi-Output', returns a numpy array with shape (num_samples, num_outputs).
                           If 'Multi-Class' or 'Binary', returns a dictionary with label types as keys and 
                           arrays of labels as values.
    """
    
    if problem_type == 'Multi-Output':
        labels_list = [labels for _, labels in dataset]
        return np.array(labels_list).squeeze()

    elif problem_type in ['Multi-Class', 'Binary']:
        labels_dict = {}
        for label_type in ['Focus_Label', 'StigX_Label', 'StigY_Label']:
            label_data = []
            for _, labels in dataset[label_type]:
                label_data.extend(labels.numpy())
            labels_dict[label_type] = np.array(label_data)
        return labels_dict

    else:
        print(f"Unknown problem type: {problem_type}")
        return None

# Usage
problem_type = config['Experiment']['PROBLEM_TYPE']
test_labels = extract_labels_from_dataset(test_dataset, problem_type)

# Choose a specific model (replace 'specific_model_name' with the actual model name you're interested in)
model_name = 'specific_model_name'
model = all_best_models[model_name]

if not model:
    print(f"No model found for {model_name}")
    exit()

# 1. Predict on the test data
predictions = model.predict(test_dataset)


# 2. Get true labels and predictions for each output
# Assuming test_labels is a list where each item is an array of true labels for a given output
true_labels = [test_labels[i] for i in range(len(predictions))]
predicted_labels = [np.argmax(predictions[i], axis=1) for i in range(len(predictions))]

# List of class names for each output, assuming they are the same for all outputs in this example
classes_list = [list(range(3)) for _ in range(len(predictions))]

# 3. Generate confusion matrices
make_confusion_matrix_multi_output(true_labels, predicted_labels, classes_list)

# %% [markdown]
# ## Incorporate Later

# %%
def display_labels_with_probabilities(decoded_labels, probabilities):
    """
    Construct display strings that combine decoded labels with their corresponding probabilities.
    
    Parameters:
    - decoded_labels: A list of decoded label strings.
    - probabilities: A list of probability values corresponding to the decoded labels.
    
    Returns:
    - A list of strings combining labels with their probabilities.
    """
    return [f"{label} ({prob:.2f})" for label, prob in zip(decoded_labels, list(probabilities))]

# Load a batch of test images and labels
test_images, test_labels_list = next(iter(test_dataset.take(1)))
test_labels_array = np.stack([np.array(label) for label in test_labels_list])

# Make predictions using the selected model
predictions = model.predict(test_images)

# Decode the labels of the first few samples
decoded_labels = [decode_labels(labels, label_encoders) for labels in test_labels_array]
# Extract probabilities for the predicted labels
predicted_probs = [predictions[i][np.argmax(predictions[i])] for i in range(predictions.shape[0])]
display_strings = [display_labels_with_probabilities(labels, probs) for labels, probs in zip(decoded_labels, predicted_probs)]

# Display the images along with their decoded labels and probabilities
num_samples_to_display = 3
fig, axes = plt.subplots(1, num_samples_to_display, figsize=(15, 5))
for img, labels_with_probs, ax in zip(test_images[:num_samples_to_display], display_strings[:num_samples_to_display], axes):
    ax.imshow(img)
    title = "\n".join(labels_with_probs)
    ax.set_title(title)
    ax.axis('off')
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import classification_report

# Print the classification report
print(classification_report(y_labels, pred_classes))

# Note on classification_report():
# - Precision: Proportion of true positives. Higher precision -> fewer false positives.
# - Recall: Proportion of true positives over actual positives. Higher recall -> fewer false negatives.
# - F1 score: Harmonic mean of precision and recall. Range: [0, 1].

# Convert the report to a dictionary for further processing
classification_report_dict = classification_report(y_labels, pred_classes, output_dict=True)

# Focusing on f1-score as it combines precision and recall, extract it into a new dictionary
class_f1_scores = {class_names[int(k)]: v["f1-score"] for k, v in classification_report_dict.items() if k != "accuracy"}

class_f1_scores

# Convert dictionary to DataFrame and sort by f1-score in descending order
f1_scores_df = pd.DataFrame({
    "class_name": class_f1_scores.keys(),
    "f1-score": class_f1_scores.values()
}).sort_values("f1-score", ascending=False)

# Visualize f1-scores using a horizontal bar chart
fig, ax = plt.subplots(figsize=(12, 25))
bars = ax.barh(f1_scores_df["class_name"], f1_scores_df["f1-score"])
ax.set_xlabel("f1-score")
ax.set_title("F1-Scores for Different Classes")
ax.invert_yaxis()  # Reverse order for clarity

# Annotate bars with their respective scores
for bar in bars:
    ax.text(bar.get_width() * 1.03, bar.get_y() + bar.get_height() / 1.5,
            f"{bar.get_width():.2f}", ha='center', va='bottom')

# %%
# Analyzing Most Wrong Predictions:
# Observing predictions with high confidence but incorrect can provide insights into model performance.
# Steps:
# 1. Get test image filepaths.
# 2. Create a DataFrame for image details and predictions.
# 3. Identify correct predictions.
# 4. Extract top 100 most confidently incorrect predictions.
# 5. Visualize some of the most wrong examples.

# 1. Get the filenames of all test data
filepaths = [filepath.numpy() for filepath in test_data.list_files("101_food_classes_10_percent/test/*/*.jpg", shuffle=False)]

# 2. Create a dataframe for prediction analysis
import pandas as pd
pred_df = pd.DataFrame({
    "img_path": filepaths,
    "y_true": y_labels,
    "y_pred": pred_classes,
    "pred_conf": pred_probs.max(axis=1),
    "y_true_classname": [class_names[i] for i in y_labels],
    "y_pred_classname": [class_names[i] for i in pred_classes]
})

# 3. Identify correct predictions
pred_df["pred_correct"] = pred_df["y_true"] == pred_df["y_pred"]

# 4. Extract top 100 confidently incorrect predictions
top_100_wrong = pred_df[pred_df["pred_correct"] == False].sort_values("pred_conf", ascending=False).head(100)

# 5. Visualize some of the most wrong examples
images_to_view = 9
plt.figure(figsize=(15, 10))
for i, row in enumerate(top_100_wrong.head(images_to_view).itertuples()): 
    plt.subplot(3, 3, i+1)
    img = load_and_prep_image(row.img_path, scale=True)
    plt.imshow(img)
    plt.title(f"actual: {row.y_true_classname}, pred: {row.y_pred_classname} \nprob: {row.pred_conf:.2f}")
    plt.axis(False)
