# %% [markdown]
# ## Image Focus and Astigmatism Classifier
# **Author:** [Aaron Woods](https://aaronwoods.info)
# **Date Created:** September 21, 2023
# **Description:** This script provides an end-to-end machine learning pipeline to classify images as either "In Focus" or "Out of Focus", and additionally identifies astigmatism-related issues.
# **Repository:** [Image Classification on VSCode](https://insiders.vscode.dev/tunnel/midnightsim/c:/Users/User/Desktop/Image-Classification)
#
# ### Overview
# The script features a comprehensive pipeline that ingests data from Excel spreadsheets and feeds it into various machine learning models. The design is modular, allowing for easy adaptability to address different image classification problems, including focus quality and astigmatism detection.

# %% [markdown]
# ## Setup

# %%
# ------------------------------
# TensorFlow Installation with GPU Support
# ------------------------------
# Note: TensorFlow versions above 2.10 are not supported on GPUs on native Windows installations.
# For more details, visit: https://www.tensorflow.org/install/pip#windows-wsl2_1

# Uncomment the following line to install TensorFlow if needed.
# %pip install "tensorflow<2.11" --user

# ------------------------------
# System and TensorFlow Info Check
# ------------------------------
# Import necessary libraries and initialize an empty dictionary to store system information.
import platform
system_info = {"Platform": platform.platform(), "Python Version": platform.python_version()}

# Try importing TensorFlow and collecting relevant system information.
try:
    import tensorflow as tf
    system_info.update({
        "TensorFlow Version": tf.__version__,
        "Num GPUs Available": len(tf.config.list_physical_devices('GPU'))
    })
    system_info['Instructions'] = (
        "You're all set to run your model on a GPU." 
        if system_info['Num GPUs Available'] 
        else (
            "No GPUs found. To use a GPU, follow these steps:\n"
            "  1. Install NVIDIA drivers for your GPU.\n"
            "  2. Install a compatible CUDA toolkit.\n"
            "  3. Install the cuDNN library.\n"
            "  4. Make sure to install the GPU version of TensorFlow."
        )
    )
except ModuleNotFoundError:
    system_info['Instructions'] = (
        "TensorFlow is not installed. "
        "Install it using pip by running: !pip install tensorflow"
    )

# Format and display the gathered system information.
formatted_info = "\n".join(f"{key}: {value}" for key, value in system_info.items())
print(formatted_info)
# Out:
# Requirement already satisfied: tensorflow<2.11 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (2.10.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from tensorflow<2.11) (2.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from tensorflow<2.11) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from tensorflow<2.11) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from tensorflow<2.11) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from tensorflow<2.11) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from tensorflow<2.11) (3.9.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from tensorflow<2.11) (1.1.2)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from tensorflow<2.11) (16.0.6)
# Requirement already satisfied: numpy>=1.20 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from tensorflow<2.11) (1.26.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from tensorflow<2.11) (3.3.0)
# Requirement already satisfied: packaging in c:\users\aaron.woods\appdata\local\anaconda3\envs\tf\lib\site-packages (from tensorflow<2.11) (23.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from tensorflow<2.11) (3.19.6)
# Requirement already satisfied: setuptools in c:\users\aaron.woods\appdata\local\anaconda3\envs\tf\lib\site-packages (from tensorflow<2.11) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\aaron.woods\appdata\local\anaconda3\envs\tf\lib\site-packages (from tensorflow<2.11) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from tensorflow<2.11) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\aaron.woods\appdata\local\anaconda3\envs\tf\lib\site-packages (from tensorflow<2.11) (4.8.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from tensorflow<2.11) (1.15.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from tensorflow<2.11) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from tensorflow<2.11) (1.58.0)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from tensorflow<2.11) (2.10.1)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from tensorflow<2.11) (2.10.0)
# Requirement already satisfied: keras<2.11,>=2.10.0 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from tensorflow<2.11) (2.10.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\aaron.woods\appdata\local\anaconda3\envs\tf\lib\site-packages (from astunparse>=1.6.0->tensorflow<2.11) (0.38.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from tensorboard<2.11,>=2.10->tensorflow<2.11) (2.23.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from tensorboard<2.11,>=2.10->tensorflow<2.11) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from tensorboard<2.11,>=2.10->tensorflow<2.11) (3.4.4)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from tensorboard<2.11,>=2.10->tensorflow<2.11) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from tensorboard<2.11,>=2.10->tensorflow<2.11) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from tensorboard<2.11,>=2.10->tensorflow<2.11) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from tensorboard<2.11,>=2.10->tensorflow<2.11) (2.3.7)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow<2.11) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow<2.11) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow<2.11) (4.9)
# Requirement already satisfied: urllib3<2.0 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow<2.11) (1.26.16)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow<2.11) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\aaron.woods\appdata\local\anaconda3\envs\tf\lib\site-packages (from markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow<2.11) (6.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow<2.11) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow<2.11) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow<2.11) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from werkzeug>=1.0.1->tensorboard<2.11,>=2.10->tensorflow<2.11) (2.1.3)
# Requirement already satisfied: zipp>=0.5 in c:\users\aaron.woods\appdata\local\anaconda3\envs\tf\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow<2.11) (3.17.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow<2.11) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow<2.11) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.
# Platform: Windows-10-10.0.22621-SP0
# Python Version: 3.9.18
# TensorFlow Version: 2.10.1
# Num GPUs Available: 1
# Instructions: You're all set to run your model on a GPU.

# %%
# Avoid OOM errors by setting GPU Memory Consumption Growth
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus: 
    tf.config.experimental.set_memory_growth(gpu, True)
    
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# !pip install opencv-python numpy pandas matplotlib protobuf seaborn scikit-learn openpyxl
# Out:
# Requirement already satisfied: opencv-python in c:\users\aaron.woods\appdata\local\anaconda3\envs\tf\lib\site-packages (4.8.0.76)
# Requirement already satisfied: numpy in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (1.26.0)
# Requirement already satisfied: pandas in c:\users\aaron.woods\appdata\local\anaconda3\envs\tf\lib\site-packages (2.1.1)
# Requirement already satisfied: matplotlib in c:\users\aaron.woods\appdata\local\anaconda3\envs\tf\lib\site-packages (3.8.0)
# Requirement already satisfied: protobuf in c:\users\aaron.woods\appdata\roaming\python\python39\site-packages (3.19.6)
# Requirement already satisfied: seaborn in c:\users\aaron.woods\appdata\local\anaconda3\envs\tf\lib\site-packages (0.12.2)
# Requirement already satisfied: scikit-learn in c:\users\aaron.woods\appdata\local\anaconda3\envs\tf\lib\site-packages (1.3.1)
# Requirement already satisfied: openpyxl in c:\users\aaron.woods\appdata\local\anaconda3\envs\tf\lib\site-packages (3.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\aaron.woods\appdata\local\anaconda3\envs\tf\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\aaron.woods\appdata\local\anaconda3\envs\tf\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\aaron.woods\appdata\local\anaconda3\envs\tf\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\aaron.woods\appdata\local\anaconda3\envs\tf\lib\site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\aaron.woods\appdata\local\anaconda3\envs\tf\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\aaron.woods\appdata\local\anaconda3\envs\tf\lib\site-packages (from matplotlib) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\aaron.woods\appdata\local\anaconda3\envs\tf\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\aaron.woods\appdata\local\anaconda3\envs\tf\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\aaron.woods\appdata\local\anaconda3\envs\tf\lib\site-packages (from matplotlib) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\aaron.woods\appdata\local\anaconda3\envs\tf\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\aaron.woods\appdata\local\anaconda3\envs\tf\lib\site-packages (from matplotlib) (6.1.0)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\aaron.woods\appdata\local\anaconda3\envs\tf\lib\site-packages (from scikit-learn) (1.11.2)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\aaron.woods\appdata\local\anaconda3\envs\tf\lib\site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\aaron.woods\appdata\local\anaconda3\envs\tf\lib\site-packages (from scikit-learn) (3.2.0)
# Requirement already satisfied: et-xmlfile in c:\users\aaron.woods\appdata\local\anaconda3\envs\tf\lib\site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\aaron.woods\appdata\local\anaconda3\envs\tf\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.17.0)
# Requirement already satisfied: six>=1.5 in c:\users\aaron.woods\appdata\local\anaconda3\envs\tf\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
# ------------------------------
# Package Installation (Optional)
# ------------------------------
# Uncomment the following lines to install required packages if running on a new machine.
# To suppress the output, we use '> /dev/null 2>&1'.

# ------------------------------
# Import Libraries
# ------------------------------

# Standard Libraries
import os, sys, random, math, glob, logging
from datetime import datetime
from collections import defaultdict

# Third-Party Libraries
import numpy as np
import cv2
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.utils import class_weight
from sklearn.utils.class_weight import compute_class_weight
from IPython.display import clear_output
from collections import Counter
from sklearn.preprocessing import LabelEncoder, MultiLabelBinarizer

# TensorFlow and Keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow.keras.callbacks import TensorBoard, Callback
from tensorflow.keras.applications import InceptionV3, ResNet50
from keras.models import load_model
from tensorflow.data import Dataset

import pickle

# Type Annotations
from typing import List, Dict, Tuple, Union, Any, Optional

# %% [markdown]
# ## Configuration

# %%
# Configuration dictionary
config = {
    'Experiment': {
        'NAME': "PC_balanced_GPU_upsampled",  # Experiment name
        'RANDOM_SEED': 42,  # Seed for reproducibility
        'PROBLEM_TYPE': 'Multi-Output',  # Problem type: Binary, Multi-Class, Multi-Output, Multi-Label
    },
    'Model': {
        'IMG_SIZE': 224,  # Image input size
        'BATCH_SIZE': 16,  # Batch size for training
        'TRAIN_SIZE': 0.8,  # Fraction of data to use for training
        'VAL_SIZE': 0.5,  # Fraction of data to use for validation
        'EPOCHS': 100,  # Number of training epochs
        'LEARNING_RATE': 0.001,  # Learning rate 1e-3
        'EARLY_STOPPING_PATIENCE': 50,  # Early stopping patience
        'REDUCE_LR_PATIENCE':3,  # Reduce learning rate on plateau patience
        'MIN_LR': 1e-6,  # Minimum learning rate
    },
    'Labels': {
        'MAPPINGS': {  # Class label mappings
            'Focus_Label': {'SharpFocus': 0, 'SlightlyBlurred': 1, 'HighlyBlurred': 2},
            'StigX_Label': {'OptimalStig_X': 0, 'ModerateStig_X': 1, 'SevereStig_X': 2},
            'StigY_Label': {'OptimalStig_Y': 0, 'ModerateStig_Y': 1, 'SevereStig_Y': 2},
        }
    },
    'Augmentation': {  # Data augmentation parameters
        'rotation_factor': 0.002,
        'height_factor': (-0.18, 0.18),
        'width_factor': (-0.18, 0.18),
        'contrast_factor': 0.5,
    }
}

# %%
# Configure for dataset creation

csv_config = {
    'CSV': {
        'COLUMNS_TO_READ': ['ImageFile', 'Focus_Offset (V)', 'Stig_Offset_X (V)', 'Stig_Offset_Y (V)']
    },
    'Thresholds': {
        'FOCUS_LOW': 30,  # Lower focus threshold
        'FOCUS_HIGH': 60,  # Upper focus threshold
        'STIGX_LOW': 1,  # Lower astigmatism threshold
        'STIGX_HIGH': 2,  # Upper astigmatism threshold
        'STIGY_LOW': 1,  # Lower astigmatism threshold
        'STIGY_HIGH': 2,  # Upper astigmatism threshold
    },
    'Paths': {  # Data and model paths
        # 'DATA_FILE': "combined_output_cleaned.csv",
        'DATA_FILE': "combined_output_cleaned.csv",
        'OLD_BASE_PATH': "D:\\DOE\\",
        # 'NEW_BASE_PATH': "Y:\\User\\Aaron-HX38\\DOE\\", # On Simulation Computer
        'NEW_BASE_PATH': "C:\\Users\\aaron.woods\\OneDrive - Thermo Fisher Scientific\\Desktop\\Dec 24\\",
    },
    'SAMPLE_FRAC': 1,  # Fraction of the data to use for quicker prototyping. 1.0 means use all data.
}
config.update(csv_config)

# %%
# Set random seed for reproducibility
np.random.seed(config['Experiment']['RANDOM_SEED'])
tf.random.set_seed(config['Experiment']['RANDOM_SEED'])

# %% [markdown]
# ## Load and Preprocess the data

# %% [markdown]
# ### Functions for Preparation of CSV

# %%
# Read the data

def read_csv(config: Dict):
    # Functionality to read the data
    data_file_path = os.path.join(config['Paths']['NEW_BASE_PATH'], config['Paths']['DATA_FILE'])
    if not os.path.exists(data_file_path):
        raise FileNotFoundError(f"Error: File does not exist - {data_file_path}")
    try:
        data = pd.read_csv(data_file_path, usecols=config['CSV']['COLUMNS_TO_READ'])
        print("---> Data read successfully.")
        sample_frac = config.get('SAMPLE_FRAC', 1.0)
        if 0 < sample_frac < 1.0:
            data = data.sample(frac=sample_frac).reset_index(drop=True)
            print(f"---> Data sampled: Using {sample_frac * 100}% of the available data.")
    except Exception as e:
        raise ValueError(f"Error: Could not read data - {e}") from e
    return data

def update_image_paths(df):
    old_base_path = config['Paths']['OLD_BASE_PATH']
    new_base_path = config['Paths']['NEW_BASE_PATH']
    df['ImageFile'] = df['ImageFile'].str.replace(old_base_path, new_base_path, regex=False)
    print("---> Image paths updated.")
    return df


def clean_csv(df: pd.DataFrame, save_cleaned: bool = False) -> pd.DataFrame:
    def is_valid_string(image_path) -> bool:
        return isinstance(image_path, str)
    
    def does_file_exist(image_path) -> bool:
        return os.path.exists(image_path)
    
    def can_image_be_read(image_path) -> bool:
        img = cv2.imread(image_path)
        return img is not None
    
    removal_reasons = defaultdict(list)
    total_rows = len(df)
    csv_file_path = os.path.join(config['Paths']['NEW_BASE_PATH'], config['Paths']['DATA_FILE'])
    print("Cleaning CSV file...")
    for index, row in enumerate(df.itertuples()):
        progress = (index + 1) / total_rows * 100
        print(f"\rProgress: {progress:.2f}%", end="")
        
        image_path = row.ImageFile
        reason = None
        
        if not is_valid_string(image_path):
            reason = "Invalid ImageFile value - not a string"
        elif not does_file_exist(image_path):
            reason = "File does not exist"
        elif not can_image_be_read(image_path):
            reason = "Image can't be read"
        
        if reason:
            removal_reasons[reason].append(index)
    
    invalid_rows = [index for indices in removal_reasons.values() for index in indices]
    df.drop(index=invalid_rows, inplace=True)
    df.reset_index(drop=True, inplace=True)
    
    print("\n\nSummary of row removals:")
    for reason, indices in removal_reasons.items():
        print(f"{len(indices)} rows removed due to: {reason}")
        print(f"Row indices: {indices}")
    
    if save_cleaned and csv_file_path:
        cleaned_csv_file_path = f"{os.path.splitext(csv_file_path)[0]}_cleaned.csv"
        df.to_csv(cleaned_csv_file_path, index=False)
        print(f"Cleaned CSV saved to: {cleaned_csv_file_path}")
    
    return df

# %% [markdown]
# ### Generating labels

# %%
# Generating labels
from sklearn.preprocessing import LabelEncoder, MultiLabelBinarizer
import numpy as np
import pandas as pd
from typing import Dict

def generate_thresholds(label_key):
    low_key = f"{label_key.split('_')[0].upper()}_LOW"
    high_key = f"{label_key.split('_')[0].upper()}_HIGH"
    return config.get('Thresholds', {}).get(low_key, 0), config.get('Thresholds', {}).get(high_key, 0)

def generate_single_label(df_copy, label_key, offset_column, choices_dict):
    low_threshold, high_threshold = generate_thresholds(label_key)
    conditions = [
        (df_copy[offset_column].abs() <= low_threshold),
        (df_copy[offset_column].abs() > low_threshold) & (df_copy[offset_column].abs() <= high_threshold),
        (df_copy[offset_column].abs() > high_threshold)
    ]
    choices = list(choices_dict.keys())
    df_copy[label_key] = np.select(conditions, choices, default='Unknown')
    le = LabelEncoder()
    df_copy[label_key] = le.fit_transform(df_copy[label_key])
    return le

def generate_labels(df: pd.DataFrame):
    print("---> Generating labels for Focus, StigX, and StigY...")
    labels_config = config.get('Labels', {}).get('MAPPINGS', {})
    offset_column_mapping = {'Focus_Label': 'Focus_Offset (V)', 'StigX_Label': 'Stig_Offset_X (V)', 'StigY_Label': 'Stig_Offset_Y (V)'}

    df_copy = df.copy()
    label_encoders = {}

    for label_key, choices_dict in labels_config.items():
        offset_column = offset_column_mapping.get(label_key)
        if not offset_column:
            print(f"Warning: No offset column mapping found for '{label_key}'. Skipping label generation.")
            continue
        if offset_column not in df.columns:
            print(f"Warning: Column '{offset_column}' not found in DataFrame. Skipping label generation for '{label_key}'.")
            continue
        label_encoders[label_key] = generate_single_label(df_copy, label_key, offset_column, choices_dict)
        print(f"---> Labels generated for {label_key}")

    if config.get('Experiment', {}).get('PROBLEM_TYPE') == 'Multi-Output':
        df_copy['Multi_Output_Labels'] = df_copy.apply(lambda row: [row[key] for key in labels_config.keys()], axis=1)
        print("---> Multi-Output Labels generated.")
        
    return df_copy, label_encoders

# %% [markdown]
# ### Shuffling and Splitting the Data

# %%
# Shuffling and Splitting the data

def shuffle_and_reset_index(data):
    print("---> Shuffling and resetting index...")
    shuffled_df = data.sample(frac=1, random_state=config['Experiment']['RANDOM_SEED']).reset_index(drop=True)
    print("---> Data shuffled and index reset.")
    return shuffled_df

def prepare_datasets(df: pd.DataFrame):
    """Prepare training, validation, and test datasets."""
    # Check if DataFrame is empty
    if df is None or df.empty:
        print("Warning: DataFrame is empty. Cannot proceed with data preparation.")
        return {'train': None, 'valid': None, 'test': None}
    # Split Data
    try:
        train_df, temp_df = train_test_split(df, test_size=1 - config['Model']['TRAIN_SIZE'], random_state=config['Experiment']['RANDOM_SEED'])
        val_df, test_df = train_test_split(temp_df, test_size=1 - config['Model']['VAL_SIZE'], random_state=config['Experiment']['RANDOM_SEED'])
    except ValueError:
        print("Not enough data to split into training, validation, and test sets.")
        return {'train': None, 'valid': None, 'test': None}
    print("---> Data split into training, validation, and test sets.")
    return {'train': train_df, 'valid': val_df, 'test': test_df}

# %% [markdown]
# ### Computting Class Weights

# %%
# Compute class weights

from collections import Counter
from sklearn.preprocessing import LabelEncoder, MultiLabelBinarizer
from sklearn.utils.class_weight import compute_class_weight
import numpy as np
import pandas as pd
from typing import Dict


def compute_multi_output_class_weights(split: str, df: pd.DataFrame, label: str, label_encoders: Dict[str, LabelEncoder], all_records: List[Dict]) -> None:
    unique_labels = df[label].unique()
    class_weights = compute_class_weight('balanced', classes=np.unique(unique_labels), y=df[label])
    class_weights_dict = dict(zip(unique_labels, class_weights))
    for cls, weight in class_weights_dict.items():
        cnt = Counter(df[label])[cls]
        original_class = label_encoders[label].inverse_transform([cls])[0]
        all_records.append({'split': split, 'label': label, 'class': original_class, 'Count': cnt, 'Weight': weight})

def compute_multi_label_class_weights(split: str, df: pd.DataFrame, label: str, label_encoders: Dict[str, LabelEncoder], all_records: List[Dict]) -> None:
    label_data = df[label].values
    unique_labels = np.unique(label_data)
    class_weights = compute_class_weight('balanced', classes=np.unique(unique_labels), y=label_data)
    class_weights_dict = dict(zip(unique_labels, class_weights))
    for cls, weight in class_weights_dict.items():
        cnt = Counter(label_data)[cls]
        original_class = label_encoders[label].inverse_transform([cls])[0]
        all_records.append({'split': split, 'label': label, 'class': original_class, 'Count': cnt, 'Weight': weight})

def compute_and_store_class_weights(datasets: Dict[str, pd.DataFrame], label_encoders: Dict[str, LabelEncoder]) -> pd.DataFrame:
    problem_type = config.get('Experiment', {}).get('PROBLEM_TYPE', 'Binary')
    all_records = []
    
    for split, df in datasets.items():
        if df is None:
            continue
        for label in config['Labels']['MAPPINGS']:
            if problem_type == 'Multi-label':
                compute_multi_label_class_weights(split, df, label, label_encoders, all_records)
            else:
                compute_multi_output_class_weights(split, df, label, label_encoders, all_records)
                
    df_class_weights = pd.DataFrame.from_records(all_records)
    df_class_weights.set_index(['split', 'label', 'class'], inplace=True)
    return df_class_weights

# %% [markdown]
# ### Creating Tensorflow Datasets

# %%
# Create TensorFlow datasets

def create_tf_datasets_from_dfs(dfs: Dict[str, pd.DataFrame], include_offset=False) -> Dict[str, Dict[str, Any]]:
    """
    Create TensorFlow datasets from DataFrames for training, validation, and testing.
    Parameters:
    - dfs: Dictionary containing DataFrames for 'train', 'val', and 'test'.
    Returns:
    - Dictionary containing TensorFlow datasets for each split.
    """
    problem_type = config.get('Experiment', {}).get('PROBLEM_TYPE')
    batch_size = config.get('Model', {}).get('BATCH_SIZE', 32)
    AUTOTUNE = tf.data.AUTOTUNE
    # Create preprocessing and augmentation layers
    preprocessing_layers = create_preprocessing_layers()
    augmentation_layers = create_augmentation_layers()
    # Initialize output dictionary
    tf_datasets = {'train': {}, 'valid': {}, 'test': {}}
    
    def load_and_preprocess_image(file_path, label, offset=None, augment=False):
        file_path_str = file_path.numpy().decode('utf-8')
        image = read_and_convert_image(file_path_str)
        image = preprocessing_layers(image)
        label = tf.cast(label, tf.int32)  # Explicitly casting to tf.int32
        offset = tf.cast(offset, tf.float32) if offset is not None else None
        if augment:
            image = augmentation_layers(image)
            image = tf.clip_by_value(image, 0.0, 1.0)
        return (image, label, offset) if include_offset else (image, label)
    
    
    offset_column_mapping = {
        'Focus_Label': 'Focus_Offset (V)',
        'StigX_Label': 'Stig_Offset_X (V)',
        'StigY_Label': 'Stig_Offset_Y (V)'}
    for split, df in dfs.items():
        augment_data = (split == 'train')
        if problem_type in ['Multi-Class', 'Binary']:
            for label in ['Focus_Label', 'StigX_Label', 'StigY_Label']:
                offset_column = offset_column_mapping.get(label)
                offsets_tensor = df[offset_column].values if include_offset else None
                
                ds = tf.data.Dataset.from_tensor_slices((df['ImageFile'].values, df[label].values, offsets_tensor))

                # Handling offset inside the lambda
                ds = ds.map(lambda file_path, label, offset: tf.py_function(
                    func=load_and_preprocess_image,
                    inp=[file_path, label, offset if offset is not None else tf.constant([], dtype=tf.float32), augment_data],
                    Tout=[tf.float32, label.dtype, tf.float32] if include_offset else [tf.float32, label.dtype]
                ))
                
                ds = ds.batch(batch_size)
                # ds = ds.cache().prefetch(buffer_size=AUTOTUNE) Memory Issues
                ds = ds.prefetch(buffer_size=AUTOTUNE)
                tf_datasets[split][label] = ds

        elif problem_type == 'Multi-Output':
            labels_tensor = df[['Focus_Label', 'StigX_Label', 'StigY_Label']].values
            offsets_tensor = df[['Focus_Offset (V)', 'Stig_Offset_X (V)', 'Stig_Offset_Y (V)']].values if include_offset else None
            ds = tf.data.Dataset.from_tensor_slices((df['ImageFile'].values, labels_tensor, offsets_tensor))
            
            # Handling offset inside the lambda
            ds = ds.map(lambda file_path, label, offset: tf.py_function(
                func=load_and_preprocess_image,
                inp=[file_path, label, offset if offset is not None else tf.constant([], dtype=tf.float32), augment_data],
                Tout=[tf.float32, label.dtype, tf.float32] if include_offset else [tf.float32, label.dtype]
            ))
            
            ds = ds.batch(batch_size)
            # ds = ds.cache().prefetch(buffer_size=AUTOTUNE)
            ds = ds.prefetch(buffer_size=AUTOTUNE)
            tf_datasets[split]['Multi_Output'] = ds

        else:
            print("Unknown problem type specified in config. Please check.")

    return tf_datasets



# Image Augmentation and Preprocessing

def create_preprocessing_layers() -> keras.Sequential:
    """Create preprocessing layers for resizing and rescaling images."""
    img_size = config['Model']['IMG_SIZE']
    return keras.Sequential([
        layers.Resizing(img_size, img_size),
        layers.Rescaling(1./255)
    ])

def create_augmentation_layers() -> keras.Sequential:
    """Create data augmentation layers."""
    aug_config = config['Augmentation']
    try:
        return keras.Sequential([
            layers.RandomFlip("horizontal"),
            layers.RandomFlip("vertical"),
            layers.RandomRotation(aug_config['rotation_factor']),
            layers.RandomTranslation(
                height_factor=aug_config['height_factor'],
                width_factor=aug_config['width_factor'],
                fill_mode="reflect"
            ),
            layers.RandomContrast(aug_config['contrast_factor']),
        ])
        
    except Exception as e:
        print(f"An error occurred while creating augmentation layers: {e}")
        return None

def read_and_convert_image(file_path: str) -> tf.Tensor:
    """Read an image from a file and convert it to a 3-channel tensor."""
    image = cv2.imread(file_path, cv2.IMREAD_GRAYSCALE)
    if image is None:
        print("Failed to read the image.")
        return None
    image = tf.convert_to_tensor(image, dtype=tf.float32)
    image = tf.expand_dims(image, axis=-1)
    return tf.image.grayscale_to_rgb(image)

# %% [markdown]
# ### Resample Datasets to deal with Imbalances

# %%
from sklearn.utils import resample
import pandas as pd

def validate_inputs(datasets, resample_label, resample_strategy):
    """
    Validates the inputs provided to the resampling function.
    """
    
    # Ensure that datasets is a dictionary
    if not isinstance(datasets, dict):
        raise ValueError("Input datasets should be a dictionary.")
    
    # Check if resample_strategy is one of the allowed values
    if resample_strategy not in ["upsample", "downsample", "combined"]:
        raise ValueError("Invalid resample_strategy. Choose from 'upsample', 'downsample', or 'combined'.")
    
    # Ensure the resample_label exists in all the datasets
    for key, df in datasets.items():
        if resample_label not in df.columns:
            raise ValueError(f"'{resample_label}' is not a valid column in the {key} dataset.")

def iterative_resampling(df, label_counts, resample_strategy, resample_label):
    """
    Iteratively resample the dataset based on the given resampling strategy.
    """
    
    resampled_data_list = []
    
    # Get the minimum and maximum label counts
    min_count = label_counts.min()
    max_count = label_counts.max()
    
    # If the strategy is "combined", set the target size to the median class size
    if resample_strategy == "combined":
        target_count = int(label_counts.median())
    else:
        target_count = None

    # Iterate over each unique label and resample accordingly
    for unique_label in label_counts.keys():
        subset = df[df[resample_label].apply(tuple) == unique_label]
        count = len(subset)

        # Determine the target count based on resampling strategy
        if resample_strategy == "downsample":
            target_count = min_count
        elif resample_strategy == "upsample":
            target_count = max_count

        # Resample the subset if its count doesn't match the target count
        if count != target_count:
            resampled_data_list.append(resample(subset, replace=(count < target_count), n_samples=target_count))
        else:
            resampled_data_list.append(subset)
            
    # Concatenate the resampled data to form a single dataframe
    return pd.concat(resampled_data_list)


def resample_datasets(datasets, resample_label='Multi_Output_Labels', resample_strategy="downsample"):
    """
    Iteratively resample a multi-class, multi-label (multi-output) dataset that is unbalanced.
    """
    
    # Validate the inputs before processing
    validate_inputs(datasets, resample_label, resample_strategy)
    
    # Identify columns with 'int32' datatype in the input datasets
    int32_columns = [col for col, dtype in datasets.get('train', pd.DataFrame()).dtypes.items() if dtype == 'int32']
    
    resampled_datasets = {}
    
    # Iterate over each dataset (train, test, etc.) and apply resampling only to the training set
    for key, df in datasets.items():
        print(f"Processing {key} dataset...")
        if key == 'train':
            label_counts = df[resample_label].apply(tuple).value_counts()
            resampled_data = iterative_resampling(df, label_counts, resample_strategy, resample_label)
            
            # Shuffle the data and reset its index
            resampled_data = resampled_data.sample(frac=1).reset_index(drop=True)

            # Convert specified columns to 'int32' datatype
            for col in int32_columns:
                resampled_data[col] = resampled_data[col].astype('int32')

            resampled_datasets[key] = resampled_data
        else:
            resampled_datasets[key] = df

    return resampled_datasets

# %% [markdown]
# ## Main Function for Data Preparation

# %%
print("===== Preprocessing CSV Data =====")
data = read_csv(config)
data = update_image_paths(data)
# data = clean_csv(data, save_cleaned=True)
data, label_encoders = generate_labels(data)
data = shuffle_and_reset_index(data)
print("===== Preparing TensorFlow Datasets =====")
datasets = prepare_datasets(data)
df_class_weights = compute_and_store_class_weights(datasets, label_encoders)
resampled_datasets = resample_datasets(datasets, resample_label='Multi_Output_Labels', resample_strategy="upsample")
rdf_class_weights = compute_and_store_class_weights(resampled_datasets, label_encoders)
datasets = create_tf_datasets_from_dfs(datasets, include_offset=True)
resampled_datasets = create_tf_datasets_from_dfs(resampled_datasets, include_offset=True)
print("===== Preprocessing Complete =====")
# Out:
# ===== Preprocessing CSV Data =====
# ---> Data read successfully.
# ---> Image paths updated.
# ---> Generating labels for Focus, StigX, and StigY...
# ---> Labels generated for Focus_Label
# ---> Labels generated for StigX_Label
# ---> Labels generated for StigY_Label
# ---> Multi-Output Labels generated.
# ---> Shuffling and resetting index...
# ---> Data shuffled and index reset.
# ===== Preparing TensorFlow Datasets =====
# ---> Data split into training, validation, and test sets.
# Processing train dataset...
# Processing valid dataset...
# Processing test dataset...
# ===== Preprocessing Complete =====

# %% [markdown]
# ## Visualize the data

# %%
# Show Class Distributions

def add_annotations(ax, bars, sub_df):
    for bar, (_, row) in zip(bars, sub_df.iterrows()):
        x = bar.get_x() + bar.get_width() / 2.0
        y = bar.get_height()
        ax.annotate(f"C: {int(row['Count'])}\nW: {row['Weight']:.2f}", 
                    (x, y), 
                    ha='center', 
                    va='bottom', 
                    fontsize=8)

def plot_single_split(ax, df, split):
    filtered_df = df.loc[split]
    x_ticks = []
    x_tick_locs = []
    
    current_x = 0  # Keep track of the current x-location for ticks
    
    labels = filtered_df.index.get_level_values('label').unique()
    for label in labels:
        sub_df = filtered_df.loc[label]
        bars = ax.bar(sub_df.index, sub_df['Count'], label=f"{label}")
        add_annotations(ax, bars, sub_df)
        
        x_ticks.extend([f"{label}_{cls}" for cls in sub_df.index])
        x_tick_locs.extend([current_x + i for i in range(len(sub_df.index))])
        
        current_x += len(sub_df.index)  # Update the x-location for the next set of bars
    
    ax.legend()
    ax.set_xticks(x_tick_locs)  # Set tick locations
    ax.set_xticklabels(x_ticks, rotation=90, fontsize=8)  # Now set tick labels
    ax.set_title(f"{split.capitalize()} Data")


def plot_dataset_info(df):
    splits = ['train', 'valid', 'test']
    
    fig, axs = plt.subplots(1, len(splits), figsize=(20, 8))
    
    for i, split in enumerate(splits):
        plot_single_split(axs[i], df, split)
        
    plt.tight_layout()
    plt.show()


# Example usage
plot_dataset_info(df_class_weights)
plot_dataset_info(rdf_class_weights)

# %%
import textwrap
import matplotlib.pyplot as plt

def plot_images_from_dataset(label_encoders, config, datasets):
    """
    Plots images, labels, and offsets (if available) from the provided datasets.
    
    Args:
        label_encoders (dict): Dictionary of label encoders for each label key.
        config (dict): Configuration dictionary containing problem type and other parameters.
        datasets (dict): Dictionary of datasets, containing training data for each label key.
        
    Returns:
        None
    """
    label_keys = ['Focus_Label', 'StigX_Label', 'StigY_Label']
    problem_type = config['Experiment']['PROBLEM_TYPE']

    plt.rcParams.update({'font.size': 8})  # Reduce font size
    fig, axes = plt.subplots(3, 3, figsize=(12, 12))  # Enlarge figure size

    if problem_type in ['Multi-Class', 'Binary']:
        for label_key in label_keys:
            label_encoder = label_encoders.get(label_key, None)
            fig.suptitle(f"Images for {label_key}")

            # Take one batch from the training dataset
            for data in datasets['train'][label_key].take(1):
                images, labels = data[:2]
                offsets = data[2] if len(data) > 2 else None  # Include offsets if they exist

                # Loop over the batch to plot images, labels, and offsets
                for i in range(min(len(images), 9)):  # Show up to 9 images
                    ax = axes[i // 3, i % 3]
                    ax.imshow(images[i].numpy())

                    label_value = labels[i].numpy()
                    offset_value = offsets[i].numpy() if offsets is not None else "N/A"

                    # Use label encoder to get original label name if available
                    if label_encoder:
                        label_name = label_encoder.inverse_transform([label_value])[0]
                    else:
                        label_name = label_value

                    ax.set_title(f"{label_name} (Offset: {offset_value})")
                    ax.axis("off")

            plt.tight_layout(rect=[0, 0.03, 1, 0.95])
            plt.show()

    elif problem_type == 'Multi-Output':
        fig.suptitle("Images for Multi-Output")

        # Take one batch from the training dataset
        for data in datasets['train']['Multi_Output'].take(1):
            images, labels = data[:2]
            offsets = data[2] if len(data) > 2 else None  # Include offsets if they exist

            # Loop over the batch to plot images, labels, and offsets
            for i in range(min(len(images), 9)):  # Show up to 9 images
                ax = axes[i // 3, i % 3]
                ax.imshow(images[i].numpy())

                label_values = labels[i].numpy()
                offset_values = offsets[i].numpy() if offsets is not None else ["N/A"] * len(label_keys)
                # Round offset values to 2 decimal places
                offset_values = [f"{offset:.2f}" for offset in offset_values]

                label_names = []
                for label_value, label_key in zip(label_values, label_keys):
                    label_encoder = label_encoders.get(label_key, None)
                    if label_encoder:
                        label_names.append(label_encoder.inverse_transform([label_value])[0])
                    else:
                        label_names.append(str(label_value))

                title_text = ", ".join(f"{name} ({offset})" for name, offset in zip(label_names, offset_values))
                ax.set_title("\n".join(textwrap.wrap(title_text, 30)))  # Wrap text to limit the width
                ax.axis("off")

            plt.tight_layout(rect=[0, 0.03, 1, 0.95])
            plt.show()
    else:
        print("Unknown problem type specified in config. Please check.")

plot_images_from_dataset(label_encoders, config, datasets)

# %% [markdown]
# ## Model Creation

# %% [markdown]
# ### Define the Models

# %%
# Transfer learning models
def create_transfer_model(base_model, input_shape: tuple, num_classes: int, hidden_units: list, dropout_rate: float, regularizer_rate: float) -> keras.Model:
    """Creates a transfer learning model based on a given base model."""
    base_model.trainable = False

    model = keras.Sequential([
        base_model,
        layers.GlobalAveragePooling2D()
    ])

    for units in hidden_units:
        model.add(layers.Dense(units, kernel_regularizer=keras.regularizers.l2(regularizer_rate), bias_regularizer=keras.regularizers.l2(regularizer_rate)))
        model.add(layers.LeakyReLU())
        model.add(layers.Dropout(dropout_rate))
        
    activation, units = determine_activation_and_units(num_classes)
    model.add(layers.Dense(units, activation=activation))

    return model

def create_mobilenetv2_transfer_model(input_shape: tuple, num_classes: int) -> keras.Model:
    """Creates a MobileNetV2 based transfer learning model."""
    base_model = tf.keras.applications.MobileNetV2(input_shape=input_shape, include_top=False, weights='imagenet')
    return create_transfer_model(base_model, input_shape, num_classes, [128, 64], 0.5, 0.001)

def create_inceptionv3_transfer_model(input_shape: tuple, num_classes: int) -> keras.Model:
    """Creates an InceptionV3 based transfer learning model."""
    base_model = tf.keras.applications.InceptionV3(input_shape=input_shape, include_top=False, weights='imagenet')
    return create_transfer_model(base_model, input_shape, num_classes, [128, 64], 0.5, 0.001)

def create_resnet50_transfer_model(input_shape: tuple, num_classes: int) -> keras.Model:
    """Creates a ResNet50 based transfer learning model."""
    base_model = tf.keras.applications.ResNet50(input_shape=input_shape, include_top=False, weights='imagenet')
    return create_transfer_model(base_model, input_shape, num_classes, [256, 128], 0.5, 0.001)

# Define the function to create a basic CNN model
def create_basic_cnn_model(input_shape, num_classes):
    conv2d_filter_size = (3, 3)
    conv2d_activation = 'relu'
    dense_activation = 'relu'
    num_conv_blocks = 3

    model = tf.keras.models.Sequential()

    # Explicitly define the input shape
    model.add(tf.keras.layers.Input(shape=input_shape))

    for _ in range(num_conv_blocks):
        model.add(tf.keras.layers.Conv2D(32 * (2**_), conv2d_filter_size, activation=conv2d_activation, padding='same'))
        model.add(tf.keras.layers.BatchNormalization())
        model.add(tf.keras.layers.MaxPooling2D((2, 2)))

    model.add(tf.keras.layers.GlobalAveragePooling2D())
    model.add(tf.keras.layers.Dense(128, activation=dense_activation))

    activation, units = determine_activation_and_units(num_classes)
    model.add(layers.Dense(units, activation=activation))

    return model

# Define the function to create a small version of the Xception network
def create_small_xception_model(input_shape, num_classes):
    # Input layer
    inputs = keras.Input(shape=input_shape)

    # Entry block: Initial Convolution and BatchNormalization
    x = layers.Rescaling(1.0 / 255)(inputs)
    x = layers.Conv2D(128, 3, strides=2, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    previous_block_activation = x  # Set aside residual for later use

    # Middle flow: Stacking Separable Convolution blocks
    for size in [256, 512, 728]:
        # ReLU activation
        x = layers.Activation("relu")(x)
        # Separable Convolution
        x = layers.SeparableConv2D(size, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        # ReLU activation
        x = layers.Activation("relu")(x)
        # Separable Convolution
        x = layers.SeparableConv2D(size, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        # Max Pooling
        x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

        # Project residual from previous block and add it to the current block
        residual = layers.Conv2D(size, 1, strides=2, padding="same")(previous_block_activation)
        x = layers.add([x, residual])  # Add back residual
        previous_block_activation = x  # Set aside next residual

    # Exit flow: Final Separable Convolution, BatchNormalization, and Global Average Pooling
    x = layers.SeparableConv2D(1024, 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.GlobalAveragePooling2D()(x)

    activation, units = determine_activation_and_units(num_classes)

    # Dropout and Dense output layer
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(units, activation=activation)(x)

    return keras.Model(inputs, outputs)

# Model Selection function to select which model to use
def select_model(model_name: str, input_shape: tuple, num_classes: int) -> keras.Model:
    """Selects a model to use based on the given model name."""
    model_map = {
        "mobilenetv2": create_mobilenetv2_transfer_model,
        "inceptionv3": create_inceptionv3_transfer_model,
        "resnet50": create_resnet50_transfer_model,
        "small_xception": create_small_xception_model,
        "basic_cnn": create_basic_cnn_model
    }
    if model_name not in model_map:
        raise ValueError("Invalid model name")

    return model_map[model_name](input_shape, num_classes)

def determine_activation_and_units(num_classes: int) -> tuple:
    """Determine the activation function and units based on the number of classes and problem type from config."""
    problem_type = config.get('Experiment').get('PROBLEM_TYPE')
    if problem_type == 'Multi-Label':
        return "sigmoid", num_classes
    elif problem_type == 'Binary' or num_classes == 2:
        return "sigmoid", 1
    elif problem_type in ['Multi-Class', 'Multi-Output']:         
        # For multi-output, we can treat each output independently.
        # Here we assume each output is a multi-class problem.
        return "softmax", num_classes
    else:
        raise ValueError(f"Invalid problem_type: {problem_type}")

# %% [markdown]
# ### Compile the Models

# %%
from tensorflow import keras
from tensorflow.keras import callbacks, optimizers
import os
from datetime import datetime

# Constants & Configurations
LOSS_CONFIG = {
    'Binary': 'binary_crossentropy',
    'Multi-Class': 'categorical_crossentropy',
    'Multi-Output': 'categorical_crossentropy',
    'Multi-Label': 'binary_crossentropy'
}

RECOMMENDED_METRICS = {
    'Binary': ['accuracy', 'binary_crossentropy', 'mean_squared_error'],
    'Multi-Class': ['categorical_accuracy', 'categorical_crossentropy', 'mean_squared_error'],
    'Multi-Output': ['categorical_accuracy', 'categorical_crossentropy', 'mean_squared_error'],
    'Multi-Label': ['binary_accuracy', 'binary_crossentropy', 'mean_squared_error']
}

# Helper Functions
def get_accuracy_metric(problem_type):
    """Determine the accuracy metric based on the problem type."""
    metric_map = {
        'Binary': "accuracy",
        'Multi-Label': "binary_accuracy",
    }
    return metric_map.get(problem_type, "categorical_accuracy")


def create_directory(path):
    """Create a directory if it doesn't exist."""
    os.makedirs(path, exist_ok=True)


# Callback Setup Functions
def setup_common_callbacks():
    """Set up common callbacks."""
    return [
        callbacks.EarlyStopping(
            patience=config['Model']['EARLY_STOPPING_PATIENCE'], 
            restore_best_weights=True
        ),
        callbacks.ReduceLROnPlateau(
            patience=config['Model']['REDUCE_LR_PATIENCE'], 
            min_lr=config['Model']['MIN_LR']
        )
    ]


def setup_specific_callbacks(model_name, model_dir, problem_type):
    """Set up model-specific callbacks."""
    datetime_str = datetime.now().strftime("%Y%m%d-%I%M%S%p")
    acc_metric = get_accuracy_metric(problem_type)
    
    checkpoint_path = os.path.join(
        model_dir, 
        f"saved_model_{datetime_str}_epoch_{{epoch}}_val_loss_{{val_loss:.2f}}_{acc_metric}_{{{{val_{acc_metric}:.2f}}}}.h5"
    )
    return [
        callbacks.ModelCheckpoint(checkpoint_path, save_best_only=True),
        callbacks.TensorBoard(log_dir=os.path.join(model_dir, "logs", datetime_str))
    ]


# Model Compilation Functions
def compile_model(model_name, input_shape, num_classes, problem_type):
    """Compile and return a model."""
    model = select_model(model_name, input_shape, num_classes)
    metrics_to_use = RECOMMENDED_METRICS.get(problem_type, ['accuracy'])
    loss_to_use = LOSS_CONFIG.get(problem_type, 'categorical_crossentropy')

    model.compile(
        optimizer=keras.optimizers.Adam(config['Model']['LEARNING_RATE']), 
        loss=loss_to_use, 
        metrics=metrics_to_use
    )
    model.summary()
    return model


def compile_and_initialize_models():
    """Main function to compile and initialize models."""
    input_shape = (config['Model']['IMG_SIZE'], config['Model']['IMG_SIZE'], 3)
    num_classes = 3
    problem_type = config['Experiment']['PROBLEM_TYPE']

    experiment_name = f"{config['Experiment']['NAME']}"
    base_dir = f"./{experiment_name}"
    create_directory(base_dir)

    common_callbacks = setup_common_callbacks()
    label_names = config['Labels']['MAPPINGS'].keys() if problem_type == 'Multi-Class' else ['']

    compiled_models = {}
    for label_name in label_names:
        label_dir = os.path.join(base_dir, label_name)
        create_directory(label_dir)

        for model_name in ['mobilenetv2', 'inceptionv3', 'resnet50', 'small_xception', 'basic_cnn']:
            model_dir = os.path.join(label_dir, model_name)
            create_directory(model_dir)
            
            specific_callbacks = setup_specific_callbacks(model_name, model_dir, problem_type)
            all_callbacks = common_callbacks + specific_callbacks
            
            model = compile_model(model_name, input_shape, num_classes, problem_type)
            compiled_models[model_name] = {'model': model, 'callbacks': all_callbacks}
    
    return compiled_models

# Execution
compiled_models = compile_and_initialize_models()
print("Models compiled and initialized successfully.")
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenetv2_1.00_224 (Funct  (None, 7, 7, 1280)       2257984
#  ional)
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)               163968
#
#  leaky_re_lu (LeakyReLU)     (None, 128)               0
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 64)                0
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 2,430,403
# Trainable params: 172,419
# Non-trainable params: 2,257,984
# _________________________________________________________________
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 5, 5, 2048)        21802784
#
#  global_average_pooling2d_1   (None, 2048)             0
#  (GlobalAveragePooling2D)
#
#  dense_3 (Dense)             (None, 128)               262272
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 128)               0
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 64)                0
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 22,073,507
# Trainable params: 270,723
# Non-trainable params: 21,802,784
# _________________________________________________________________
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  global_average_pooling2d_2   (None, 2048)             0
#  (GlobalAveragePooling2D)
#
#  dense_6 (Dense)             (None, 256)               524544
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 256)               0
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_7 (Dense)             (None, 128)               32896
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 128)               0
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_8 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 24,145,539
# Trainable params: 557,827
# Non-trainable params: 23,587,712
# _________________________________________________________________
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  rescaling_2 (Rescaling)        (None, 224, 224, 3)  0           ['input_4[0][0]']
#
#  conv2d_94 (Conv2D)             (None, 112, 112, 12  3584        ['rescaling_2[0][0]']
#                                 8)
#
#  batch_normalization_94 (BatchN  (None, 112, 112, 12  512        ['conv2d_94[0][0]']
#  ormalization)                  8)
#
#  activation_94 (Activation)     (None, 112, 112, 12  0           ['batch_normalization_94[0][0]']
#                                 8)
#
#  activation_95 (Activation)     (None, 112, 112, 12  0           ['activation_94[0][0]']
#                                 8)
#
#  separable_conv2d (SeparableCon  (None, 112, 112, 25  34176      ['activation_95[0][0]']
#  v2D)                           6)
#
#  batch_normalization_95 (BatchN  (None, 112, 112, 25  1024       ['separable_conv2d[0][0]']
#  ormalization)                  6)
#
#  activation_96 (Activation)     (None, 112, 112, 25  0           ['batch_normalization_95[0][0]']
#                                 6)
#
#  separable_conv2d_1 (SeparableC  (None, 112, 112, 25  68096      ['activation_96[0][0]']
#  onv2D)                         6)
#
#  batch_normalization_96 (BatchN  (None, 112, 112, 25  1024       ['separable_conv2d_1[0][0]']
#  ormalization)                  6)
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 56, 56, 256)  0          ['batch_normalization_96[0][0]']
#
#  conv2d_95 (Conv2D)             (None, 56, 56, 256)  33024       ['activation_94[0][0]']
#
#  add (Add)                      (None, 56, 56, 256)  0           ['max_pooling2d_4[0][0]',
#                                                                   'conv2d_95[0][0]']
#
#  activation_97 (Activation)     (None, 56, 56, 256)  0           ['add[0][0]']
#
#  separable_conv2d_2 (SeparableC  (None, 56, 56, 512)  133888     ['activation_97[0][0]']
#  onv2D)
#
#  batch_normalization_97 (BatchN  (None, 56, 56, 512)  2048       ['separable_conv2d_2[0][0]']
#  ormalization)
#
#  activation_98 (Activation)     (None, 56, 56, 512)  0           ['batch_normalization_97[0][0]']
#
#  separable_conv2d_3 (SeparableC  (None, 56, 56, 512)  267264     ['activation_98[0][0]']
#  onv2D)
#
#  batch_normalization_98 (BatchN  (None, 56, 56, 512)  2048       ['separable_conv2d_3[0][0]']
#  ormalization)
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 28, 28, 512)  0          ['batch_normalization_98[0][0]']
#
#  conv2d_96 (Conv2D)             (None, 28, 28, 512)  131584      ['add[0][0]']
#
#  add_1 (Add)                    (None, 28, 28, 512)  0           ['max_pooling2d_5[0][0]',
#                                                                   'conv2d_96[0][0]']
#
#  activation_99 (Activation)     (None, 28, 28, 512)  0           ['add_1[0][0]']
#
#  separable_conv2d_4 (SeparableC  (None, 28, 28, 728)  378072     ['activation_99[0][0]']
#  onv2D)
#
#  batch_normalization_99 (BatchN  (None, 28, 28, 728)  2912       ['separable_conv2d_4[0][0]']
#  ormalization)
#
#  activation_100 (Activation)    (None, 28, 28, 728)  0           ['batch_normalization_99[0][0]']
#
#  separable_conv2d_5 (SeparableC  (None, 28, 28, 728)  537264     ['activation_100[0][0]']
#  onv2D)
#
#  batch_normalization_100 (Batch  (None, 28, 28, 728)  2912       ['separable_conv2d_5[0][0]']
#  Normalization)
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 14, 14, 728)  0          ['batch_normalization_100[0][0]']
#
#  conv2d_97 (Conv2D)             (None, 14, 14, 728)  373464      ['add_1[0][0]']
#
#  add_2 (Add)                    (None, 14, 14, 728)  0           ['max_pooling2d_6[0][0]',
#                                                                   'conv2d_97[0][0]']
#
#  separable_conv2d_6 (SeparableC  (None, 14, 14, 1024  753048     ['add_2[0][0]']
#  onv2D)                         )
#
#  batch_normalization_101 (Batch  (None, 14, 14, 1024  4096       ['separable_conv2d_6[0][0]']
#  Normalization)                 )
#
#  activation_101 (Activation)    (None, 14, 14, 1024  0           ['batch_normalization_101[0][0]']
#                                 )
#
#  global_average_pooling2d_3 (Gl  (None, 1024)        0           ['activation_101[0][0]']
#  obalAveragePooling2D)
#
#  dropout_6 (Dropout)            (None, 1024)         0           ['global_average_pooling2d_3[0][0
#                                                                  ]']
#
#  dense_9 (Dense)                (None, 3)            3075        ['dropout_6[0][0]']
#
# ==================================================================================================
# Total params: 2,733,115
# Trainable params: 2,724,827
# Non-trainable params: 8,288
# __________________________________________________________________________________________________
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_98 (Conv2D)          (None, 224, 224, 32)      896
#
#  batch_normalization_102 (Ba  (None, 224, 224, 32)     128
#  tchNormalization)
#
#  max_pooling2d_7 (MaxPooling  (None, 112, 112, 32)     0
#  2D)
#
#  conv2d_99 (Conv2D)          (None, 112, 112, 64)      18496
#
#  batch_normalization_103 (Ba  (None, 112, 112, 64)     256
#  tchNormalization)
#
#  max_pooling2d_8 (MaxPooling  (None, 56, 56, 64)       0
#  2D)
#
#  conv2d_100 (Conv2D)         (None, 56, 56, 128)       73856
#
#  batch_normalization_104 (Ba  (None, 56, 56, 128)      512
#  tchNormalization)
#
#  max_pooling2d_9 (MaxPooling  (None, 28, 28, 128)      0
#  2D)
#
#  global_average_pooling2d_4   (None, 128)              0
#  (GlobalAveragePooling2D)
#
#  dense_10 (Dense)            (None, 128)               16512
#
#  dense_11 (Dense)            (None, 3)                 387
#
# =================================================================
# Total params: 111,043
# Trainable params: 110,595
# Non-trainable params: 448
# _________________________________________________________________
# Models compiled and initialized successfully.

# %% [markdown]
# ## Train the Models

# %% [markdown]
# ### Preparing Training Inputs

# %%
# Prepare class weights for training

def prepare_class_weights_for_multi_output(info: pd.DataFrame) -> Union[Dict[str, Dict[int, float]], None]:
    """
    Prepare class weights for multi-output problems for Keras and TensorFlow.
    
    Parameters:
    - info: DataFrame containing the class weights information
    - config: Configuration dictionary.
    
    Returns:
    - Dictionary mapping output layer names to their respective class weight dictionaries or None
    """
    if not config.get('USE_CLASS_WEIGHTS', True):
        print("Configuration says not to use class weights. Returning None.")
        return None

    class_weights = {}
    for label in info.index.get_level_values('label').unique():
        class_weights[label] = {}
        sub_df = info.loc[(slice(None), label), :]
        for idx, row in sub_df.iterrows():
            class_idx = label_encoders[label].transform([idx[2]])[0]  # Transforming class name to class index
            class_weights[label][class_idx] = row['Weight']
    return class_weights

# Additions to the config
config['USE_CLASS_WEIGHTS'] = False  # Decide whether to use class weights or not

prepared_class_weights = prepare_class_weights_for_multi_output(df_class_weights)
print(prepared_class_weights)
# Out:
# Configuration says not to use class weights. Returning None.
# None

# %%
# Preparing datasets for training

def inspect_dataset_content(dataset, name, num_batches=3):
    """
    Inspect the content of the dataset to determine the nature of the tensors.
    
    Parameters:
    - dataset: A TensorFlow dataset.
    - name: The name of the dataset ('Train', 'Validation', 'Test')
    - num_batches: Number of batches to inspect from the dataset.
    """
    print(f"Inspecting first few records of {name} dataset...")
    
    for i, record in enumerate(dataset.take(num_batches)):
        summary = {k: (v.shape, v.dtype) for k, v in enumerate(record)}
        print(f"{name} record {i + 1}: {summary}")
        
    print(f"Inspecting unique values in {name} dataset...")
    
    for i, batch in enumerate(dataset.take(num_batches)):
        print(f"Batch {i + 1} content:")
        
        for j, tensor in enumerate(batch):
            # Check unique values in each tensor
            unique_values = tf.unique(tf.reshape(tensor, [-1])).y.numpy()
            print(f"Unique values in tensor {j}: {unique_values}")
        
        print("------")

# Function to select appropriate tensors from the dataset
def select_tensors(*tensors):
    return tensors[0], tensors[1]  # Return only the image and label tensors

def prepare_datasets_for_training(raw_datasets):
    """
    Prepare and inspect datasets for training.

    Parameters:
    - raw_datasets: A dictionary containing raw TensorFlow datasets.

    Returns:
    - prepared_datasets: A dictionary containing prepared TensorFlow datasets for training, validation, and testing.
    """
    # Check if the dataset dictionary is None
    if raw_datasets is None:
        print("Datasets dictionary is None. Exiting.")
        return None

    # Separate datasets into train, valid, and test
    train_dataset = raw_datasets.get('train', {}).get('Multi_Output')
    valid_dataset = raw_datasets.get('valid', {}).get('Multi_Output')
    test_dataset = raw_datasets.get('test', {}).get('Multi_Output')
    
    # Select appropriate tensors for training and validation
    train_dataset = train_dataset.map(select_tensors)
    valid_dataset = valid_dataset.map(select_tensors)
    test_dataset = test_dataset.map(select_tensors)

    if train_dataset is None or valid_dataset is None or test_dataset is None:
        print("One or more datasets are None. Exiting.")
        return None

    # Inspect the datasets
    # for name, dataset in [('Train', train_dataset), ('Validation', valid_dataset), ('Test', test_dataset)]:
    #     inspect_dataset_content(dataset, name)

    return train_dataset, valid_dataset, test_dataset

# Uncomment this line to run the function with your datasets
# train_dataset, valid_dataset, test_dataset = prepare_datasets_for_training(datasets)
train_dataset, valid_dataset, test_dataset = prepare_datasets_for_training(resampled_datasets)

# %% [markdown]
# ### Training the Models

# %%
from tensorflow.keras.callbacks import Callback
import pandas as pd
import os

class ExcelMetricsSaver(Callback):
    def __init__(self, writer, sheet_name):
        super().__init__()
        self.writer = writer
        self.sheet_name = sheet_name

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        logs['epoch'] = epoch + 1 # Add epoch number to logs
        epoch_df = pd.DataFrame([logs])
        if epoch == 0:
            epoch_df.to_excel(self.writer, sheet_name=self.sheet_name, index=False)
        else:
            book = self.writer.book
            writer_sheets = self.writer.sheets
            worksheet = writer_sheets[self.sheet_name]
            start_row = worksheet.max_row
            epoch_df.to_excel(self.writer, sheet_name=self.sheet_name, startrow=start_row, header=False, index=False)


def train_and_save_metrics(train_dataset, valid_dataset, test_dataset, compiled_models, prepared_class_weights):
    try:
        if train_dataset is None or valid_dataset is None or test_dataset is None:
            print("One or more datasets are None. Exiting.")
            return

        excel_filename = f"{config['Experiment']['NAME']}.xlsx"
        excel_path = os.path.join("./", excel_filename)

        with pd.ExcelWriter(excel_path, engine='openpyxl') as writer:
            for model_name, model_info in compiled_models.items():
                model = model_info.get('model')
                callbacks = model_info.get('callbacks')

                if model is None or callbacks is None:
                    print(f"Model or callbacks for {model_name} are None. Skipping.")
                    continue

                print(f"Training {model_name} for multi-output...")
                
                excel_saver = ExcelMetricsSaver(writer, sheet_name=f"{model_name}")
                callbacks.append(excel_saver)

                history = model.fit(
                    train_dataset,
                    validation_data=valid_dataset,
                    epochs=config['Model']['EPOCHS'],
                    class_weight=prepared_class_weights,
                    callbacks=callbacks
                )

                print(f"\nTraining for {model_name} completed.")

        print(f"\nSaved all metrics to {excel_path}")

    except Exception as e:
        print(f"\nAn error occurred: {e}")

# %%
train_and_save_metrics(train_dataset, valid_dataset, test_dataset, compiled_models, prepared_class_weights)
# Out:
# Training mobilenetv2 for multi-output...
# Epoch 1/100
# 75/75 [==============================] - 42s 433ms/step - loss: 3.9944 - categorical_accuracy: 0.4234 - categorical_crossentropy: 3.6902 - mean_squared_error: 1.0918 - val_loss: 3.3889 - val_categorical_accuracy: 0.7806 - val_categorical_crossentropy: 3.0947 - val_mean_squared_error: 0.6404 - lr: 0.0010 - epoch: 1.0000
# Epoch 2/100
# 75/75 [==============================] - 30s 399ms/step - loss: 3.5856 - categorical_accuracy: 0.4470 - categorical_crossentropy: 3.2993 - mean_squared_error: 1.0645 - val_loss: 3.2557 - val_categorical_accuracy: 0.8178 - val_categorical_crossentropy: 2.9773 - val_mean_squared_error: 0.6342 - lr: 0.0010 - epoch: 2.0000
# Epoch 3/100
# 75/75 [==============================] - 30s 406ms/step - loss: 3.5259 - categorical_accuracy: 0.4579 - categorical_crossentropy: 3.2543 - mean_squared_error: 1.0592 - val_loss: 3.3292 - val_categorical_accuracy: 0.8541 - val_categorical_crossentropy: 3.0645 - val_mean_squared_error: 0.6380 - lr: 0.0010 - epoch: 3.0000
# Epoch 4/100
# 75/75 [==============================] - 29s 393ms/step - loss: 3.4209 - categorical_accuracy: 0.5109 - categorical_crossentropy: 3.1621 - mean_squared_error: 1.0426 - val_loss: 3.3071 - val_categorical_accuracy: 0.7786 - val_categorical_crossentropy: 3.0549 - val_mean_squared_error: 0.6334 - lr: 0.0010 - epoch: 4.0000
# Epoch 5/100
# 75/75 [==============================] - 30s 395ms/step - loss: 3.4204 - categorical_accuracy: 0.5185 - categorical_crossentropy: 3.1739 - mean_squared_error: 1.0483 - val_loss: 3.1668 - val_categorical_accuracy: 0.7669 - val_categorical_crossentropy: 2.9263 - val_mean_squared_error: 0.6309 - lr: 0.0010 - epoch: 5.0000
# Epoch 6/100
# 75/75 [==============================] - 29s 392ms/step - loss: 3.3513 - categorical_accuracy: 0.5387 - categorical_crossentropy: 3.1159 - mean_squared_error: 1.0388 - val_loss: 3.1789 - val_categorical_accuracy: 0.7718 - val_categorical_crossentropy: 2.9491 - val_mean_squared_error: 0.6295 - lr: 0.0010 - epoch: 6.0000
# Epoch 7/100
# 75/75 [==============================] - 30s 398ms/step - loss: 3.3429 - categorical_accuracy: 0.5589 - categorical_crossentropy: 3.1179 - mean_squared_error: 1.0374 - val_loss: 3.1674 - val_categorical_accuracy: 0.8433 - val_categorical_crossentropy: 2.9472 - val_mean_squared_error: 0.6286 - lr: 0.0010 - epoch: 7.0000
# Epoch 8/100
# 75/75 [==============================] - 29s 392ms/step - loss: 3.3232 - categorical_accuracy: 0.5455 - categorical_crossentropy: 3.1076 - mean_squared_error: 1.0368 - val_loss: 3.1986 - val_categorical_accuracy: 0.8639 - val_categorical_crossentropy: 2.9874 - val_mean_squared_error: 0.6291 - lr: 0.0010 - epoch: 8.0000
# Epoch 9/100
# 75/75 [==============================] - 30s 395ms/step - loss: 3.2869 - categorical_accuracy: 0.5724 - categorical_crossentropy: 3.0763 - mean_squared_error: 1.0359 - val_loss: 3.1656 - val_categorical_accuracy: 0.8531 - val_categorical_crossentropy: 2.9556 - val_mean_squared_error: 0.6272 - lr: 1.0000e-04 - epoch: 9.0000
# Epoch 10/100
# 75/75 [==============================] - 29s 391ms/step - loss: 3.2758 - categorical_accuracy: 0.5918 - categorical_crossentropy: 3.0665 - mean_squared_error: 1.0334 - val_loss: 3.1614 - val_categorical_accuracy: 0.8541 - val_categorical_crossentropy: 2.9526 - val_mean_squared_error: 0.6267 - lr: 1.0000e-04 - epoch: 10.0000
# Epoch 11/100
# 75/75 [==============================] - 29s 386ms/step - loss: 3.2535 - categorical_accuracy: 0.5791 - categorical_crossentropy: 3.0453 - mean_squared_error: 1.0300 - val_loss: 3.1886 - val_categorical_accuracy: 0.8472 - val_categorical_crossentropy: 2.9811 - val_mean_squared_error: 0.6261 - lr: 1.0000e-04 - epoch: 11.0000
# Epoch 12/100
# 75/75 [==============================] - 31s 409ms/step - loss: 3.2578 - categorical_accuracy: 0.5816 - categorical_crossentropy: 3.0509 - mean_squared_error: 1.0296 - val_loss: 3.1415 - val_categorical_accuracy: 0.8472 - val_categorical_crossentropy: 2.9353 - val_mean_squared_error: 0.6256 - lr: 1.0000e-04 - epoch: 12.0000
# Epoch 13/100
# 75/75 [==============================] - 30s 405ms/step - loss: 3.2308 - categorical_accuracy: 0.5934 - categorical_crossentropy: 3.0252 - mean_squared_error: 1.0245 - val_loss: 3.1306 - val_categorical_accuracy: 0.8394 - val_categorical_crossentropy: 2.9257 - val_mean_squared_error: 0.6252 - lr: 1.0000e-04 - epoch: 13.0000
# Epoch 14/100
# 75/75 [==============================] - 29s 393ms/step - loss: 3.2256 - categorical_accuracy: 0.6019 - categorical_crossentropy: 3.0213 - mean_squared_error: 1.0237 - val_loss: 3.1279 - val_categorical_accuracy: 0.8413 - val_categorical_crossentropy: 2.9243 - val_mean_squared_error: 0.6246 - lr: 1.0000e-04 - epoch: 14.0000
# Epoch 15/100
# 75/75 [==============================] - 29s 394ms/step - loss: 3.2236 - categorical_accuracy: 0.6069 - categorical_crossentropy: 3.0206 - mean_squared_error: 1.0220 - val_loss: 3.1460 - val_categorical_accuracy: 0.8423 - val_categorical_crossentropy: 2.9437 - val_mean_squared_error: 0.6244 - lr: 1.0000e-04 - epoch: 15.0000
# Epoch 16/100
# 75/75 [==============================] - 29s 388ms/step - loss: 3.2234 - categorical_accuracy: 0.6061 - categorical_crossentropy: 3.0217 - mean_squared_error: 1.0238 - val_loss: 3.1337 - val_categorical_accuracy: 0.8433 - val_categorical_crossentropy: 2.9327 - val_mean_squared_error: 0.6236 - lr: 1.0000e-04 - epoch: 16.0000
# Epoch 17/100
# 75/75 [==============================] - 29s 386ms/step - loss: 3.2152 - categorical_accuracy: 0.6221 - categorical_crossentropy: 3.0149 - mean_squared_error: 1.0211 - val_loss: 3.1291 - val_categorical_accuracy: 0.8433 - val_categorical_crossentropy: 2.9294 - val_mean_squared_error: 0.6230 - lr: 1.0000e-04 - epoch: 17.0000
# Epoch 18/100
# 75/75 [==============================] - 29s 391ms/step - loss: 3.2176 - categorical_accuracy: 0.5951 - categorical_crossentropy: 3.0180 - mean_squared_error: 1.0224 - val_loss: 3.1385 - val_categorical_accuracy: 0.8443 - val_categorical_crossentropy: 2.9390 - val_mean_squared_error: 0.6230 - lr: 1.0000e-05 - epoch: 18.0000
# Epoch 19/100
# 75/75 [==============================] - 30s 396ms/step - loss: 3.2138 - categorical_accuracy: 0.5985 - categorical_crossentropy: 3.0143 - mean_squared_error: 1.0202 - val_loss: 3.1407 - val_categorical_accuracy: 0.8443 - val_categorical_crossentropy: 2.9413 - val_mean_squared_error: 0.6229 - lr: 1.0000e-05 - epoch: 19.0000
# Epoch 20/100
# 75/75 [==============================] - 29s 393ms/step - loss: 3.2082 - categorical_accuracy: 0.6406 - categorical_crossentropy: 3.0089 - mean_squared_error: 1.0215 - val_loss: 3.1390 - val_categorical_accuracy: 0.8452 - val_categorical_crossentropy: 2.9398 - val_mean_squared_error: 0.6228 - lr: 1.0000e-05 - epoch: 20.0000
# Epoch 21/100
# 75/75 [==============================] - 30s 399ms/step - loss: 3.2091 - categorical_accuracy: 0.6170 - categorical_crossentropy: 3.0099 - mean_squared_error: 1.0205 - val_loss: 3.1387 - val_categorical_accuracy: 0.8452 - val_categorical_crossentropy: 2.9395 - val_mean_squared_error: 0.6229 - lr: 1.0000e-06 - epoch: 21.0000
# Epoch 22/100
# 75/75 [==============================] - 29s 390ms/step - loss: 3.2041 - categorical_accuracy: 0.6052 - categorical_crossentropy: 3.0049 - mean_squared_error: 1.0197 - val_loss: 3.1392 - val_categorical_accuracy: 0.8462 - val_categorical_crossentropy: 2.9400 - val_mean_squared_error: 0.6229 - lr: 1.0000e-06 - epoch: 22.0000
# Epoch 23/100
# 75/75 [==============================] - 29s 391ms/step - loss: 3.2108 - categorical_accuracy: 0.6279 - categorical_crossentropy: 3.0116 - mean_squared_error: 1.0194 - val_loss: 3.1385 - val_categorical_accuracy: 0.8452 - val_categorical_crossentropy: 2.9393 - val_mean_squared_error: 0.6228 - lr: 1.0000e-06 - epoch: 23.0000
# Epoch 24/100
# 75/75 [==============================] - 30s 401ms/step - loss: 3.2133 - categorical_accuracy: 0.6061 - categorical_crossentropy: 3.0141 - mean_squared_error: 1.0222 - val_loss: 3.1386 - val_categorical_accuracy: 0.8452 - val_categorical_crossentropy: 2.9394 - val_mean_squared_error: 0.6229 - lr: 1.0000e-06 - epoch: 24.0000
# Epoch 25/100
# 75/75 [==============================] - 29s 390ms/step - loss: 3.2061 - categorical_accuracy: 0.6162 - categorical_crossentropy: 3.0069 - mean_squared_error: 1.0190 - val_loss: 3.1388 - val_categorical_accuracy: 0.8452 - val_categorical_crossentropy: 2.9396 - val_mean_squared_error: 0.6229 - lr: 1.0000e-06 - epoch: 25.0000
# Epoch 26/100
# 75/75 [==============================] - 29s 389ms/step - loss: 3.2154 - categorical_accuracy: 0.6094 - categorical_crossentropy: 3.0162 - mean_squared_error: 1.0233 - val_loss: 3.1381 - val_categorical_accuracy: 0.8462 - val_categorical_crossentropy: 2.9390 - val_mean_squared_error: 0.6229 - lr: 1.0000e-06 - epoch: 26.0000
# Epoch 27/100
# 75/75 [==============================] - 30s 406ms/step - loss: 3.2007 - categorical_accuracy: 0.6170 - categorical_crossentropy: 3.0015 - mean_squared_error: 1.0178 - val_loss: 3.1390 - val_categorical_accuracy: 0.8462 - val_categorical_crossentropy: 2.9399 - val_mean_squared_error: 0.6229 - lr: 1.0000e-06 - epoch: 27.0000
# Epoch 28/100
# 75/75 [==============================] - 29s 388ms/step - loss: 3.2120 - categorical_accuracy: 0.5993 - categorical_crossentropy: 3.0129 - mean_squared_error: 1.0209 - val_loss: 3.1387 - val_categorical_accuracy: 0.8462 - val_categorical_crossentropy: 2.9396 - val_mean_squared_error: 0.6229 - lr: 1.0000e-06 - epoch: 28.0000
# Epoch 29/100
# 75/75 [==============================] - 29s 391ms/step - loss: 3.2133 - categorical_accuracy: 0.6178 - categorical_crossentropy: 3.0141 - mean_squared_error: 1.0215 - val_loss: 3.1385 - val_categorical_accuracy: 0.8462 - val_categorical_crossentropy: 2.9394 - val_mean_squared_error: 0.6229 - lr: 1.0000e-06 - epoch: 29.0000
# Epoch 30/100
# 75/75 [==============================] - 29s 393ms/step - loss: 3.2092 - categorical_accuracy: 0.6423 - categorical_crossentropy: 3.0101 - mean_squared_error: 1.0207 - val_loss: 3.1389 - val_categorical_accuracy: 0.8462 - val_categorical_crossentropy: 2.9399 - val_mean_squared_error: 0.6229 - lr: 1.0000e-06 - epoch: 30.0000
# Epoch 31/100
# 75/75 [==============================] - 30s 402ms/step - loss: 3.2117 - categorical_accuracy: 0.5976 - categorical_crossentropy: 3.0127 - mean_squared_error: 1.0202 - val_loss: 3.1393 - val_categorical_accuracy: 0.8462 - val_categorical_crossentropy: 2.9403 - val_mean_squared_error: 0.6229 - lr: 1.0000e-06 - epoch: 31.0000
# Epoch 32/100
# 75/75 [==============================] - 29s 389ms/step - loss: 3.2069 - categorical_accuracy: 0.6347 - categorical_crossentropy: 3.0078 - mean_squared_error: 1.0192 - val_loss: 3.1386 - val_categorical_accuracy: 0.8462 - val_categorical_crossentropy: 2.9396 - val_mean_squared_error: 0.6229 - lr: 1.0000e-06 - epoch: 32.0000
# Epoch 33/100
# 75/75 [==============================] - 30s 395ms/step - loss: 3.2030 - categorical_accuracy: 0.6279 - categorical_crossentropy: 3.0040 - mean_squared_error: 1.0195 - val_loss: 3.1382 - val_categorical_accuracy: 0.8462 - val_categorical_crossentropy: 2.9392 - val_mean_squared_error: 0.6229 - lr: 1.0000e-06 - epoch: 33.0000
# Epoch 34/100
# 75/75 [==============================] - 28s 378ms/step - loss: 3.2100 - categorical_accuracy: 0.6035 - categorical_crossentropy: 3.0109 - mean_squared_error: 1.0211 - val_loss: 3.1383 - val_categorical_accuracy: 0.8472 - val_categorical_crossentropy: 2.9393 - val_mean_squared_error: 0.6228 - lr: 1.0000e-06 - epoch: 34.0000
# Epoch 35/100
# 75/75 [==============================] - 29s 387ms/step - loss: 3.2083 - categorical_accuracy: 0.6204 - categorical_crossentropy: 3.0093 - mean_squared_error: 1.0217 - val_loss: 3.1384 - val_categorical_accuracy: 0.8462 - val_categorical_crossentropy: 2.9394 - val_mean_squared_error: 0.6228 - lr: 1.0000e-06 - epoch: 35.0000
# Epoch 36/100
# 75/75 [==============================] - 29s 394ms/step - loss: 3.2215 - categorical_accuracy: 0.6195 - categorical_crossentropy: 3.0225 - mean_squared_error: 1.0223 - val_loss: 3.1383 - val_categorical_accuracy: 0.8462 - val_categorical_crossentropy: 2.9393 - val_mean_squared_error: 0.6229 - lr: 1.0000e-06 - epoch: 36.0000
# Epoch 37/100
# 75/75 [==============================] - 29s 387ms/step - loss: 3.2070 - categorical_accuracy: 0.6136 - categorical_crossentropy: 3.0080 - mean_squared_error: 1.0213 - val_loss: 3.1385 - val_categorical_accuracy: 0.8462 - val_categorical_crossentropy: 2.9396 - val_mean_squared_error: 0.6229 - lr: 1.0000e-06 - epoch: 37.0000
# Epoch 38/100
# 75/75 [==============================] - 29s 384ms/step - loss: 3.1971 - categorical_accuracy: 0.6204 - categorical_crossentropy: 2.9981 - mean_squared_error: 1.0179 - val_loss: 3.1387 - val_categorical_accuracy: 0.8462 - val_categorical_crossentropy: 2.9398 - val_mean_squared_error: 0.6229 - lr: 1.0000e-06 - epoch: 38.0000
# Epoch 39/100
# 75/75 [==============================] - 30s 400ms/step - loss: 3.2124 - categorical_accuracy: 0.6263 - categorical_crossentropy: 3.0134 - mean_squared_error: 1.0220 - val_loss: 3.1386 - val_categorical_accuracy: 0.8462 - val_categorical_crossentropy: 2.9397 - val_mean_squared_error: 0.6228 - lr: 1.0000e-06 - epoch: 39.0000
# Epoch 40/100
# 75/75 [==============================] - 29s 392ms/step - loss: 3.1986 - categorical_accuracy: 0.6187 - categorical_crossentropy: 2.9997 - mean_squared_error: 1.0176 - val_loss: 3.1388 - val_categorical_accuracy: 0.8462 - val_categorical_crossentropy: 2.9399 - val_mean_squared_error: 0.6228 - lr: 1.0000e-06 - epoch: 40.0000
# Epoch 41/100
# 75/75 [==============================] - 29s 393ms/step - loss: 3.2068 - categorical_accuracy: 0.6094 - categorical_crossentropy: 3.0079 - mean_squared_error: 1.0209 - val_loss: 3.1390 - val_categorical_accuracy: 0.8462 - val_categorical_crossentropy: 2.9401 - val_mean_squared_error: 0.6228 - lr: 1.0000e-06 - epoch: 41.0000
# Epoch 42/100
# 75/75 [==============================] - 28s 370ms/step - loss: 3.2054 - categorical_accuracy: 0.6271 - categorical_crossentropy: 3.0065 - mean_squared_error: 1.0205 - val_loss: 3.1393 - val_categorical_accuracy: 0.8462 - val_categorical_crossentropy: 2.9405 - val_mean_squared_error: 0.6229 - lr: 1.0000e-06 - epoch: 42.0000
# Epoch 43/100
# 75/75 [==============================] - 28s 376ms/step - loss: 3.2016 - categorical_accuracy: 0.6010 - categorical_crossentropy: 3.0028 - mean_squared_error: 1.0204 - val_loss: 3.1392 - val_categorical_accuracy: 0.8462 - val_categorical_crossentropy: 2.9404 - val_mean_squared_error: 0.6229 - lr: 1.0000e-06 - epoch: 43.0000
# Epoch 44/100
# 75/75 [==============================] - 28s 376ms/step - loss: 3.2060 - categorical_accuracy: 0.6086 - categorical_crossentropy: 3.0071 - mean_squared_error: 1.0190 - val_loss: 3.1393 - val_categorical_accuracy: 0.8462 - val_categorical_crossentropy: 2.9404 - val_mean_squared_error: 0.6229 - lr: 1.0000e-06 - epoch: 44.0000
# Epoch 45/100
# 75/75 [==============================] - 28s 374ms/step - loss: 3.2012 - categorical_accuracy: 0.6061 - categorical_crossentropy: 3.0023 - mean_squared_error: 1.0194 - val_loss: 3.1400 - val_categorical_accuracy: 0.8462 - val_categorical_crossentropy: 2.9412 - val_mean_squared_error: 0.6229 - lr: 1.0000e-06 - epoch: 45.0000
# Epoch 46/100
# 75/75 [==============================] - 28s 373ms/step - loss: 3.1979 - categorical_accuracy: 0.6145 - categorical_crossentropy: 2.9991 - mean_squared_error: 1.0173 - val_loss: 3.1399 - val_categorical_accuracy: 0.8462 - val_categorical_crossentropy: 2.9411 - val_mean_squared_error: 0.6228 - lr: 1.0000e-06 - epoch: 46.0000
# Epoch 47/100
# 75/75 [==============================] - 28s 375ms/step - loss: 3.2123 - categorical_accuracy: 0.6187 - categorical_crossentropy: 3.0135 - mean_squared_error: 1.0196 - val_loss: 3.1391 - val_categorical_accuracy: 0.8462 - val_categorical_crossentropy: 2.9404 - val_mean_squared_error: 0.6228 - lr: 1.0000e-06 - epoch: 47.0000
# Epoch 48/100
# 75/75 [==============================] - 28s 377ms/step - loss: 3.2012 - categorical_accuracy: 0.6027 - categorical_crossentropy: 3.0025 - mean_squared_error: 1.0190 - val_loss: 3.1393 - val_categorical_accuracy: 0.8462 - val_categorical_crossentropy: 2.9406 - val_mean_squared_error: 0.6228 - lr: 1.0000e-06 - epoch: 48.0000
# Epoch 49/100
# 75/75 [==============================] - 29s 383ms/step - loss: 3.2023 - categorical_accuracy: 0.6035 - categorical_crossentropy: 3.0036 - mean_squared_error: 1.0179 - val_loss: 3.1401 - val_categorical_accuracy: 0.8462 - val_categorical_crossentropy: 2.9414 - val_mean_squared_error: 0.6229 - lr: 1.0000e-06 - epoch: 49.0000
# Epoch 50/100
# 75/75 [==============================] - 29s 392ms/step - loss: 3.2044 - categorical_accuracy: 0.6052 - categorical_crossentropy: 3.0057 - mean_squared_error: 1.0200 - val_loss: 3.1403 - val_categorical_accuracy: 0.8462 - val_categorical_crossentropy: 2.9416 - val_mean_squared_error: 0.6228 - lr: 1.0000e-06 - epoch: 50.0000
# Epoch 51/100
# 75/75 [==============================] - 29s 386ms/step - loss: 3.2211 - categorical_accuracy: 0.6347 - categorical_crossentropy: 3.0224 - mean_squared_error: 1.0231 - val_loss: 3.1396 - val_categorical_accuracy: 0.8452 - val_categorical_crossentropy: 2.9409 - val_mean_squared_error: 0.6228 - lr: 1.0000e-06 - epoch: 51.0000
# Epoch 52/100
# 75/75 [==============================] - 28s 378ms/step - loss: 3.2095 - categorical_accuracy: 0.6061 - categorical_crossentropy: 3.0108 - mean_squared_error: 1.0206 - val_loss: 3.1390 - val_categorical_accuracy: 0.8452 - val_categorical_crossentropy: 2.9403 - val_mean_squared_error: 0.6229 - lr: 1.0000e-06 - epoch: 52.0000
# Epoch 53/100
# 75/75 [==============================] - 29s 388ms/step - loss: 3.1964 - categorical_accuracy: 0.6296 - categorical_crossentropy: 2.9977 - mean_squared_error: 1.0176 - val_loss: 3.1391 - val_categorical_accuracy: 0.8462 - val_categorical_crossentropy: 2.9404 - val_mean_squared_error: 0.6229 - lr: 1.0000e-06 - epoch: 53.0000
# Epoch 54/100
# 75/75 [==============================] - 28s 375ms/step - loss: 3.2056 - categorical_accuracy: 0.6212 - categorical_crossentropy: 3.0070 - mean_squared_error: 1.0199 - val_loss: 3.1391 - val_categorical_accuracy: 0.8452 - val_categorical_crossentropy: 2.9405 - val_mean_squared_error: 0.6229 - lr: 1.0000e-06 - epoch: 54.0000
# Epoch 55/100
# 75/75 [==============================] - 28s 374ms/step - loss: 3.2078 - categorical_accuracy: 0.6145 - categorical_crossentropy: 3.0092 - mean_squared_error: 1.0191 - val_loss: 3.1393 - val_categorical_accuracy: 0.8452 - val_categorical_crossentropy: 2.9407 - val_mean_squared_error: 0.6228 - lr: 1.0000e-06 - epoch: 55.0000
# Epoch 56/100
# 75/75 [==============================] - 29s 382ms/step - loss: 3.2154 - categorical_accuracy: 0.6044 - categorical_crossentropy: 3.0168 - mean_squared_error: 1.0210 - val_loss: 3.1385 - val_categorical_accuracy: 0.8452 - val_categorical_crossentropy: 2.9400 - val_mean_squared_error: 0.6228 - lr: 1.0000e-06 - epoch: 56.0000
# Epoch 57/100
# 75/75 [==============================] - 29s 383ms/step - loss: 3.1920 - categorical_accuracy: 0.6077 - categorical_crossentropy: 2.9934 - mean_squared_error: 1.0159 - val_loss: 3.1384 - val_categorical_accuracy: 0.8452 - val_categorical_crossentropy: 2.9399 - val_mean_squared_error: 0.6228 - lr: 1.0000e-06 - epoch: 57.0000
# Epoch 58/100
# 75/75 [==============================] - 28s 379ms/step - loss: 3.2104 - categorical_accuracy: 0.6246 - categorical_crossentropy: 3.0119 - mean_squared_error: 1.0189 - val_loss: 3.1375 - val_categorical_accuracy: 0.8452 - val_categorical_crossentropy: 2.9390 - val_mean_squared_error: 0.6228 - lr: 1.0000e-06 - epoch: 58.0000
# Epoch 59/100
# 75/75 [==============================] - 29s 381ms/step - loss: 3.1977 - categorical_accuracy: 0.6187 - categorical_crossentropy: 2.9992 - mean_squared_error: 1.0179 - val_loss: 3.1380 - val_categorical_accuracy: 0.8452 - val_categorical_crossentropy: 2.9394 - val_mean_squared_error: 0.6228 - lr: 1.0000e-06 - epoch: 59.0000
# Epoch 60/100
# 75/75 [==============================] - 29s 385ms/step - loss: 3.2071 - categorical_accuracy: 0.6103 - categorical_crossentropy: 3.0086 - mean_squared_error: 1.0202 - val_loss: 3.1387 - val_categorical_accuracy: 0.8452 - val_categorical_crossentropy: 2.9403 - val_mean_squared_error: 0.6228 - lr: 1.0000e-06 - epoch: 60.0000
# Epoch 61/100
# 75/75 [==============================] - 28s 377ms/step - loss: 3.2108 - categorical_accuracy: 0.6035 - categorical_crossentropy: 3.0124 - mean_squared_error: 1.0210 - val_loss: 3.1383 - val_categorical_accuracy: 0.8452 - val_categorical_crossentropy: 2.9398 - val_mean_squared_error: 0.6228 - lr: 1.0000e-06 - epoch: 61.0000
# Epoch 62/100
# 75/75 [==============================] - 28s 378ms/step - loss: 3.1950 - categorical_accuracy: 0.6128 - categorical_crossentropy: 2.9965 - mean_squared_error: 1.0171 - val_loss: 3.1383 - val_categorical_accuracy: 0.8462 - val_categorical_crossentropy: 2.9399 - val_mean_squared_error: 0.6228 - lr: 1.0000e-06 - epoch: 62.0000
# Epoch 63/100
# 75/75 [==============================] - 28s 379ms/step - loss: 3.2023 - categorical_accuracy: 0.6406 - categorical_crossentropy: 3.0039 - mean_squared_error: 1.0180 - val_loss: 3.1384 - val_categorical_accuracy: 0.8452 - val_categorical_crossentropy: 2.9400 - val_mean_squared_error: 0.6228 - lr: 1.0000e-06 - epoch: 63.0000
# Epoch 64/100
# 75/75 [==============================] - 28s 379ms/step - loss: 3.1872 - categorical_accuracy: 0.6069 - categorical_crossentropy: 2.9888 - mean_squared_error: 1.0159 - val_loss: 3.1384 - val_categorical_accuracy: 0.8462 - val_categorical_crossentropy: 2.9400 - val_mean_squared_error: 0.6228 - lr: 1.0000e-06 - epoch: 64.0000
#
# Training for mobilenetv2 completed.
# Training inceptionv3 for multi-output...
# Epoch 1/100
# 75/75 [==============================] - 34s 416ms/step - loss: 4.8973 - categorical_accuracy: 0.3763 - categorical_crossentropy: 4.5684 - mean_squared_error: 1.1378 - val_loss: 3.3554 - val_categorical_accuracy: 0.8012 - val_categorical_crossentropy: 3.0288 - val_mean_squared_error: 0.6466 - lr: 0.0010 - epoch: 1.0000
# Epoch 2/100
# 75/75 [==============================] - 31s 408ms/step - loss: 3.8624 - categorical_accuracy: 0.4318 - categorical_crossentropy: 3.5391 - mean_squared_error: 1.0820 - val_loss: 3.2832 - val_categorical_accuracy: 0.7453 - val_categorical_crossentropy: 2.9634 - val_mean_squared_error: 0.6410 - lr: 0.0010 - epoch: 2.0000
# Epoch 3/100
# 75/75 [==============================] - 30s 407ms/step - loss: 3.8105 - categorical_accuracy: 0.4217 - categorical_crossentropy: 3.4934 - mean_squared_error: 1.0832 - val_loss: 3.2584 - val_categorical_accuracy: 0.7493 - val_categorical_crossentropy: 2.9445 - val_mean_squared_error: 0.6405 - lr: 0.0010 - epoch: 3.0000
# Epoch 4/100
# 75/75 [==============================] - 30s 399ms/step - loss: 3.7154 - categorical_accuracy: 0.4554 - categorical_crossentropy: 3.4048 - mean_squared_error: 1.0741 - val_loss: 3.2901 - val_categorical_accuracy: 0.8697 - val_categorical_crossentropy: 2.9830 - val_mean_squared_error: 0.6355 - lr: 0.0010 - epoch: 4.0000
# Epoch 5/100
# 75/75 [==============================] - 30s 406ms/step - loss: 3.6356 - categorical_accuracy: 0.4714 - categorical_crossentropy: 3.3321 - mean_squared_error: 1.0700 - val_loss: 3.2526 - val_categorical_accuracy: 0.7718 - val_categorical_crossentropy: 2.9531 - val_mean_squared_error: 0.6418 - lr: 0.0010 - epoch: 5.0000
# Epoch 6/100
# 75/75 [==============================] - 30s 396ms/step - loss: 3.5725 - categorical_accuracy: 0.5042 - categorical_crossentropy: 3.2766 - mean_squared_error: 1.0613 - val_loss: 3.2638 - val_categorical_accuracy: 0.7884 - val_categorical_crossentropy: 2.9718 - val_mean_squared_error: 0.6410 - lr: 0.0010 - epoch: 6.0000
# Epoch 7/100
# 75/75 [==============================] - 30s 401ms/step - loss: 3.5593 - categorical_accuracy: 0.4891 - categorical_crossentropy: 3.2706 - mean_squared_error: 1.0613 - val_loss: 3.2375 - val_categorical_accuracy: 0.8257 - val_categorical_crossentropy: 2.9527 - val_mean_squared_error: 0.6391 - lr: 0.0010 - epoch: 7.0000
# Epoch 8/100
# 75/75 [==============================] - 31s 409ms/step - loss: 3.5330 - categorical_accuracy: 0.4916 - categorical_crossentropy: 3.2520 - mean_squared_error: 1.0585 - val_loss: 3.1944 - val_categorical_accuracy: 0.8599 - val_categorical_crossentropy: 2.9175 - val_mean_squared_error: 0.6348 - lr: 0.0010 - epoch: 8.0000
# Epoch 9/100
# 75/75 [==============================] - 30s 404ms/step - loss: 3.4879 - categorical_accuracy: 0.4891 - categorical_crossentropy: 3.2149 - mean_squared_error: 1.0600 - val_loss: 3.2239 - val_categorical_accuracy: 0.8658 - val_categorical_crossentropy: 2.9547 - val_mean_squared_error: 0.6365 - lr: 0.0010 - epoch: 9.0000
# Epoch 10/100
# 75/75 [==============================] - 31s 414ms/step - loss: 3.4561 - categorical_accuracy: 0.5008 - categorical_crossentropy: 3.1907 - mean_squared_error: 1.0568 - val_loss: 3.1939 - val_categorical_accuracy: 0.8071 - val_categorical_crossentropy: 2.9322 - val_mean_squared_error: 0.6341 - lr: 0.0010 - epoch: 10.0000
# Epoch 11/100
# 75/75 [==============================] - 31s 420ms/step - loss: 3.4234 - categorical_accuracy: 0.5253 - categorical_crossentropy: 3.1658 - mean_squared_error: 1.0499 - val_loss: 3.1662 - val_categorical_accuracy: 0.7914 - val_categorical_crossentropy: 2.9127 - val_mean_squared_error: 0.6334 - lr: 0.0010 - epoch: 11.0000
# Epoch 12/100
# 75/75 [==============================] - 30s 405ms/step - loss: 3.4131 - categorical_accuracy: 0.5236 - categorical_crossentropy: 3.1631 - mean_squared_error: 1.0545 - val_loss: 3.1626 - val_categorical_accuracy: 0.8227 - val_categorical_crossentropy: 2.9163 - val_mean_squared_error: 0.6322 - lr: 0.0010 - epoch: 12.0000
# Epoch 13/100
# 75/75 [==============================] - 30s 399ms/step - loss: 3.3762 - categorical_accuracy: 0.5421 - categorical_crossentropy: 3.1337 - mean_squared_error: 1.0473 - val_loss: 3.1861 - val_categorical_accuracy: 0.8276 - val_categorical_crossentropy: 2.9474 - val_mean_squared_error: 0.6350 - lr: 0.0010 - epoch: 13.0000
# Epoch 14/100
# 75/75 [==============================] - 29s 393ms/step - loss: 3.3566 - categorical_accuracy: 0.5446 - categorical_crossentropy: 3.1214 - mean_squared_error: 1.0508 - val_loss: 3.1642 - val_categorical_accuracy: 0.8247 - val_categorical_crossentropy: 2.9328 - val_mean_squared_error: 0.6298 - lr: 0.0010 - epoch: 14.0000
# Epoch 15/100
# 75/75 [==============================] - 30s 407ms/step - loss: 3.3332 - categorical_accuracy: 0.5522 - categorical_crossentropy: 3.1053 - mean_squared_error: 1.0465 - val_loss: 3.1402 - val_categorical_accuracy: 0.8031 - val_categorical_crossentropy: 2.9161 - val_mean_squared_error: 0.6301 - lr: 0.0010 - epoch: 15.0000
# Epoch 16/100
# 75/75 [==============================] - 30s 404ms/step - loss: 3.3203 - categorical_accuracy: 0.5614 - categorical_crossentropy: 3.0996 - mean_squared_error: 1.0436 - val_loss: 3.1798 - val_categorical_accuracy: 0.8198 - val_categorical_crossentropy: 2.9626 - val_mean_squared_error: 0.6293 - lr: 0.0010 - epoch: 16.0000
# Epoch 17/100
# 75/75 [==============================] - 30s 403ms/step - loss: 3.3099 - categorical_accuracy: 0.5665 - categorical_crossentropy: 3.0961 - mean_squared_error: 1.0429 - val_loss: 3.1149 - val_categorical_accuracy: 0.8139 - val_categorical_crossentropy: 2.9045 - val_mean_squared_error: 0.6306 - lr: 0.0010 - epoch: 17.0000
# Epoch 18/100
# 75/75 [==============================] - 30s 405ms/step - loss: 3.3202 - categorical_accuracy: 0.5572 - categorical_crossentropy: 3.1131 - mean_squared_error: 1.0505 - val_loss: 3.1233 - val_categorical_accuracy: 0.8648 - val_categorical_crossentropy: 2.9196 - val_mean_squared_error: 0.6309 - lr: 0.0010 - epoch: 18.0000
# Epoch 19/100
# 75/75 [==============================] - 30s 405ms/step - loss: 3.2927 - categorical_accuracy: 0.5589 - categorical_crossentropy: 3.0923 - mean_squared_error: 1.0442 - val_loss: 3.1115 - val_categorical_accuracy: 0.8501 - val_categorical_crossentropy: 2.9145 - val_mean_squared_error: 0.6306 - lr: 0.0010 - epoch: 19.0000
# Epoch 20/100
# 75/75 [==============================] - 30s 408ms/step - loss: 3.2851 - categorical_accuracy: 0.5614 - categorical_crossentropy: 3.0913 - mean_squared_error: 1.0458 - val_loss: 3.1133 - val_categorical_accuracy: 0.8345 - val_categorical_crossentropy: 2.9228 - val_mean_squared_error: 0.6304 - lr: 0.0010 - epoch: 20.0000
# Epoch 21/100
# 75/75 [==============================] - 31s 411ms/step - loss: 3.2736 - categorical_accuracy: 0.5631 - categorical_crossentropy: 3.0862 - mean_squared_error: 1.0448 - val_loss: 3.0961 - val_categorical_accuracy: 0.8433 - val_categorical_crossentropy: 2.9117 - val_mean_squared_error: 0.6308 - lr: 0.0010 - epoch: 21.0000
# Epoch 22/100
# 75/75 [==============================] - 36s 477ms/step - loss: 3.2427 - categorical_accuracy: 0.6103 - categorical_crossentropy: 3.0611 - mean_squared_error: 1.0383 - val_loss: 3.1106 - val_categorical_accuracy: 0.8462 - val_categorical_crossentropy: 2.9321 - val_mean_squared_error: 0.6289 - lr: 0.0010 - epoch: 22.0000
# Epoch 23/100
# 75/75 [==============================] - 34s 452ms/step - loss: 3.2562 - categorical_accuracy: 0.5892 - categorical_crossentropy: 3.0806 - mean_squared_error: 1.0432 - val_loss: 3.0843 - val_categorical_accuracy: 0.8413 - val_categorical_crossentropy: 2.9116 - val_mean_squared_error: 0.6302 - lr: 0.0010 - epoch: 23.0000
# Epoch 24/100
# 75/75 [==============================] - 34s 456ms/step - loss: 3.2472 - categorical_accuracy: 0.5867 - categorical_crossentropy: 3.0773 - mean_squared_error: 1.0415 - val_loss: 3.0837 - val_categorical_accuracy: 0.8266 - val_categorical_crossentropy: 2.9165 - val_mean_squared_error: 0.6296 - lr: 0.0010 - epoch: 24.0000
# Epoch 25/100
# 75/75 [==============================] - 35s 463ms/step - loss: 3.2424 - categorical_accuracy: 0.5648 - categorical_crossentropy: 3.0778 - mean_squared_error: 1.0406 - val_loss: 3.0740 - val_categorical_accuracy: 0.8492 - val_categorical_crossentropy: 2.9119 - val_mean_squared_error: 0.6289 - lr: 0.0010 - epoch: 25.0000
# Epoch 26/100
# 75/75 [==============================] - 33s 445ms/step - loss: 3.2358 - categorical_accuracy: 0.5707 - categorical_crossentropy: 3.0763 - mean_squared_error: 1.0434 - val_loss: 3.0811 - val_categorical_accuracy: 0.8482 - val_categorical_crossentropy: 2.9242 - val_mean_squared_error: 0.6286 - lr: 0.0010 - epoch: 26.0000
# Epoch 27/100
# 75/75 [==============================] - 36s 487ms/step - loss: 3.2274 - categorical_accuracy: 0.5960 - categorical_crossentropy: 3.0730 - mean_squared_error: 1.0416 - val_loss: 3.0697 - val_categorical_accuracy: 0.8482 - val_categorical_crossentropy: 2.9178 - val_mean_squared_error: 0.6285 - lr: 0.0010 - epoch: 27.0000
# Epoch 28/100
# 75/75 [==============================] - 34s 462ms/step - loss: 3.2223 - categorical_accuracy: 0.6035 - categorical_crossentropy: 3.0728 - mean_squared_error: 1.0385 - val_loss: 3.0631 - val_categorical_accuracy: 0.8100 - val_categorical_crossentropy: 2.9159 - val_mean_squared_error: 0.6314 - lr: 0.0010 - epoch: 28.0000
# Epoch 29/100
# 75/75 [==============================] - 35s 462ms/step - loss: 3.2106 - categorical_accuracy: 0.6010 - categorical_crossentropy: 3.0657 - mean_squared_error: 1.0414 - val_loss: 3.0469 - val_categorical_accuracy: 0.8384 - val_categorical_crossentropy: 2.9042 - val_mean_squared_error: 0.6302 - lr: 0.0010 - epoch: 29.0000
# Epoch 30/100
# 75/75 [==============================] - 33s 444ms/step - loss: 3.2098 - categorical_accuracy: 0.5968 - categorical_crossentropy: 3.0696 - mean_squared_error: 1.0391 - val_loss: 3.0347 - val_categorical_accuracy: 0.8492 - val_categorical_crossentropy: 2.8970 - val_mean_squared_error: 0.6307 - lr: 0.0010 - epoch: 30.0000
# Epoch 31/100
# 75/75 [==============================] - 33s 435ms/step - loss: 3.2041 - categorical_accuracy: 0.6061 - categorical_crossentropy: 3.0684 - mean_squared_error: 1.0408 - val_loss: 3.0529 - val_categorical_accuracy: 0.7904 - val_categorical_crossentropy: 2.9191 - val_mean_squared_error: 0.6295 - lr: 0.0010 - epoch: 31.0000
# Epoch 32/100
# 75/75 [==============================] - 34s 460ms/step - loss: 3.2270 - categorical_accuracy: 0.5682 - categorical_crossentropy: 3.0951 - mean_squared_error: 1.0470 - val_loss: 3.0437 - val_categorical_accuracy: 0.8678 - val_categorical_crossentropy: 2.9137 - val_mean_squared_error: 0.6299 - lr: 0.0010 - epoch: 32.0000
# Epoch 33/100
# 75/75 [==============================] - 34s 449ms/step - loss: 3.1859 - categorical_accuracy: 0.6035 - categorical_crossentropy: 3.0579 - mean_squared_error: 1.0377 - val_loss: 3.0335 - val_categorical_accuracy: 0.8345 - val_categorical_crossentropy: 2.9076 - val_mean_squared_error: 0.6300 - lr: 0.0010 - epoch: 33.0000
# Epoch 34/100
# 75/75 [==============================] - 34s 460ms/step - loss: 3.1956 - categorical_accuracy: 0.5825 - categorical_crossentropy: 3.0716 - mean_squared_error: 1.0422 - val_loss: 3.0415 - val_categorical_accuracy: 0.8737 - val_categorical_crossentropy: 2.9193 - val_mean_squared_error: 0.6285 - lr: 0.0010 - epoch: 34.0000
# Epoch 35/100
# 75/75 [==============================] - 34s 453ms/step - loss: 3.2094 - categorical_accuracy: 0.5808 - categorical_crossentropy: 3.0888 - mean_squared_error: 1.0418 - val_loss: 3.0502 - val_categorical_accuracy: 0.8570 - val_categorical_crossentropy: 2.9315 - val_mean_squared_error: 0.6317 - lr: 0.0010 - epoch: 35.0000
# Epoch 36/100
# 75/75 [==============================] - 31s 421ms/step - loss: 3.1677 - categorical_accuracy: 0.5993 - categorical_crossentropy: 3.0507 - mean_squared_error: 1.0376 - val_loss: 3.0386 - val_categorical_accuracy: 0.8688 - val_categorical_crossentropy: 2.9235 - val_mean_squared_error: 0.6291 - lr: 0.0010 - epoch: 36.0000
# Epoch 37/100
# 75/75 [==============================] - 31s 421ms/step - loss: 3.1635 - categorical_accuracy: 0.6187 - categorical_crossentropy: 3.0487 - mean_squared_error: 1.0355 - val_loss: 3.0310 - val_categorical_accuracy: 0.8619 - val_categorical_crossentropy: 2.9165 - val_mean_squared_error: 0.6291 - lr: 1.0000e-04 - epoch: 37.0000
# Epoch 38/100
# 75/75 [==============================] - 32s 428ms/step - loss: 3.1342 - categorical_accuracy: 0.6347 - categorical_crossentropy: 3.0201 - mean_squared_error: 1.0300 - val_loss: 3.0411 - val_categorical_accuracy: 0.8599 - val_categorical_crossentropy: 2.9272 - val_mean_squared_error: 0.6277 - lr: 1.0000e-04 - epoch: 38.0000
# Epoch 39/100
# 75/75 [==============================] - 32s 432ms/step - loss: 3.1629 - categorical_accuracy: 0.6313 - categorical_crossentropy: 3.0494 - mean_squared_error: 1.0330 - val_loss: 3.0319 - val_categorical_accuracy: 0.8452 - val_categorical_crossentropy: 2.9187 - val_mean_squared_error: 0.6286 - lr: 1.0000e-04 - epoch: 39.0000
# Epoch 40/100
# 75/75 [==============================] - 32s 428ms/step - loss: 3.1421 - categorical_accuracy: 0.6111 - categorical_crossentropy: 3.0293 - mean_squared_error: 1.0326 - val_loss: 3.0262 - val_categorical_accuracy: 0.8472 - val_categorical_crossentropy: 2.9136 - val_mean_squared_error: 0.6282 - lr: 1.0000e-04 - epoch: 40.0000
# Epoch 41/100
# 75/75 [==============================] - 32s 422ms/step - loss: 3.1435 - categorical_accuracy: 0.6237 - categorical_crossentropy: 3.0313 - mean_squared_error: 1.0310 - val_loss: 3.0327 - val_categorical_accuracy: 0.8472 - val_categorical_crossentropy: 2.9208 - val_mean_squared_error: 0.6281 - lr: 1.0000e-04 - epoch: 41.0000
# Epoch 42/100
# 75/75 [==============================] - 33s 438ms/step - loss: 3.1302 - categorical_accuracy: 0.6439 - categorical_crossentropy: 3.0186 - mean_squared_error: 1.0262 - val_loss: 3.0248 - val_categorical_accuracy: 0.8482 - val_categorical_crossentropy: 2.9136 - val_mean_squared_error: 0.6277 - lr: 1.0000e-04 - epoch: 42.0000
# Epoch 43/100
# 75/75 [==============================] - 34s 454ms/step - loss: 3.1161 - categorical_accuracy: 0.6338 - categorical_crossentropy: 3.0052 - mean_squared_error: 1.0238 - val_loss: 3.0331 - val_categorical_accuracy: 0.8560 - val_categorical_crossentropy: 2.9225 - val_mean_squared_error: 0.6276 - lr: 1.0000e-04 - epoch: 43.0000
# Epoch 44/100
# 75/75 [==============================] - 35s 467ms/step - loss: 3.1242 - categorical_accuracy: 0.6372 - categorical_crossentropy: 3.0140 - mean_squared_error: 1.0259 - val_loss: 3.0143 - val_categorical_accuracy: 0.8443 - val_categorical_crossentropy: 2.9043 - val_mean_squared_error: 0.6277 - lr: 1.0000e-04 - epoch: 44.0000
# Epoch 45/100
# 75/75 [==============================] - 32s 423ms/step - loss: 3.1282 - categorical_accuracy: 0.6423 - categorical_crossentropy: 3.0186 - mean_squared_error: 1.0282 - val_loss: 3.0160 - val_categorical_accuracy: 0.8276 - val_categorical_crossentropy: 2.9068 - val_mean_squared_error: 0.6278 - lr: 1.0000e-04 - epoch: 45.0000
# Epoch 46/100
# 75/75 [==============================] - 32s 433ms/step - loss: 3.1164 - categorical_accuracy: 0.6439 - categorical_crossentropy: 3.0075 - mean_squared_error: 1.0246 - val_loss: 3.0362 - val_categorical_accuracy: 0.8472 - val_categorical_crossentropy: 2.9276 - val_mean_squared_error: 0.6271 - lr: 1.0000e-04 - epoch: 46.0000
# Epoch 47/100
# 75/75 [==============================] - 33s 435ms/step - loss: 3.1203 - categorical_accuracy: 0.6490 - categorical_crossentropy: 3.0120 - mean_squared_error: 1.0241 - val_loss: 3.0316 - val_categorical_accuracy: 0.8531 - val_categorical_crossentropy: 2.9237 - val_mean_squared_error: 0.6274 - lr: 1.0000e-04 - epoch: 47.0000
# Epoch 48/100
# 75/75 [==============================] - 32s 431ms/step - loss: 3.1193 - categorical_accuracy: 0.6355 - categorical_crossentropy: 3.0114 - mean_squared_error: 1.0250 - val_loss: 3.0273 - val_categorical_accuracy: 0.8521 - val_categorical_crossentropy: 2.9195 - val_mean_squared_error: 0.6275 - lr: 1.0000e-05 - epoch: 48.0000
# Epoch 49/100
# 75/75 [==============================] - 33s 440ms/step - loss: 3.1251 - categorical_accuracy: 0.6423 - categorical_crossentropy: 3.0174 - mean_squared_error: 1.0261 - val_loss: 3.0239 - val_categorical_accuracy: 0.8511 - val_categorical_crossentropy: 2.9162 - val_mean_squared_error: 0.6276 - lr: 1.0000e-05 - epoch: 49.0000
# Epoch 50/100
# 75/75 [==============================] - 33s 440ms/step - loss: 3.1119 - categorical_accuracy: 0.6347 - categorical_crossentropy: 3.0042 - mean_squared_error: 1.0247 - val_loss: 3.0237 - val_categorical_accuracy: 0.8433 - val_categorical_crossentropy: 2.9160 - val_mean_squared_error: 0.6275 - lr: 1.0000e-05 - epoch: 50.0000
# Epoch 51/100
# 75/75 [==============================] - 33s 441ms/step - loss: 3.1060 - categorical_accuracy: 0.6313 - categorical_crossentropy: 2.9983 - mean_squared_error: 1.0235 - val_loss: 3.0238 - val_categorical_accuracy: 0.8433 - val_categorical_crossentropy: 2.9161 - val_mean_squared_error: 0.6275 - lr: 1.0000e-06 - epoch: 51.0000
# Epoch 52/100
# 75/75 [==============================] - 33s 443ms/step - loss: 3.1152 - categorical_accuracy: 0.6246 - categorical_crossentropy: 3.0075 - mean_squared_error: 1.0251 - val_loss: 3.0241 - val_categorical_accuracy: 0.8433 - val_categorical_crossentropy: 2.9164 - val_mean_squared_error: 0.6275 - lr: 1.0000e-06 - epoch: 52.0000
# Epoch 53/100
# 75/75 [==============================] - 32s 422ms/step - loss: 3.1087 - categorical_accuracy: 0.6456 - categorical_crossentropy: 3.0011 - mean_squared_error: 1.0228 - val_loss: 3.0243 - val_categorical_accuracy: 0.8433 - val_categorical_crossentropy: 2.9166 - val_mean_squared_error: 0.6275 - lr: 1.0000e-06 - epoch: 53.0000
# Epoch 54/100
# 75/75 [==============================] - 31s 413ms/step - loss: 3.1098 - categorical_accuracy: 0.6448 - categorical_crossentropy: 3.0021 - mean_squared_error: 1.0222 - val_loss: 3.0241 - val_categorical_accuracy: 0.8433 - val_categorical_crossentropy: 2.9165 - val_mean_squared_error: 0.6275 - lr: 1.0000e-06 - epoch: 54.0000
# Epoch 55/100
# 75/75 [==============================] - 31s 410ms/step - loss: 3.1076 - categorical_accuracy: 0.6380 - categorical_crossentropy: 3.0000 - mean_squared_error: 1.0233 - val_loss: 3.0240 - val_categorical_accuracy: 0.8433 - val_categorical_crossentropy: 2.9163 - val_mean_squared_error: 0.6275 - lr: 1.0000e-06 - epoch: 55.0000
# Epoch 56/100
# 75/75 [==============================] - 32s 432ms/step - loss: 3.1268 - categorical_accuracy: 0.6347 - categorical_crossentropy: 3.0191 - mean_squared_error: 1.0251 - val_loss: 3.0235 - val_categorical_accuracy: 0.8433 - val_categorical_crossentropy: 2.9159 - val_mean_squared_error: 0.6275 - lr: 1.0000e-06 - epoch: 56.0000
# Epoch 57/100
# 75/75 [==============================] - 31s 419ms/step - loss: 3.1146 - categorical_accuracy: 0.6524 - categorical_crossentropy: 3.0070 - mean_squared_error: 1.0228 - val_loss: 3.0236 - val_categorical_accuracy: 0.8433 - val_categorical_crossentropy: 2.9160 - val_mean_squared_error: 0.6275 - lr: 1.0000e-06 - epoch: 57.0000
# Epoch 58/100
# 75/75 [==============================] - 32s 429ms/step - loss: 3.1038 - categorical_accuracy: 0.6313 - categorical_crossentropy: 2.9962 - mean_squared_error: 1.0238 - val_loss: 3.0234 - val_categorical_accuracy: 0.8433 - val_categorical_crossentropy: 2.9157 - val_mean_squared_error: 0.6275 - lr: 1.0000e-06 - epoch: 58.0000
# Epoch 59/100
# 75/75 [==============================] - 31s 414ms/step - loss: 3.1186 - categorical_accuracy: 0.6380 - categorical_crossentropy: 3.0110 - mean_squared_error: 1.0247 - val_loss: 3.0232 - val_categorical_accuracy: 0.8433 - val_categorical_crossentropy: 2.9156 - val_mean_squared_error: 0.6275 - lr: 1.0000e-06 - epoch: 59.0000
# Epoch 60/100
# 75/75 [==============================] - 31s 414ms/step - loss: 3.1079 - categorical_accuracy: 0.6515 - categorical_crossentropy: 3.0003 - mean_squared_error: 1.0236 - val_loss: 3.0233 - val_categorical_accuracy: 0.8433 - val_categorical_crossentropy: 2.9157 - val_mean_squared_error: 0.6275 - lr: 1.0000e-06 - epoch: 60.0000
# Epoch 61/100
# 75/75 [==============================] - 30s 404ms/step - loss: 3.1245 - categorical_accuracy: 0.6473 - categorical_crossentropy: 3.0169 - mean_squared_error: 1.0270 - val_loss: 3.0232 - val_categorical_accuracy: 0.8433 - val_categorical_crossentropy: 2.9157 - val_mean_squared_error: 0.6275 - lr: 1.0000e-06 - epoch: 61.0000
# Epoch 62/100
# 75/75 [==============================] - 31s 408ms/step - loss: 3.1093 - categorical_accuracy: 0.6330 - categorical_crossentropy: 3.0017 - mean_squared_error: 1.0247 - val_loss: 3.0234 - val_categorical_accuracy: 0.8433 - val_categorical_crossentropy: 2.9159 - val_mean_squared_error: 0.6275 - lr: 1.0000e-06 - epoch: 62.0000
# Epoch 63/100
# 75/75 [==============================] - 31s 411ms/step - loss: 3.1095 - categorical_accuracy: 0.6574 - categorical_crossentropy: 3.0019 - mean_squared_error: 1.0220 - val_loss: 3.0235 - val_categorical_accuracy: 0.8433 - val_categorical_crossentropy: 2.9159 - val_mean_squared_error: 0.6275 - lr: 1.0000e-06 - epoch: 63.0000
# Epoch 64/100
# 75/75 [==============================] - 31s 411ms/step - loss: 3.1199 - categorical_accuracy: 0.6448 - categorical_crossentropy: 3.0123 - mean_squared_error: 1.0231 - val_loss: 3.0235 - val_categorical_accuracy: 0.8433 - val_categorical_crossentropy: 2.9159 - val_mean_squared_error: 0.6275 - lr: 1.0000e-06 - epoch: 64.0000
# Epoch 65/100
# 75/75 [==============================] - 31s 409ms/step - loss: 3.1237 - categorical_accuracy: 0.6305 - categorical_crossentropy: 3.0161 - mean_squared_error: 1.0261 - val_loss: 3.0234 - val_categorical_accuracy: 0.8433 - val_categorical_crossentropy: 2.9159 - val_mean_squared_error: 0.6275 - lr: 1.0000e-06 - epoch: 65.0000
# Epoch 66/100
# 75/75 [==============================] - 30s 405ms/step - loss: 3.1193 - categorical_accuracy: 0.6288 - categorical_crossentropy: 3.0118 - mean_squared_error: 1.0244 - val_loss: 3.0238 - val_categorical_accuracy: 0.8433 - val_categorical_crossentropy: 2.9163 - val_mean_squared_error: 0.6275 - lr: 1.0000e-06 - epoch: 66.0000
# Epoch 67/100
# 75/75 [==============================] - 32s 428ms/step - loss: 3.1102 - categorical_accuracy: 0.6406 - categorical_crossentropy: 3.0026 - mean_squared_error: 1.0250 - val_loss: 3.0240 - val_categorical_accuracy: 0.8433 - val_categorical_crossentropy: 2.9165 - val_mean_squared_error: 0.6275 - lr: 1.0000e-06 - epoch: 67.0000
# Epoch 68/100
# 75/75 [==============================] - 32s 433ms/step - loss: 3.1202 - categorical_accuracy: 0.6389 - categorical_crossentropy: 3.0127 - mean_squared_error: 1.0249 - val_loss: 3.0236 - val_categorical_accuracy: 0.8433 - val_categorical_crossentropy: 2.9160 - val_mean_squared_error: 0.6275 - lr: 1.0000e-06 - epoch: 68.0000
# Epoch 69/100
# 75/75 [==============================] - 32s 434ms/step - loss: 3.1154 - categorical_accuracy: 0.6128 - categorical_crossentropy: 3.0079 - mean_squared_error: 1.0252 - val_loss: 3.0230 - val_categorical_accuracy: 0.8433 - val_categorical_crossentropy: 2.9155 - val_mean_squared_error: 0.6275 - lr: 1.0000e-06 - epoch: 69.0000
# Epoch 70/100
# 75/75 [==============================] - 32s 423ms/step - loss: 3.1138 - categorical_accuracy: 0.6364 - categorical_crossentropy: 3.0063 - mean_squared_error: 1.0249 - val_loss: 3.0228 - val_categorical_accuracy: 0.8433 - val_categorical_crossentropy: 2.9153 - val_mean_squared_error: 0.6275 - lr: 1.0000e-06 - epoch: 70.0000
# Epoch 71/100
# 75/75 [==============================] - 34s 454ms/step - loss: 3.1267 - categorical_accuracy: 0.6338 - categorical_crossentropy: 3.0192 - mean_squared_error: 1.0284 - val_loss: 3.0231 - val_categorical_accuracy: 0.8433 - val_categorical_crossentropy: 2.9157 - val_mean_squared_error: 0.6275 - lr: 1.0000e-06 - epoch: 71.0000
# Epoch 72/100
# 75/75 [==============================] - 35s 463ms/step - loss: 3.1055 - categorical_accuracy: 0.6456 - categorical_crossentropy: 2.9981 - mean_squared_error: 1.0233 - val_loss: 3.0233 - val_categorical_accuracy: 0.8443 - val_categorical_crossentropy: 2.9158 - val_mean_squared_error: 0.6275 - lr: 1.0000e-06 - epoch: 72.0000
# Epoch 73/100
# 75/75 [==============================] - 30s 406ms/step - loss: 3.1169 - categorical_accuracy: 0.6263 - categorical_crossentropy: 3.0094 - mean_squared_error: 1.0272 - val_loss: 3.0238 - val_categorical_accuracy: 0.8433 - val_categorical_crossentropy: 2.9163 - val_mean_squared_error: 0.6275 - lr: 1.0000e-06 - epoch: 73.0000
# Epoch 74/100
# 75/75 [==============================] - 30s 400ms/step - loss: 3.1137 - categorical_accuracy: 0.6498 - categorical_crossentropy: 3.0063 - mean_squared_error: 1.0238 - val_loss: 3.0242 - val_categorical_accuracy: 0.8433 - val_categorical_crossentropy: 2.9168 - val_mean_squared_error: 0.6275 - lr: 1.0000e-06 - epoch: 74.0000
# Epoch 75/100
# 75/75 [==============================] - 32s 429ms/step - loss: 3.1082 - categorical_accuracy: 0.6456 - categorical_crossentropy: 3.0008 - mean_squared_error: 1.0239 - val_loss: 3.0239 - val_categorical_accuracy: 0.8433 - val_categorical_crossentropy: 2.9164 - val_mean_squared_error: 0.6275 - lr: 1.0000e-06 - epoch: 75.0000
# Epoch 76/100
# 75/75 [==============================] - 31s 412ms/step - loss: 3.1196 - categorical_accuracy: 0.6397 - categorical_crossentropy: 3.0122 - mean_squared_error: 1.0259 - val_loss: 3.0239 - val_categorical_accuracy: 0.8433 - val_categorical_crossentropy: 2.9165 - val_mean_squared_error: 0.6275 - lr: 1.0000e-06 - epoch: 76.0000
# Epoch 77/100
# 75/75 [==============================] - 31s 411ms/step - loss: 3.1124 - categorical_accuracy: 0.6338 - categorical_crossentropy: 3.0050 - mean_squared_error: 1.0232 - val_loss: 3.0240 - val_categorical_accuracy: 0.8433 - val_categorical_crossentropy: 2.9166 - val_mean_squared_error: 0.6275 - lr: 1.0000e-06 - epoch: 77.0000
# Epoch 78/100
# ...
# 75/75 [==============================] - 30s 397ms/step - loss: 2.9851 - categorical_accuracy: 0.5918 - categorical_crossentropy: 2.9851 - mean_squared_error: 1.0134 - val_loss: 2.9166 - val_categorical_accuracy: 0.6964 - val_categorical_crossentropy: 2.9166 - val_mean_squared_error: 0.6287 - lr: 1.0000e-06 - epoch: 31.0000
# Epoch 32/100
# 75/75 [==============================] - 30s 394ms/step - loss: 2.9789 - categorical_accuracy: 0.5934 - categorical_crossentropy: 2.9789 - mean_squared_error: 1.0126 - val_loss: 2.9164 - val_categorical_accuracy: 0.6983 - val_categorical_crossentropy: 2.9164 - val_mean_squared_error: 0.6287 - lr: 1.0000e-06 - epoch: 32.0000
# Epoch 33/100
# 75/75 [==============================] - 31s 413ms/step - loss: 2.9823 - categorical_accuracy: 0.5859 - categorical_crossentropy: 2.9823 - mean_squared_error: 1.0121 - val_loss: 2.9171 - val_categorical_accuracy: 0.7042 - val_categorical_crossentropy: 2.9171 - val_mean_squared_error: 0.6287 - lr: 1.0000e-06 - epoch: 33.0000
# Epoch 34/100
# 75/75 [==============================] - 30s 405ms/step - loss: 2.9758 - categorical_accuracy: 0.6103 - categorical_crossentropy: 2.9758 - mean_squared_error: 1.0117 - val_loss: 2.9174 - val_categorical_accuracy: 0.7071 - val_categorical_crossentropy: 2.9174 - val_mean_squared_error: 0.6286 - lr: 1.0000e-06 - epoch: 34.0000
# Epoch 35/100
# 75/75 [==============================] - 30s 395ms/step - loss: 2.9862 - categorical_accuracy: 0.5951 - categorical_crossentropy: 2.9862 - mean_squared_error: 1.0137 - val_loss: 2.9175 - val_categorical_accuracy: 0.7101 - val_categorical_crossentropy: 2.9175 - val_mean_squared_error: 0.6285 - lr: 1.0000e-06 - epoch: 35.0000
# Epoch 36/100
# 75/75 [==============================] - 29s 391ms/step - loss: 2.9797 - categorical_accuracy: 0.6010 - categorical_crossentropy: 2.9797 - mean_squared_error: 1.0118 - val_loss: 2.9177 - val_categorical_accuracy: 0.7062 - val_categorical_crossentropy: 2.9177 - val_mean_squared_error: 0.6286 - lr: 1.0000e-06 - epoch: 36.0000
# Epoch 37/100
# 75/75 [==============================] - 29s 393ms/step - loss: 2.9827 - categorical_accuracy: 0.6111 - categorical_crossentropy: 2.9827 - mean_squared_error: 1.0124 - val_loss: 2.9171 - val_categorical_accuracy: 0.7023 - val_categorical_crossentropy: 2.9171 - val_mean_squared_error: 0.6286 - lr: 1.0000e-06 - epoch: 37.0000
# Epoch 38/100
# 75/75 [==============================] - 29s 394ms/step - loss: 2.9811 - categorical_accuracy: 0.5993 - categorical_crossentropy: 2.9811 - mean_squared_error: 1.0124 - val_loss: 2.9167 - val_categorical_accuracy: 0.6964 - val_categorical_crossentropy: 2.9167 - val_mean_squared_error: 0.6286 - lr: 1.0000e-06 - epoch: 38.0000
# Epoch 39/100
# 75/75 [==============================] - 29s 394ms/step - loss: 2.9808 - categorical_accuracy: 0.5943 - categorical_crossentropy: 2.9808 - mean_squared_error: 1.0120 - val_loss: 2.9162 - val_categorical_accuracy: 0.6905 - val_categorical_crossentropy: 2.9162 - val_mean_squared_error: 0.6287 - lr: 1.0000e-06 - epoch: 39.0000
# Epoch 40/100
# 75/75 [==============================] - 30s 395ms/step - loss: 2.9786 - categorical_accuracy: 0.5875 - categorical_crossentropy: 2.9786 - mean_squared_error: 1.0114 - val_loss: 2.9166 - val_categorical_accuracy: 0.6885 - val_categorical_crossentropy: 2.9166 - val_mean_squared_error: 0.6287 - lr: 1.0000e-06 - epoch: 40.0000
# Epoch 41/100
# 75/75 [==============================] - 30s 403ms/step - loss: 2.9744 - categorical_accuracy: 0.5951 - categorical_crossentropy: 2.9744 - mean_squared_error: 1.0106 - val_loss: 2.9162 - val_categorical_accuracy: 0.6876 - val_categorical_crossentropy: 2.9162 - val_mean_squared_error: 0.6288 - lr: 1.0000e-06 - epoch: 41.0000
# Epoch 42/100
# 75/75 [==============================] - 29s 392ms/step - loss: 2.9805 - categorical_accuracy: 0.6069 - categorical_crossentropy: 2.9805 - mean_squared_error: 1.0125 - val_loss: 2.9161 - val_categorical_accuracy: 0.6954 - val_categorical_crossentropy: 2.9161 - val_mean_squared_error: 0.6285 - lr: 1.0000e-06 - epoch: 42.0000
# Epoch 43/100
# 75/75 [==============================] - 31s 410ms/step - loss: 2.9802 - categorical_accuracy: 0.6019 - categorical_crossentropy: 2.9802 - mean_squared_error: 1.0110 - val_loss: 2.9169 - val_categorical_accuracy: 0.7042 - val_categorical_crossentropy: 2.9169 - val_mean_squared_error: 0.6285 - lr: 1.0000e-06 - epoch: 43.0000
# Epoch 44/100
# 75/75 [==============================] - 30s 403ms/step - loss: 2.9843 - categorical_accuracy: 0.6019 - categorical_crossentropy: 2.9843 - mean_squared_error: 1.0129 - val_loss: 2.9175 - val_categorical_accuracy: 0.7042 - val_categorical_crossentropy: 2.9175 - val_mean_squared_error: 0.6286 - lr: 1.0000e-06 - epoch: 44.0000
# Epoch 45/100
# 75/75 [==============================] - 30s 401ms/step - loss: 2.9780 - categorical_accuracy: 0.5993 - categorical_crossentropy: 2.9780 - mean_squared_error: 1.0113 - val_loss: 2.9172 - val_categorical_accuracy: 0.7091 - val_categorical_crossentropy: 2.9172 - val_mean_squared_error: 0.6285 - lr: 1.0000e-06 - epoch: 45.0000
# Epoch 46/100
# 75/75 [==============================] - 30s 400ms/step - loss: 2.9774 - categorical_accuracy: 0.5951 - categorical_crossentropy: 2.9774 - mean_squared_error: 1.0118 - val_loss: 2.9178 - val_categorical_accuracy: 0.7111 - val_categorical_crossentropy: 2.9178 - val_mean_squared_error: 0.6286 - lr: 1.0000e-06 - epoch: 46.0000
# Epoch 47/100
# 75/75 [==============================] - 30s 403ms/step - loss: 2.9812 - categorical_accuracy: 0.6010 - categorical_crossentropy: 2.9812 - mean_squared_error: 1.0126 - val_loss: 2.9174 - val_categorical_accuracy: 0.7111 - val_categorical_crossentropy: 2.9174 - val_mean_squared_error: 0.6285 - lr: 1.0000e-06 - epoch: 47.0000
# Epoch 48/100
# 75/75 [==============================] - 29s 393ms/step - loss: 2.9868 - categorical_accuracy: 0.5867 - categorical_crossentropy: 2.9868 - mean_squared_error: 1.0131 - val_loss: 2.9188 - val_categorical_accuracy: 0.7120 - val_categorical_crossentropy: 2.9188 - val_mean_squared_error: 0.6287 - lr: 1.0000e-06 - epoch: 48.0000
# Epoch 49/100
# 75/75 [==============================] - 30s 398ms/step - loss: 2.9789 - categorical_accuracy: 0.5892 - categorical_crossentropy: 2.9789 - mean_squared_error: 1.0116 - val_loss: 2.9182 - val_categorical_accuracy: 0.7111 - val_categorical_crossentropy: 2.9182 - val_mean_squared_error: 0.6287 - lr: 1.0000e-06 - epoch: 49.0000
# Epoch 50/100
# 75/75 [==============================] - 30s 403ms/step - loss: 2.9818 - categorical_accuracy: 0.6002 - categorical_crossentropy: 2.9818 - mean_squared_error: 1.0120 - val_loss: 2.9181 - val_categorical_accuracy: 0.7120 - val_categorical_crossentropy: 2.9181 - val_mean_squared_error: 0.6285 - lr: 1.0000e-06 - epoch: 50.0000
# Epoch 51/100
# 75/75 [==============================] - 29s 383ms/step - loss: 2.9746 - categorical_accuracy: 0.5859 - categorical_crossentropy: 2.9746 - mean_squared_error: 1.0117 - val_loss: 2.9179 - val_categorical_accuracy: 0.7032 - val_categorical_crossentropy: 2.9179 - val_mean_squared_error: 0.6286 - lr: 1.0000e-06 - epoch: 51.0000
# Epoch 52/100
# 75/75 [==============================] - 30s 400ms/step - loss: 2.9800 - categorical_accuracy: 0.5976 - categorical_crossentropy: 2.9800 - mean_squared_error: 1.0121 - val_loss: 2.9181 - val_categorical_accuracy: 0.7140 - val_categorical_crossentropy: 2.9181 - val_mean_squared_error: 0.6285 - lr: 1.0000e-06 - epoch: 52.0000
# Epoch 53/100
# 75/75 [==============================] - 30s 400ms/step - loss: 2.9836 - categorical_accuracy: 0.5985 - categorical_crossentropy: 2.9836 - mean_squared_error: 1.0123 - val_loss: 2.9177 - val_categorical_accuracy: 0.7120 - val_categorical_crossentropy: 2.9177 - val_mean_squared_error: 0.6285 - lr: 1.0000e-06 - epoch: 53.0000
# Epoch 54/100
# 75/75 [==============================] - 30s 406ms/step - loss: 2.9770 - categorical_accuracy: 0.6069 - categorical_crossentropy: 2.9770 - mean_squared_error: 1.0111 - val_loss: 2.9178 - val_categorical_accuracy: 0.7150 - val_categorical_crossentropy: 2.9178 - val_mean_squared_error: 0.6284 - lr: 1.0000e-06 - epoch: 54.0000
# Epoch 55/100
# 75/75 [==============================] - 30s 397ms/step - loss: 2.9805 - categorical_accuracy: 0.5926 - categorical_crossentropy: 2.9805 - mean_squared_error: 1.0122 - val_loss: 2.9182 - val_categorical_accuracy: 0.7209 - val_categorical_crossentropy: 2.9182 - val_mean_squared_error: 0.6284 - lr: 1.0000e-06 - epoch: 55.0000
# Epoch 56/100
# 75/75 [==============================] - 32s 421ms/step - loss: 2.9754 - categorical_accuracy: 0.6094 - categorical_crossentropy: 2.9754 - mean_squared_error: 1.0102 - val_loss: 2.9183 - val_categorical_accuracy: 0.7209 - val_categorical_crossentropy: 2.9183 - val_mean_squared_error: 0.6285 - lr: 1.0000e-06 - epoch: 56.0000
# Epoch 57/100
# 75/75 [==============================] - 30s 400ms/step - loss: 2.9772 - categorical_accuracy: 0.5934 - categorical_crossentropy: 2.9772 - mean_squared_error: 1.0119 - val_loss: 2.9182 - val_categorical_accuracy: 0.7228 - val_categorical_crossentropy: 2.9182 - val_mean_squared_error: 0.6284 - lr: 1.0000e-06 - epoch: 57.0000
# Epoch 58/100
# 75/75 [==============================] - 31s 408ms/step - loss: 2.9815 - categorical_accuracy: 0.5943 - categorical_crossentropy: 2.9815 - mean_squared_error: 1.0120 - val_loss: 2.9182 - val_categorical_accuracy: 0.7209 - val_categorical_crossentropy: 2.9182 - val_mean_squared_error: 0.6285 - lr: 1.0000e-06 - epoch: 58.0000
# Epoch 59/100
# 75/75 [==============================] - 31s 410ms/step - loss: 2.9842 - categorical_accuracy: 0.5901 - categorical_crossentropy: 2.9842 - mean_squared_error: 1.0123 - val_loss: 2.9186 - val_categorical_accuracy: 0.7258 - val_categorical_crossentropy: 2.9186 - val_mean_squared_error: 0.6284 - lr: 1.0000e-06 - epoch: 59.0000
# Epoch 60/100
# 75/75 [==============================] - 30s 400ms/step - loss: 2.9811 - categorical_accuracy: 0.5850 - categorical_crossentropy: 2.9811 - mean_squared_error: 1.0122 - val_loss: 2.9180 - val_categorical_accuracy: 0.7277 - val_categorical_crossentropy: 2.9180 - val_mean_squared_error: 0.6282 - lr: 1.0000e-06 - epoch: 60.0000
# Epoch 61/100
# 75/75 [==============================] - 30s 397ms/step - loss: 2.9754 - categorical_accuracy: 0.5800 - categorical_crossentropy: 2.9754 - mean_squared_error: 1.0109 - val_loss: 2.9186 - val_categorical_accuracy: 0.7267 - val_categorical_crossentropy: 2.9186 - val_mean_squared_error: 0.6284 - lr: 1.0000e-06 - epoch: 61.0000
# Epoch 62/100
# 75/75 [==============================] - 34s 447ms/step - loss: 2.9731 - categorical_accuracy: 0.5985 - categorical_crossentropy: 2.9731 - mean_squared_error: 1.0102 - val_loss: 2.9191 - val_categorical_accuracy: 0.7307 - val_categorical_crossentropy: 2.9191 - val_mean_squared_error: 0.6283 - lr: 1.0000e-06 - epoch: 62.0000
# Epoch 63/100
# 75/75 [==============================] - 30s 399ms/step - loss: 2.9833 - categorical_accuracy: 0.5842 - categorical_crossentropy: 2.9833 - mean_squared_error: 1.0123 - val_loss: 2.9191 - val_categorical_accuracy: 0.7287 - val_categorical_crossentropy: 2.9191 - val_mean_squared_error: 0.6283 - lr: 1.0000e-06 - epoch: 63.0000
# Epoch 64/100
# 75/75 [==============================] - 30s 401ms/step - loss: 2.9815 - categorical_accuracy: 0.5800 - categorical_crossentropy: 2.9815 - mean_squared_error: 1.0115 - val_loss: 2.9201 - val_categorical_accuracy: 0.7287 - val_categorical_crossentropy: 2.9201 - val_mean_squared_error: 0.6283 - lr: 1.0000e-06 - epoch: 64.0000
# Epoch 65/100
# 75/75 [==============================] - 31s 416ms/step - loss: 2.9821 - categorical_accuracy: 0.6010 - categorical_crossentropy: 2.9821 - mean_squared_error: 1.0117 - val_loss: 2.9195 - val_categorical_accuracy: 0.7267 - val_categorical_crossentropy: 2.9195 - val_mean_squared_error: 0.6284 - lr: 1.0000e-06 - epoch: 65.0000
# Epoch 66/100
# 75/75 [==============================] - 30s 402ms/step - loss: 2.9809 - categorical_accuracy: 0.5884 - categorical_crossentropy: 2.9809 - mean_squared_error: 1.0120 - val_loss: 2.9192 - val_categorical_accuracy: 0.7267 - val_categorical_crossentropy: 2.9192 - val_mean_squared_error: 0.6283 - lr: 1.0000e-06 - epoch: 66.0000
# Epoch 67/100
# 75/75 [==============================] - 32s 426ms/step - loss: 2.9760 - categorical_accuracy: 0.5976 - categorical_crossentropy: 2.9760 - mean_squared_error: 1.0120 - val_loss: 2.9197 - val_categorical_accuracy: 0.7307 - val_categorical_crossentropy: 2.9197 - val_mean_squared_error: 0.6283 - lr: 1.0000e-06 - epoch: 67.0000
# Epoch 68/100
# 75/75 [==============================] - 32s 427ms/step - loss: 2.9749 - categorical_accuracy: 0.5993 - categorical_crossentropy: 2.9749 - mean_squared_error: 1.0109 - val_loss: 2.9192 - val_categorical_accuracy: 0.7287 - val_categorical_crossentropy: 2.9192 - val_mean_squared_error: 0.6283 - lr: 1.0000e-06 - epoch: 68.0000
# Epoch 69/100
# 75/75 [==============================] - 32s 424ms/step - loss: 2.9817 - categorical_accuracy: 0.6145 - categorical_crossentropy: 2.9817 - mean_squared_error: 1.0120 - val_loss: 2.9185 - val_categorical_accuracy: 0.7277 - val_categorical_crossentropy: 2.9185 - val_mean_squared_error: 0.6282 - lr: 1.0000e-06 - epoch: 69.0000
# Epoch 70/100
# 75/75 [==============================] - 32s 432ms/step - loss: 2.9763 - categorical_accuracy: 0.6061 - categorical_crossentropy: 2.9763 - mean_squared_error: 1.0113 - val_loss: 2.9181 - val_categorical_accuracy: 0.7267 - val_categorical_crossentropy: 2.9181 - val_mean_squared_error: 0.6282 - lr: 1.0000e-06 - epoch: 70.0000
# Epoch 71/100
# 75/75 [==============================] - 33s 440ms/step - loss: 2.9817 - categorical_accuracy: 0.6052 - categorical_crossentropy: 2.9817 - mean_squared_error: 1.0129 - val_loss: 2.9188 - val_categorical_accuracy: 0.7287 - val_categorical_crossentropy: 2.9188 - val_mean_squared_error: 0.6284 - lr: 1.0000e-06 - epoch: 71.0000
# Epoch 72/100
# 75/75 [==============================] - 31s 408ms/step - loss: 2.9772 - categorical_accuracy: 0.6061 - categorical_crossentropy: 2.9772 - mean_squared_error: 1.0118 - val_loss: 2.9182 - val_categorical_accuracy: 0.7258 - val_categorical_crossentropy: 2.9182 - val_mean_squared_error: 0.6283 - lr: 1.0000e-06 - epoch: 72.0000
# Epoch 73/100
# 75/75 [==============================] - 32s 421ms/step - loss: 2.9864 - categorical_accuracy: 0.5918 - categorical_crossentropy: 2.9864 - mean_squared_error: 1.0125 - val_loss: 2.9179 - val_categorical_accuracy: 0.7179 - val_categorical_crossentropy: 2.9179 - val_mean_squared_error: 0.6283 - lr: 1.0000e-06 - epoch: 73.0000
# Epoch 74/100
# 75/75 [==============================] - 32s 423ms/step - loss: 2.9856 - categorical_accuracy: 0.5993 - categorical_crossentropy: 2.9856 - mean_squared_error: 1.0130 - val_loss: 2.9172 - val_categorical_accuracy: 0.7169 - val_categorical_crossentropy: 2.9172 - val_mean_squared_error: 0.6282 - lr: 1.0000e-06 - epoch: 74.0000
# Epoch 75/100
# 75/75 [==============================] - 30s 394ms/step - loss: 2.9761 - categorical_accuracy: 0.5875 - categorical_crossentropy: 2.9761 - mean_squared_error: 1.0106 - val_loss: 2.9170 - val_categorical_accuracy: 0.7150 - val_categorical_crossentropy: 2.9170 - val_mean_squared_error: 0.6284 - lr: 1.0000e-06 - epoch: 75.0000
# Epoch 76/100
# 75/75 [==============================] - 30s 400ms/step - loss: 2.9802 - categorical_accuracy: 0.5918 - categorical_crossentropy: 2.9802 - mean_squared_error: 1.0117 - val_loss: 2.9176 - val_categorical_accuracy: 0.7179 - val_categorical_crossentropy: 2.9176 - val_mean_squared_error: 0.6283 - lr: 1.0000e-06 - epoch: 76.0000
# Epoch 77/100
# 75/75 [==============================] - 31s 418ms/step - loss: 2.9790 - categorical_accuracy: 0.6019 - categorical_crossentropy: 2.9790 - mean_squared_error: 1.0118 - val_loss: 2.9181 - val_categorical_accuracy: 0.7218 - val_categorical_crossentropy: 2.9181 - val_mean_squared_error: 0.6283 - lr: 1.0000e-06 - epoch: 77.0000
#
# Training for basic_cnn completed.
#
# Saved all metrics to ./PC_balanced_GPU.xlsx

# %% [markdown]
# ## View Model Performance

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
from matplotlib.legend_handler import HandlerTuple

class HandlerTupleVertical(HandlerTuple):
    def create_artists(self, legend, orig_handle, xdescent, ydescent, width, height, fontsize, trans):
        numlines = len(orig_handle)
        handler_map = legend.get_legend_handler_map()
        height_y = (height / numlines)
        leglines = []
        for i, handle in enumerate(orig_handle):
            handler = legend.get_legend_handler(handler_map, handle)
            legline = handler.create_artists(legend, handle, xdescent, (2*i + 1)*height_y, width, 2*height, fontsize, trans)
            leglines.extend(legline)
        return leglines

def get_dataframes_from_excel(xls):
    """Load DataFrames from the Excel file."""
    model_names = xls.sheet_names
    return {model_name: pd.read_excel(xls, model_name) for model_name in model_names}

def plot_metrics(ax, dfs, metric, readable_metric, color_dict):
    """Plot metrics for all models on a single graph."""
    for model_name, cleaned_name in zip(dfs.keys(), color_dict.keys()):
        epochs = dfs[model_name]['epoch']
        ax.plot(epochs, dfs[model_name][f'{metric}'], '--', color=color_dict[cleaned_name], label=f"{cleaned_name}") #Training
        ax.plot(epochs, dfs[model_name][f'val_{metric}'], '-', color=color_dict[cleaned_name], label=f"{cleaned_name}") #Validation
    ax.set_title(f"{readable_metric} vs Epoch")
    ax.set_xlabel('Epoch')
    ax.set_ylabel(readable_metric)
    
model_name_mapping = {
    "mobilenetv2": "MobileNetV2 Transfer",
    "inceptionv3": "InceptionV3 Transfer",
    "resnet50": "ResNet50 Transfer",
    "small_xception": "Small Xception",
    "basic_cnn": "Basic CNN"
}
def plot_metrics_from_excel(excel_path):
    # Load the Excel file and get DataFrames
    xls = pd.ExcelFile(excel_path)
    model_names = xls.sheet_names
    dfs = get_dataframes_from_excel(xls)
    readable_model_names = [model_name_mapping.get(name, name) for name in model_names]
    
    # Metrics mapping and Seaborn style
    metric_mapping = {
        'loss': 'Loss',
        'categorical_accuracy': 'Categorical Accuracy',
        'categorical_crossentropy': 'Categorical Crossentropy',
        'mean_squared_error': 'Mean Squared Error'
    }
    sns.set_style("whitegrid")
    palette = sns.color_palette("tab10", len(model_names))
    color_dict = {readable_name: palette[i] for i, readable_name in enumerate(readable_model_names)}
    
    # Plotting
    fig, axes = plt.subplots(2, 2, figsize=(18, 10))
    axes_flat = axes.ravel()
    for i, (metric, readable_metric) in enumerate(metric_mapping.items()):
        plot_metrics(axes_flat[i], dfs, metric, readable_metric, color_dict)
        # Add legend to each subplot
        handles, labels = axes_flat[i].get_legend_handles_labels()
        new_handles = [(handles[j], handles[j + 1]) for j in range(0, len(handles), 2)]
        axes_flat[i].legend(new_handles, labels[::2], handler_map={tuple: HandlerTupleVertical()})
    
    # Add main title
    experiment_name = os.path.basename(excel_path).replace(".xlsx", "")
    fig.suptitle(f"Metrics for {experiment_name}", fontsize=20, y=1.08)
    
    # Add informational note below the subplots
    note_text = r"$\bf{Models}$" + "\nTraining (Dashed) | Validation (Solid)"
    fig.text(0.5, -0.02, note_text, ha='center', fontsize=10, transform=fig.transFigure)
    
    fig.tight_layout()
    
    # Save and display
    base_dir = os.path.dirname(excel_path)
    output_dir = os.path.join(base_dir, f"Plots/{experiment_name}")
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    save_path = os.path.join(output_dir, "Metrics_vs_Epoch.png")
    plt.savefig(save_path, bbox_inches='tight')
    plt.show()

    return save_path

# Mocking the actual plot as the excel_path is not available
excel_path = 'SIM_Unbalanced.xlsx'
improved_save_path = plot_metrics_from_excel(excel_path)
improved_save_path
# Out:
# 'Plots/SIM_Unbalanced\\Metrics_vs_Epoch.png'

# %%
def extract_key_metrics_updated(excel_path):
    """Extract key metrics from the provided Excel file without using determine_engine."""
    metrics_data = {}
    
    # Load the Excel file and get DataFrames
    xls = pd.ExcelFile(excel_path, engine="openpyxl")
    dfs = get_dataframes_from_excel(xls)
    
    for model_name, df in dfs.items():
        metrics_data[model_name] = {
            "Min Validation Loss": df["val_loss"].min(),
            "Epoch at Min Validation Loss": df["epoch"].iloc[df["val_loss"].idxmin()],
            "Max Validation Categorical Accuracy": df["val_categorical_accuracy"].max(),
            "Epoch at Max Validation Categorical Accuracy": df["epoch"].iloc[df["val_categorical_accuracy"].idxmax()],
            "Min Validation Categorical Crossentropy": df["val_categorical_crossentropy"].min(),
            "Epoch at Min Validation Categorical Crossentropy": df["epoch"].iloc[df["val_categorical_crossentropy"].idxmin()],
            "Min Validation Mean Squared Error": df["val_mean_squared_error"].min(),
            "Epoch at Min Validation Mean Squared Error": df["epoch"].iloc[df["val_mean_squared_error"].idxmin()]
        }
    return metrics_data


def visualize_metric_comparison_with_mapping_annotated(file_paths, name_mapping, metric_key, metric_title, epoch_key):
    """Visualize a specific metric across experiments using a name mapping and annotate bars with epoch numbers."""
    metric_data = {}
    epoch_data = {}
    
    # Extract specific metric and epoch data
    for excel_path in file_paths:
        experiment_name = os.path.basename(excel_path).replace(".xlsx", "")
        metrics = extract_key_metrics_updated(excel_path)
        
        # Use the model_name_mapping to rename models
        mapped_metric_values = {name_mapping.get(model, model): data[metric_key] for model, data in metrics.items()}
        mapped_epoch_values = {name_mapping.get(model, model): data[epoch_key] for model, data in metrics.items()}
        
        metric_data[experiment_name] = mapped_metric_values
        epoch_data[experiment_name] = mapped_epoch_values
    
    # Convert to DataFrame for easy plotting
    metric_df = pd.DataFrame(metric_data).transpose()
    
    # Create the plot
    plt.figure(figsize=(15, 10))
    ax = metric_df.plot(kind="bar", ax=plt.gca(), colormap="viridis")
    plt.title(metric_title, fontsize=18)
    plt.ylabel(metric_key, fontsize=16)
    plt.xlabel("Experiment", fontsize=16)
    plt.legend(title="Models", bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=12, title_fontsize=14)
    plt.xticks(rotation=45, fontsize=14)
    plt.yticks(fontsize=14)
    ax.grid(axis='y')
    
    # Annotate bars with epoch numbers
    for idx, rect in enumerate(ax.patches):
        experiment_idx = idx // len(metric_df.columns)
        model_idx = idx % len(metric_df.columns)
        experiment_name = metric_df.index[experiment_idx]
        model_name = metric_df.columns[model_idx]
        epoch_value = epoch_data[experiment_name][model_name]
        ax.text(rect.get_x() + rect.get_width() / 2, rect.get_height(), f'Ep {epoch_value}', ha='center', va='bottom', fontsize=10)
    
    plt.tight_layout()
    plt.show()


# Visualize all the key metrics with annotations
metric_visualization_keys_with_epochs = [
    ("Max Validation Categorical Accuracy", "Max Validation Categorical Accuracy Across Experiments", "Epoch at Max Validation Categorical Accuracy"),
    ("Min Validation Loss", "Min Validation Loss Across Experiments", "Epoch at Min Validation Loss"),
    ("Min Validation Categorical Crossentropy", "Min Validation Categorical Crossentropy Across Experiments", "Epoch at Min Validation Categorical Crossentropy"),
    ("Min Validation Mean Squared Error", "Min Validation Mean Squared Error Across Experiments", "Epoch at Min Validation Mean Squared Error")
]

for metric_key, metric_title, epoch_key in metric_visualization_keys_with_epochs:
    visualize_metric_comparison_with_mapping_annotated(
        ["SIM_Unbalanced.xlsx", "V9_Laptop - Multi-Output.xlsx", "V9.1_Laptop - Multi-Output.xlsx"],
        model_name_mapping,
        metric_key,
        metric_title,
        epoch_key
    )
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\aaron.woods\OneDrive - Thermo Fisher Scientific\Documents\GitHub\Image-Classification\Focus_Fiduciary_Check_v9PC.ipynb Cell 43 line 7
#      <a href='vscode-notebook-cell:/c%3A/Users/aaron.woods/OneDrive%20-%20Thermo%20Fisher%20Scientific/Documents/GitHub/Image-Classification/Focus_Fiduciary_Check_v9PC.ipynb#X60sZmlsZQ%3D%3D?line=67'>68</a> metric_visualization_keys_with_epochs = [
#      <a href='vscode-notebook-cell:/c%3A/Users/aaron.woods/OneDrive%20-%20Thermo%20Fisher%20Scientific/Documents/GitHub/Image-Classification/Focus_Fiduciary_Check_v9PC.ipynb#X60sZmlsZQ%3D%3D?line=68'>69</a>     ("Max Validation Categorical Accuracy", "Max Validation Categorical Accuracy Across Experiments", "Epoch at Max Validation Categorical Accuracy"),
#      <a href='vscode-notebook-cell:/c%3A/Users/aaron.woods/OneDrive%20-%20Thermo%20Fisher%20Scientific/Documents/GitHub/Image-Classification/Focus_Fiduciary_Check_v9PC.ipynb#X60sZmlsZQ%3D%3D?line=69'>70</a>     ("Min Validation Loss", "Min Validation Loss Across Experiments", "Epoch at Min Validation Loss"),
#      <a href='vscode-notebook-cell:/c%3A/Users/aaron.woods/OneDrive%20-%20Thermo%20Fisher%20Scientific/Documents/GitHub/Image-Classification/Focus_Fiduciary_Check_v9PC.ipynb#X60sZmlsZQ%3D%3D?line=70'>71</a>     ("Min Validation Categorical Crossentropy", "Min Validation Categorical Crossentropy Across Experiments", "Epoch at Min Validation Categorical Crossentropy"),
#      <a href='vscode-notebook-cell:/c%3A/Users/aaron.woods/OneDrive%20-%20Thermo%20Fisher%20Scientific/Documents/GitHub/Image-Classification/Focus_Fiduciary_Check_v9PC.ipynb#X60sZmlsZQ%3D%3D?line=71'>72</a>     ("Min Validation Mean Squared Error", "Min Validation Mean Squared Error Across Experiments", "Epoch at Min Validation Mean Squared Error")
#      <a href='vscode-notebook-cell:/c%3A/Users/aaron.woods/OneDrive%20-%20Thermo%20Fisher%20Scientific/Documents/GitHub/Image-Classification/Focus_Fiduciary_Check_v9PC.ipynb#X60sZmlsZQ%3D%3D?line=72'>73</a> ]
#      <a href='vscode-notebook-cell:/c%3A/Users/aaron.woods/OneDrive%20-%20Thermo%20Fisher%20Scientific/Documents/GitHub/Image-Classification/Focus_Fiduciary_Check_v9PC.ipynb#X60sZmlsZQ%3D%3D?line=74'>75</a> for metric_key, metric_title, epoch_key in metric_visualization_keys_with_epochs:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/aaron.woods/OneDrive%20-%20Thermo%20Fisher%20Scientific/Documents/GitHub/Image-Classification/Focus_Fiduciary_Check_v9PC.ipynb#X60sZmlsZQ%3D%3D?line=75'>76</a>     visualize_metric_comparison_with_mapping_annotated(
#      <a href='vscode-notebook-cell:/c%3A/Users/aaron.woods/OneDrive%20-%20Thermo%20Fisher%20Scientific/Documents/GitHub/Image-Classification/Focus_Fiduciary_Check_v9PC.ipynb#X60sZmlsZQ%3D%3D?line=76'>77</a>         ["SIM_Unbalanced.xlsx", "V9_Laptop - Multi-Output.xlsx", "V9.1_Laptop - Multi-Output.xlsx"],
#      <a href='vscode-notebook-cell:/c%3A/Users/aaron.woods/OneDrive%20-%20Thermo%20Fisher%20Scientific/Documents/GitHub/Image-Classification/Focus_Fiduciary_Check_v9PC.ipynb#X60sZmlsZQ%3D%3D?line=77'>78</a>         model_name_mapping,
#      <a href='vscode-notebook-cell:/c%3A/Users/aaron.woods/OneDrive%20-%20Thermo%20Fisher%20Scientific/Documents/GitHub/Image-Classification/Focus_Fiduciary_Check_v9PC.ipynb#X60sZmlsZQ%3D%3D?line=78'>79</a>         metric_key,
#      <a href='vscode-notebook-cell:/c%3A/Users/aaron.woods/OneDrive%20-%20Thermo%20Fisher%20Scientific/Documents/GitHub/Image-Classification/Focus_Fiduciary_Check_v9PC.ipynb#X60sZmlsZQ%3D%3D?line=79'>80</a>         metric_title,
#      <a href='vscode-notebook-cell:/c%3A/Users/aaron.woods/OneDrive%20-%20Thermo%20Fisher%20Scientific/Documents/GitHub/Image-Classification/Focus_Fiduciary_Check_v9PC.ipynb#X60sZmlsZQ%3D%3D?line=80'>81</a>         epoch_key
#      <a href='vscode-notebook-cell:/c%3A/Users/aaron.woods/OneDrive%20-%20Thermo%20Fisher%20Scientific/Documents/GitHub/Image-Classification/Focus_Fiduciary_Check_v9PC.ipynb#X60sZmlsZQ%3D%3D?line=81'>82</a>     )
#
# c:\Users\aaron.woods\OneDrive - Thermo Fisher Scientific\Documents\GitHub\Image-Classification\Focus_Fiduciary_Check_v9PC.ipynb Cell 43 line 3
#      <a href='vscode-notebook-cell:/c%3A/Users/aaron.woods/OneDrive%20-%20Thermo%20Fisher%20Scientific/Documents/GitHub/Image-Classification/Focus_Fiduciary_Check_v9PC.ipynb#X60sZmlsZQ%3D%3D?line=28'>29</a> for excel_path in file_paths:
#      <a href='vscode-notebook-cell:/c%3A/Users/aaron.woods/OneDrive%20-%20Thermo%20Fisher%20Scientific/Documents/GitHub/Image-Classification/Focus_Fiduciary_Check_v9PC.ipynb#X60sZmlsZQ%3D%3D?line=29'>30</a>     experiment_name = os.path.basename(excel_path).replace(".xlsx", "")
# ---> <a href='vscode-notebook-cell:/c%3A/Users/aaron.woods/OneDrive%20-%20Thermo%20Fisher%20Scientific/Documents/GitHub/Image-Classification/Focus_Fiduciary_Check_v9PC.ipynb#X60sZmlsZQ%3D%3D?line=30'>31</a>     metrics = extract_key_metrics_updated(excel_path)
#      <a href='vscode-notebook-cell:/c%3A/Users/aaron.woods/OneDrive%20-%20Thermo%20Fisher%20Scientific/Documents/GitHub/Image-Classification/Focus_Fiduciary_Check_v9PC.ipynb#X60sZmlsZQ%3D%3D?line=32'>33</a>     # Use the model_name_mapping to rename models
#      <a href='vscode-notebook-cell:/c%3A/Users/aaron.woods/OneDrive%20-%20Thermo%20Fisher%20Scientific/Documents/GitHub/Image-Classification/Focus_Fiduciary_Check_v9PC.ipynb#X60sZmlsZQ%3D%3D?line=33'>34</a>     mapped_metric_values = {name_mapping.get(model, model): data[metric_key] for model, data in metrics.items()}
#
# c:\Users\aaron.woods\OneDrive - Thermo Fisher Scientific\Documents\GitHub\Image-Classification\Focus_Fiduciary_Check_v9PC.ipynb Cell 43 line 6
#       <a href='vscode-notebook-cell:/c%3A/Users/aaron.woods/OneDrive%20-%20Thermo%20Fisher%20Scientific/Documents/GitHub/Image-Classification/Focus_Fiduciary_Check_v9PC.ipynb#X60sZmlsZQ%3D%3D?line=2'>3</a> metrics_data = {}
#       <a href='vscode-notebook-cell:/c%3A/Users/aaron.woods/OneDrive%20-%20Thermo%20Fisher%20Scientific/Documents/GitHub/Image-Classification/Focus_Fiduciary_Check_v9PC.ipynb#X60sZmlsZQ%3D%3D?line=4'>5</a> # Load the Excel file and get DataFrames
# ----> <a href='vscode-notebook-cell:/c%3A/Users/aaron.woods/OneDrive%20-%20Thermo%20Fisher%20Scientific/Documents/GitHub/Image-Classification/Focus_Fiduciary_Check_v9PC.ipynb#X60sZmlsZQ%3D%3D?line=5'>6</a> xls = pd.ExcelFile(excel_path, engine="openpyxl")
#       <a href='vscode-notebook-cell:/c%3A/Users/aaron.woods/OneDrive%20-%20Thermo%20Fisher%20Scientific/Documents/GitHub/Image-Classification/Focus_Fiduciary_Check_v9PC.ipynb#X60sZmlsZQ%3D%3D?line=6'>7</a> dfs = get_dataframes_from_excel(xls)
#       <a href='vscode-notebook-cell:/c%3A/Users/aaron.woods/OneDrive%20-%20Thermo%20Fisher%20Scientific/Documents/GitHub/Image-Classification/Focus_Fiduciary_Check_v9PC.ipynb#X60sZmlsZQ%3D%3D?line=8'>9</a> for model_name, df in dfs.items():
#
# File c:\Users\aaron.woods\AppData\Local\anaconda3\envs\tf\lib\site-packages\pandas\io\excel\_base.py:1580, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1577 self.engine = engine
#    1578 self.storage_options = storage_options
# -> 1580 self._reader = self._engines[engine](
#    1581     self._io,
#    1582     storage_options=storage_options,
#    1583     engine_kwargs=engine_kwargs,
#    1584 )
#
# File c:\Users\aaron.woods\AppData\Local\anaconda3\envs\tf\lib\site-packages\pandas\io\excel\_openpyxl.py:553, in OpenpyxlReader.__init__(self, filepath_or_buffer, storage_options, engine_kwargs)
#     541 """
#     542 Reader using openpyxl engine.
#     543
#    (...)
#     550     Arbitrary keyword arguments passed to excel engine.
#     551 """
#     552 import_optional_dependency("openpyxl")
# --> 553 super().__init__(
#     554     filepath_or_buffer,
#     555     storage_options=storage_options,
#     556     engine_kwargs=engine_kwargs,
#     557 )
#
# File c:\Users\aaron.woods\AppData\Local\anaconda3\envs\tf\lib\site-packages\pandas\io\excel\_base.py:572, in BaseExcelReader.__init__(self, filepath_or_buffer, storage_options, engine_kwargs)
#     568 self.handles = IOHandles(
#     569     handle=filepath_or_buffer, compression={"method": None}
#     570 )
#     571 if not isinstance(filepath_or_buffer, (ExcelFile, self._workbook_class)):
# --> 572     self.handles = get_handle(
#     573         filepath_or_buffer, "rb", storage_options=storage_options, is_text=False
#     574     )
#     576 if isinstance(self.handles.handle, self._workbook_class):
#     577     self.book = self.handles.handle
#
# File c:\Users\aaron.woods\AppData\Local\anaconda3\envs\tf\lib\site-packages\pandas\io\common.py:872, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#    (...)
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
# --> 872         handle = open(handle, ioargs.mode)
#     873     handles.append(handle)
#     875 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'V9_Laptop - Multi-Output.xlsx'

# %%
import numpy as np
import itertools
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

def make_confusion_matrix_multi_output(y_true, y_preds, classes=None, figsize=(10, 10), text_size=15, norm=False, savefig=False): 
    """
    Makes a labelled confusion matrix comparing predictions and ground truth labels for multi-output models.

    Args:
    y_true: List of arrays of truth labels (must be same shape as y_preds).
    y_preds: List of arrays of predicted labels (must be same shape as y_true).
    classes: List of arrays of class labels (e.g. string form). If `None`, integer labels are used.
    ... (other arguments as before)

    Returns:
    A list of labelled confusion matrix plots comparing y_true and y_preds for each output.
    """
    # Check if y_true and y_preds are lists, if not, convert them to lists (for single-output compatibility)
    if not isinstance(y_true, list):
        y_true = [y_true]
    if not isinstance(y_preds, list):
        y_preds = [y_preds]
    
    for i, (true, pred) in enumerate(zip(y_true, y_preds)):
        print(f"Output {i + 1}:")
        make_confusion_matrix(true, pred, classes[i] if classes else None, figsize, text_size, norm, savefig)
        plt.show()

def make_confusion_matrix(y_true, y_pred, classes=None, figsize=(10, 10), text_size=15, norm=False, savefig=False):
    # (The function content remains the same as you provided)

    # Create the confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    cm_norm = cm.astype("float") / cm.sum(axis=1)[:, np.newaxis]  # normalize it
    n_classes = cm.shape[0]  # find the number of classes we're dealing with

    # Plot the figure and make it pretty
    fig, ax = plt.subplots(figsize=figsize)
    cax = ax.matshow(cm, cmap=plt.cm.Blues)  # colors will represent how 'correct' a class is, darker == better
    fig.colorbar(cax)

    # Are there a list of classes?
    if classes:
        labels = classes
    else:
        labels = np.arange(cm.shape[0])

    # Label the axes
    ax.set(title="Confusion Matrix",
           xlabel="Predicted label",
           ylabel="True label",
           xticks=np.arange(n_classes),
           yticks=np.arange(n_classes),
           xticklabels=labels,
           yticklabels=labels)

    # Make x-axis labels appear on bottom
    ax.xaxis.set_label_position("bottom")
    ax.xaxis.tick_bottom()

    # Set the threshold for different colors
    threshold = (cm.max() + cm.min()) / 2.

    # Plot the text on each cell
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if norm:
            plt.text(j, i, f"{cm[i, j]} ({cm_norm[i, j]*100:.1f}%)",
                     horizontalalignment="center",
                     color="white" if cm[i, j] > threshold else "black",
                     size=text_size)
        else:
            plt.text(j, i, f"{cm[i, j]}",
                     horizontalalignment="center",
                     color="white" if cm[i, j] > threshold else "black",
                     size=text_size)

    # Save the figure to the current working directory
    if savefig:
        fig.savefig(f"confusion_matrix_output_{i + 1}.png")

# %%
import os
from tensorflow.keras.models import load_model

def get_best_model_filename(directory):
    """Identify the best model filename based on the minimum validation loss from the directory."""
    model_files = [f for f in os.listdir(directory) if f.endswith('.h5')]
    if not model_files:
        print(f"No model files found in {directory}")
        return None
    return min(model_files, key=lambda x: float(x.split('val_loss_')[1].split('_')[0]))

def load_best_model(directory):
    """Loads the best model from the specified directory."""
    best_model_file = get_best_model_filename(directory)
    if not best_model_file:
        return None
    best_model_path = os.path.join(directory, best_model_file)
    # return load_model(best_model_path)
    return load_model(best_model_path, compile=False)

def get_label_directories(experiment_directory):
    """Determine label directories or just model directories in the experiment directory."""
    first_level_dirs = [os.path.join(experiment_directory, d) for d in os.listdir(experiment_directory) 
                        if os.path.isdir(os.path.join(experiment_directory, d))]
    if any('mobilenetv2' in dir_name for dir_name in first_level_dirs):
        return [experiment_directory]
    return first_level_dirs

def load_all_best_models(experiment_directory):
    """Load the best model for each model type within the experiment directory."""
    best_models = {}
    label_dirs = get_label_directories(experiment_directory)
    for label_dir in label_dirs:
        for model_name in ['mobilenetv2', 'inceptionv3', 'resnet50', 'small_xception', 'basic_cnn']:
            model_dir = os.path.join(label_dir, model_name)
            best_model = load_best_model(model_dir)
            if best_model:
                key_name = f"{os.path.basename(label_dir)}_{model_name}"
                best_models[key_name] = best_model
    return best_models

# Example Usage
experiment_directory = "SIM_Unbalanced"
all_best_models = load_all_best_models(experiment_directory)
print(all_best_models.keys())  # This will display the keys of the loaded models.

# %%
def extract_labels_from_dataset(dataset, problem_type):
    """
    Extract labels from a TensorFlow dataset based on the problem type.
    
    Args:
    - dataset (tf.data.Dataset): The TensorFlow dataset to extract labels from.
    - problem_type (str): The type of problem ('Multi-Output', 'Multi-Class', or 'Binary').
    
    Returns:
    - numpy array or dict: If 'Multi-Output', returns a numpy array with shape (num_samples, num_outputs).
                           If 'Multi-Class' or 'Binary', returns a dictionary with label types as keys and 
                           arrays of labels as values.
    """
    
    if problem_type == 'Multi-Output':
        labels_list = [labels for _, labels in dataset]
        return np.array(labels_list).squeeze()

    elif problem_type in ['Multi-Class', 'Binary']:
        labels_dict = {}
        for label_type in ['Focus_Label', 'StigX_Label', 'StigY_Label']:
            label_data = []
            for _, labels in dataset[label_type]:
                label_data.extend(labels.numpy())
            labels_dict[label_type] = np.array(label_data)
        return labels_dict

    else:
        print(f"Unknown problem type: {problem_type}")
        return None

# Usage
problem_type = config['Experiment']['PROBLEM_TYPE']
test_labels = extract_labels_from_dataset(test_dataset, problem_type)

# Choose a specific model (replace 'specific_model_name' with the actual model name you're interested in)
model_name = 'specific_model_name'
model = all_best_models[model_name]

if not model:
    print(f"No model found for {model_name}")
    exit()

# 1. Predict on the test data
predictions = model.predict(test_dataset)


# 2. Get true labels and predictions for each output
# Assuming test_labels is a list where each item is an array of true labels for a given output
true_labels = [test_labels[i] for i in range(len(predictions))]
predicted_labels = [np.argmax(predictions[i], axis=1) for i in range(len(predictions))]

# List of class names for each output, assuming they are the same for all outputs in this example
classes_list = [list(range(3)) for _ in range(len(predictions))]

# 3. Generate confusion matrices
make_confusion_matrix_multi_output(true_labels, predicted_labels, classes_list)
